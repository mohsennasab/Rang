# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohsennasab/Rang/blob/main/tools/notebooks/rang_palette_workflow.ipynb)
#
# <div style="font-family:Arial,sans-serif">
#
# # Rang palette workflow, notebook 1
#
# This notebook takes one artwork image through region drawing, color extraction, curation, adjustment, checking, file preparation, and replay.
#
# Upload the artwork once. All seven stages run in this notebook, and the final
# workflow ZIP downloads after verification. Upload that ZIP to notebook 2 to
# prepare a complete proposal package.
#
# Created by **Mohsen Tahmasebi Nasab, PhD**<br>
# [hydromohsen.com](https://hydromohsen.com)
#
# Copyright and license holder: Mohsen Tahmasebi Nasab. Notebook code is
# licensed under the repository's MIT License. Rang palette data follows the
# CC0 dedication described in the licensing guide. Source images keep their own
# rights and reuse terms.
#
# </div>

# %% [markdown]
# ### Contents
#
# 01. Upload the image and define regions
# 02. Extract colors with k-means
# 03. Curate the palette
# 04. Adjust colors
# 05. Check the palette
# 06. Prepare the palette files
# 07. Replay, verify, and download

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#fff3cd;padding:14px"><strong>YOUR INPUT</strong><br>Give the palette a short filename. You enter it once for the complete workflow.</div>

# %%
PALETTE_SLUG = "your-palette" #@param {type:"string"}
DOWNLOAD_FINAL_ZIP = True #@param {type:"boolean"}

# %%
#@title Set up this notebook
import base64
import json
import subprocess
import sys
import types
import zlib
from pathlib import Path

IN_COLAB = False
try:
    from google.colab import files
    IN_COLAB = True
except ImportError:
    pass

try:
    import matplotlib
    import numpy
    import PIL
    import sklearn
except ImportError:
    subprocess.run([
        sys.executable, "-m", "pip", "install", "-q",
        "numpy", "pillow", "scikit-learn", "matplotlib"
    ], check=True)

PACKED_MODULE_SOURCES = "c-rNC4SU-*lJH+)-Mcf{P>dvht5x?B$8EgpCV6b{r>#>diLzKzB$uROt3LhrcRm0RASqdHv-f^&pN%OJ7z_r3!OUPVc-k2!QIbXBXs2iG+|qwnGd~L^7JabhelfGA@KDSG>(Y<!tRhLG+`El$<J07GkmXi>`Qux7Yn`5-UA%c~`SHZMIGsWL7(a(eoVx<p=MaBdlVBQ-!yq0ntvsABBENvQx3NDhg3S8KAJ6<rVg-feN1kPO+wBv_rRJf5cW3asEx=8}=`_dyPT*3jSSIzOpeTadI0`-oku?jV6mc9a!l<yI?IKC7WQs-Sp7m*w1y;P6r%Tt$6RQ6(OQL}K2xx?{l`Z1@Hhu_;S+W3(M9Vp$A3#siAf8}PkRVLIIGm?RR#+kQhG?bU{E}lg#g7yS3uITnvp_vAvIxF-S@6$AkQcXQ9YWReb1P2q?d930kHgE4AFr*x1m}H%zxHrA4WnQ<bO1)4M4toO@lqJnxDbDC<4<oc&aSV|hVRZVp>_%BwRO8AXqaPXPT!oqZ!R^4feNt5ZTz+MDNB9{#sv^23xYUAHkm=&K+Fko&pd=aEare_m_3BKK9&n0U<P9yLBU0az&?k;1A-`-BloO7L#435&f_4=p&ucTlNckm0F&`Ojo%a+%4fj7)9?;P7l!5Z<Hg6zw-@Ih-VLwcU!GmP|9J5ZI&<u`8THoh{2%i_alJo6kUtIo_V<543vufCS>`Y8o13<`-|6lj9PYbT+uJ)hIygG);A7{wy}x&KFmP{UtM)&r)$Mc-kGdyV^r&;tIp}urv3=C-938aR)@pZ7_V)IuR;P2)IqA0X@#LVr*WT|82F`8#*Z1ewX9kM&egDX{I$oRpIX*t#!=m^fOjwvnkHaDvW_Kfd=JdGb8Gx91QC?(WYTxdBeY@lEhb$--S*(E%<HDZZguT#uWpxM8z@bBY5n3?EY-kZWw(r1)X_WYd)-1G#%|h!oJj#YM*Sd495%(ZVfQ4*$7)O8xl!D#@z=H$F@%+44rhyI3o0v@j+o!D8?mn)b?)cA${xCxuUG@<N>Ok-~P9`X9qIBl>u?2w-PyK7)zdXE)f&2El)(E)u4YCGQ4eo%&y$@&C)*=r;90C_l5o_$dm-+eJPc59XELRcYUuPgcER;LebOCdNnzX{)Y60V<D7ThD6eSPzs(Wzgg5(OvGnCgb8FHKp4CoXE7EGD~25Gban3r#^K***b7OjU28p#oft3@{T$H5OFG!;a_9ApIIQud9X!zr{E#(Cj`^s@;k7zPk>js=4mCq=_&q`myww!Z6&uD}BjuvfBh=A&Hriytk5vn)$8U??s*U*v@~3Sf#UQckmE4!~g10T?CMDXzc)w?8wBea8Oj+{>frh)SQaL98Os`p)X^JJx?&c81T$r|^7-&&T*UGT4YKx2&%9%{MsaKp%efeP6um06C#s^tR-zT(ET%#(|&NW64KjF(-4LHe)#-K;S}0QDT|1>tP1#pFKum!nEIS?;pTY3xzvf?*wL)4WC}&7vNNU%MXB7*W1_T7-NC>AYL_WXj(O4Mf0rVY(}cR*V$_yyNr_cjWu=|4}3&a><)Gg@BuOkOuwN~t%`uiAL%0CarrBtS0N;RxBk;23GCrAMS_kiOu09V9oGJy&^tcH$%EY-Wd**6ZXJ0?$47t$mU;y|fV2ZnsCE?ie0*=;z$Yj>z41H``Zj=mbPgLuGyLxW7Ch*)DBQ-vs-m;5QrD=|(JFNZC^K6feK7rz<aBtH)PhHowctf5Y>7NeoCNS%q4tWnpSmuJJVF(uI+T57siJ_;YwVbd?_1^jF1`oc4e|?`5vV1CllYfoss?FFGsqYxeg&L8B{GYFfj=~4$U54Hi;=3ZH#YL0*a*D$qdPB*KikAGj(1(BBdCEo9WOw3tA%GREo;l)1##GHnI?se^&R>>3GP5!%4u$8V-T8M8vyx^WBt3eci7ffUqD070eIA~Idy3j*0CASp2y}CD1|(qQ0tjL3H>;Sh22q~K#o^FNqk<UGD)4k)a5K&s`#YZBfKln)nO@GqGZ4oEDOi5EWsKTg#oRRJcRJ)ZdO>Zrn33*mv_UT-dtav{|yN6Bp0hROMsHMV9pr&7wS&Ohb()#2gkrdEl{u8`^SgJgLU(cwW&^LA2cUY!Hy5R$E3HlPfog>!;KYNB>Rq!yVMdi1dPhfcTP@@2Wqz8?o5J36UKXoM|-UA9Urz2_YWE4?$OD!7<Z3hx*T9lP#zE3jPd@_erNAlj60oU))w3Q-IIOR8xKJh?C1!?_|y^Zcp$V7y2sqzqr;>96MF2xygWL2w&A1W{SF~|0;@%vb=Uo)!*=(XzP6!bdo((SCmkReDcJ43lXjaiULmLa<^1aW<A>q(-#?vQp_KcO#Gu8Myy9x3;A$OoR8=r+&n~d;6V~lPnK;Sjek9nNtCg%LpOZB7;afuw^kL`cAXDWH8p~(?w$hXco>Bp;y!T-|G1bv4@g3~s@eC9un0;e`uSdoE*cTxla$IJ?7K51?-vtw|qV-{MR5hvhn$A{=79o8Imj>xm5yH*ub~&SOu)%>6$iLr8Ls6t`PDw$q;wJ&VKoJhy2mf}JY=z%G{D0JeQOD2XHOxpK{y*yS>#oqUq2y_o1+ftGRM*i3KUEWCIVCmqv;zz2X_xdne*dF|S`%tVpcu7C5dRbO5-1J}-w~8kk6=h0(32xoS-+Daaw$Saz(3-8h<Iqf6uv1UoSGP?b(B*L=UGRTZ(6vBT&Y~UM1}5#3Pi|Cg~<i9H#x;x7hUN7MTfC$A;O9o;TgI@*aNXNcAU&oBA<X3L{Qit!Qw?A0DT9QQZTw}byNwhrg{e&$i_PGuj&D6`x{EW()#)yKXt`wOM@)?<uoqA0E-w!jK;+Xhj2ureSrgf!F=Re1n3n5QjE2UZZm?y_yMj}>QN78-6raBO<Psf8e|&E57u|s^9?nbG)8@clC|=!O8IMMd$b}tN6qTZh-$Tg=g=zZ?l+dg5rL9&Qqljg_+GcM_#PLBB8Lv!Fx_@z!F^G%WgYIRDLW}pd)pH=g2&Wu*|tEmdvw5tADe8l%H_DqHc+}04rxs~aJ8!lsv(=$xXhD)xu9ka+5$e*mmr}FuWH`~oUwp|Is$@$CdHRo`K2Siz`xf5?E=2G>RgRI0V+7i^Os}ONrTIXEpf6zH~@-Q5u<|$qNIQ~W9`j*dNboU>oo@`3kZE<fY53?Utrylu4s!r(dbB*>yGq-4(DM!oCki4P6_l2sa4rr$$t{wQ*<(7am{-=3W|pyh{=D-zG(!W3$H4!??M4bKUj5Dj{?y$%xtUsj4!5u;(lIO#Y4g^frg%;`tZ+1m<1E%g<(@uGuoA&QfiBaGm*SBGvTEPa!}h?nUPZ@2XHsWQhgH+XtBQeWgy&$uJsE7P(F8<eDe|5cjP>_Gt_Bp>@Avd0Ke-D3{Hb_uqV0WmMll30<Sb1>;bx5499*R2%?$V7HES}kQb$kdlIrE%<{)slIP0Bt&d1<42g!#dKPhRz&6KD-(!z;)wYH!0%^jP9hLE26j<XZ$tBjfF(OA+Y^P|bT4a=?4}ON;!`MW9gh2YF9}0UPF$~$osUxXz*_Y-N+3eQbz@#C5=$W!&0*I|;IkPCtBkH`+j?vXQf$4<rV5E9=86-$$Ph9Q>f##=Q;K{H!SPwQ;>5<qJ;*mzhYO)+A8O-;lv3|P<BOXiO$1#8itTY_oTU5cyiv;)j$j=;rSuTZ^@<UTGz!1BKKtR$I!qv>;CbXs?Zwf1j3*2Zk8)9I%xh8u+TUxle6H8W;_D3-TPGn3NH&8ZW7~mi+a4<7}o?1E9hbbjo(`SfrUIeM-PbS<pBUQ`*%ens;&ck2X8LoDqO3|t2XCbgt^>MCdfj?OisR9_NUltRviZ;$<BurA`rcaI-Z3V?|f)sZnV*_S0qbt#h!tm+7*Enm~4s@Jm>9CSRid=(zw{f00b!!gAkHP!-&HX^~KRrva+bn@-8WK<RaSZH@(=evlhr_(=NB(>?@vXGS=zXJfuraa*5;0G*BAD0&U3>#xi~^!Am%^niHabO!+=S(RlWdu`GkDh`7Htg5iu}SOSvRq<BM8dCH0<%pp@>Os{8EBbdLDB$paHTQG`CVj0xtJ1qZP!9d63~ia%Gq{g`XAujy^_eKK7}qAsFaeDH-H69OjEr9uzjSw#&u9$g8gjYEI6B!Wu0Fa%*N_ecielQ<uiBm0|f`!_;h(2+s3*P@;)@I$4?!2g~9W+!S8yE{K+TC76{_LL1HjqX<ps<Re_WaTTxMw2HM2E8wKgW~C@DH>a#L$-^T29LP;7r4T{e*a&xFOC<{zk{l$=SW2`ouWMQe7)`lOeGcDnYrt*;C2mNM(!|V|*>z0pO2tK4jC6pagOW>)X`{7<<wDe)Y5oxmw1GNkOV}|zm4$ync>vP|_vUc($gI=V7jY<Az`I{GzF!n_Dw<ouxM-s0&yToif%_xk18VhC$6P)EQptQN%xPrjA!u3Q+`kK?nngc`7**lY3e)c#nLPPEd0^#<*G&-@5*9h`O8Qm~oEQObrU`TxsfX+-Ml_uzMWR+%oOsk4kMU$NhH3y~3Yr$KhEVqy75ydsNyA4lj78W3y3Lo?&p#uAKmW|&M1whe1kS?w;aQhri6u;-gN*HNZsBY~`B+~Rg-1z7)dYZdTp*I5BPz(;Sgz3Y+6{{z?bUudzpz9Q%Q^Pd<v$<OT(L5(<Im1GDy1f!oGzVmPRxOKBy2FK!|AX9#?4`N1~$F-65t}c9AC%rI8><s@E|udP+l=x%tx^wMz(#78(i>@BT)A)0~%w{WxR_wA5Q=A@oJp`q`61KImP6F1|8VAlfS1z6xe6#-1K_bMPnvDt;(5LDh2v9^s~F5FdH@W32kmo46UPF=NX1;rH?EY(ns2O@khG83;5j3aP47q?TLpI+EIp+jhgSV!`2f{z77y<&Gh?yKHbu~PW%asf!Zj8pF{D@j{SMXlD-73PFBrde}@IW_b@KYv)+uyu+Zh!?w@=ZpLo}`cJKKK7XzQ-Gbqf;SXk0(>=m_X2>#T|7t?9@h@$#-hg!Sc(MAtJ=;2teF*@ZbFEWPZMacuG_RdPwtiT2q&x_nPbcB>NEDM`+sY#fow$z<G;IBCiF|NIO%idj-j9?OcBU*BFzTvs}0}$auQv86yD?B9u*AIyr4I<K0x&m^3hH2xEqM&Cz34~T^YC&<pj_8g9mfNX^`u4C09t#`fae_nIzuj3B)7CK}qS=(el46En@dfILjTekF^vhkCcoC07jw+;Ayvp!1P%RLTERF%ZMmyZ=fEI*O2zXWuI3~lNf~D#`^cKbKJk0Y@sv%;fCQ!Ri@b7B3st#y62efh{yEDM$CR3V87I+x`Ls308s1!GETK^c}KYr`i!8h0qqq4I}crva%3(G1Iii*bAPs75Gz*L%8Z>~<y&(VEgs2N5hk|C|H`pDbBP4dmlTBlBlpgqt92)I=ES>5Z4hUNGT)=^OEjS<WRMY{vkG<78dz1Q7saFkjwVhL+Qfq|e0xF&bH9LbaG#PQ>$UBzefD1Lp@Zk_n8>6_LMgQvq44&&JLDpVA+ttiXdfC$@FYH1FFXA<6_+XfbXjziLrNBTUC)sR-&UC|(GG<+%b0EI;y{!?p{=ARl_F&oQ)tx}Q-XakG5(7P&T<}^i#T^|;#XpRiN@i=~wJC850|J=rQ98Enkm<4B54FAm2Vu_v+7#EDUBUE+j-|n!@wj+cMDO^HOGl9hS0e2S-O;*D@rv40S?{>(tA*xv|K{j6$9GF3xS_k>O^rVbI(ibMm^kD>w&&0&LQL5>M2g2;ynu(~MLbk{j<XxNkQ688mvF(N8UPs8TVN;fqxNO)Wkc`yWF9T8;Ub+!bttP6wTTw&S*~Z+=v$2|9a)lG~i+>JbJ;E6XOK1@mkyt|~pwRQvU69;memYz7&v`Hj7ju4IWD!4*`rI7ZKtVVQ7`pLrlFVT?D9q#%3AQCJjM{3hBWA9^(3?^?2mm#TRhHwPG_<s3`3dzoR)oYWXZ4H_ho%wF%8D%CN~uv3+v~gZRlk8W+YG<bCq%zcO@c);h$f|&RpJKmitq9b`UZBPhR91MC!^sR5T2i=&CP1<t>+J5RRAAIHuOPN&pGbKk^KYc9vCn-)R3Dyl^x`b;KxATuwd{RhMDD?VgC!cQ5Z@vgG)b!A4SrtDRq6eL(XW~SFU#G&K>SV!8?-m%FpmgR0nl0gO7eGRAMl4@d!pPg4aXgN<>@VpG>HbJRrlcWDEB}kSf1>6pXRtZf?y&+*d%-f_4Z77r@D9U<0AC%;Ddopa{nRWGS7vL5%7PU=;@stRqGs!kc2yp{L}@GAuo|YMj!n5sT<X>&DyzESKH9>W&8U1czUj-7c86xW|lVlTu9q*Y@D10jPVzs|12`m}Km4s2HTwxDSRa(1T1#>I4S6v!i5^JjBAtMOmL%bnxai(F~{s_WMMQv9w`*>(7@Msv2VeM-nXxwp?AdWT}xXz;MjZfn4shAWf_+NeXe2K(ILsX7XT|cj%-N$FA6umE(Dwd03!Bh_{`Y;q%u`qgS<;b;^|XMw3}9=Y<@#sB$C;E#^jOP;>)4_$p$e<WVPYem@B_o2m?x`~EdZH0j%+QR<gvp<SapRV2JTjY4FdKLE$wv<HqyoT5u+g4u*%nxU%{q=?P}Pa5=6W{Ax-z|1^6=3VmN8eZ;m`icy@f%yy8b^qyh=g)bNwcgy}@i7WZ{3-c0j3WOvo=ezSX^7AsUIh>MNq#r@?cnj340sWLQ|D3WK8#S{;=!1T#Xa@tn2Mc|i@>h9lc@e}4D)fvpZv1G4SG_E%j1k6aO+NSurN+QLf{!innR_tR=L`7SYXM8^0XGv{5qSUbC>tNIVKst#IO!o_5}z54zaZCQ-^fV*#Zx&;10X}-jRoMip(G1<Al16(;$H+Eq`1rPz+j=ARlKTX?BdoD8SK9rc=*)OGuzR&a8=_-Q(`fJjnvKhw}V3&V3*TdSuZm@cH~*lE8Pg6+G*cDd{<IqhpQyT*!{IN1{N^awJ_AGde1nMEPrjs$ROZS}j3Cuw#$?ll{Xz_v^j=gXvKhwC`36mr?lC>0P|q=SjakxTEP_yW4iZ_DB2v{*n9jxP8>#KLN1+C0Rnj@AfWQd+zD01HI9`-uqX_^dbccu$&wPAWnlJ9WM1!b`*Zf$Zd^c4{O56vr~K$P~?Nl986GLc}U8)7!r*xA5|p{5Qv{x%VYt~#k@_->mkL_TK=7niy*y9U>NbpLH($xpWUT?mIuaR(A&7tbFMzfgS+x;>F{;6!war<AjH*<5xCmPI#=@>Yg;3T(GcllqrNEx6Z+Sy{tWx}cJj*U+1@J$S4J!@)nii$o!68l*>&$tcDKM|XV=SAIs1dh6m$yOXJ7{IF<HqWa35H}1g{R<)7D<8W=<Y)OA5s1+`G$?MQV2_Dz76qlBs&drw#~^ts$#)OR4Re8hYB)``g?68~f(s^gU2_;P9_ktpU=+{zLEf)+6ftfxfWEF4N6L>B*fpdKx#-2Ns4AC|82hcApUL3KUCFlr5l(1$43Azv{G&MM6;ECN1gXE$}d)?Vw+u-S}xq2~*kvd0h!YQ%=(~S~91oBa)(!I)5~talEuVQ?q8LLY~cYR5jc&=Qx74OWTJX+=vk$UdeWZes+QMZ5!1)T6OWeTI*EQDl2tqk3&3Fi@z7e^}uDROO#ua`Z+A~@Q$t{q7kIld>@sg+JJw;UzyDd1Ub_CLolDl!y$7i?umomaMP9>HGb-W){e(ksXkyVWh^2tZAsE<Tsk1%M>owJ7Oy;jrhP*mD&}c|DorMz6n_B2JG3MNfKB_Q2yrp$#9u^3|7P8Rj(Je{pZ%;)TDF|%2uh$xGM?Pk*ca?b8u$h7Fl@vTMScl{cOpQATO-UBr0fo*1OVhd;BQ++w}{FZmS{K+$#aTDJ+Z#&Vgx6;DsFnR8J;%(q1`~pz%)xfhZAkDQ<0!VmO3EZgA7aCFwy6%!VihrtH~fbo{J*%J8~`xP>piwYKaEd*<(lwsxl>?u=XpfLt7%rqR0_-JuibUiwN%<s4*Z?D<M+8FXf0NJ?q3E`2@+xU{`xw0%ON4OYnMDr7XR56kzlLA!Sm-q8~pX3K-Xn$D&T!8p-B&a;Mn?n^o=|yOuqEu)fjhM-VtZ`Pd;<7teMZln_yieEiRh1;QvA2IN`-<;s8nCcvdI9CkA{*uKMu4s8t9z&CBj`AtB49SC#_yW|)|@pAujU`tXu4c5#<hCcQuS!89|n3N*}GgJ0+loSPMIQWXYOvIu@7*lIFL<?#-<n7eq5Jl*4sCHCYqOwJRp7~Ld+z%g;>>if3hgy=8=^`HUW~t0^!YVR+qGTuN(5G|rq&*98BKrxLBPc3IOY5g(hVg0F{%j5^^(eGH_&KUrpJwlF<5^LpdGGb>*>VDE8<oUBI8LCFE=jkyFc_!X?jEiIbsJxV;~>tJg^ig0bbf7#*D}Bajd+-e=zBp^zOHGa%73`8e$M>dNJ0`O+a)VWBfkKG%{OE(F%{ZsN)z!Km>XRRT8b0Us?sPa2*MJd&?HQwqB#eOcn3PNdd}}bOlDF^*1?I)2%_9&faj3zu<>UjRH%Re?2RKZU|<MD;XnNZ23M}Ma>KrnWlGt$Mt8THl9W_Jfn6iga;^QY#{;`fMgcw7!pqmft3^nyvm9J4K%Qpn>E+p*>yMWdhOlXd0C)cN?Clk2B)Q#LH(#LG#rf&khpV$8Qs-<FU@Uxjc6$ElZ1|V6OQaf#@KWts(2^edQN@>vNoL;Qd-e>F$2>yM0O<)L-V6N}=-rM+XwAdSJ58YbW>iR2c-a^<H-DakdX0N4_ESmW+np)M6>sX#!)VFQlpL6-1$tgMHFi}*N&Rcjy1CsUBzZx*2uHY5pn$qUPNbLbf?xc<EX0d}36K-xOwtfx;ku@O^&bONTTrL;KrCaCAJCD%wh+m$YO$50+mW>L5A$eoXGG-S3pS_n#fX9%{>yLu+HRc;UU4T{_y=pq?P<r8sb*T$?F|IBIdV*TfXV;_xm)X7^o9H@EdHy$c!aJcq`*)Wl#jOV&lN@WpcdUR$lk!`qFmJZ4Rkt`ZMeK~FPkC<ZpDwPxjZRIN#uKCS0?|+h0fpP*rYn#DxpW+n1HO!ZE6}f7A63r--Y^dzCf2sJ`Te^4Lfc?qahrx+Y+=Ix?9=p;Nwx!EV>WWq75^3JPSdo$bxa0%AidAI)uJ~PQsrXoa=94v5YXrC0gq7mpGa4<K!W>WD}^Wri-F_8b>u(CARiShM@~|swL%nWmlBAR*M?_&{3dCB3aIC+Su16&Thn1-wM7_ySGiwXdP6N89%@3TN|Nmo_?&JP<O;IlzZ7S{zs}YYFMU8G!e5=s`LRx(&>Xkoq(A&Pd*16X@>%W3&_15L4C}a6ilc)d6_h#GS~!9V`Gg5h7`<#J4#K)7N-7X3>+4s(9cEt>%P{jvi`vNml^<Lp0gHed09~hP5X^RpjAtr<1q>epVvHKFEH4zifv!BT%-^fF%n`!%ph7l%mHI|Do`9R%qat%vU7FTeyL<4U#w6Ry?=x$h9DYqg-j}3DpaBKPs4X-KU}=IK6^)73Zit+G`N@y<oIKPRO~8IOKd-I8CR6`v@lO0!E}^LNj4PRBN&r^sTEMfh1Pb&lmd<WCiFlXIHEQt^P{aLsxB8tbHQTBxa%&Sz&1zAH@%ZFp=lr=g^L893Q|AB6Fjasdlmc!%T7;?mW*)a6rB@zl`?tb7N-n?r;*clw*1(7e|`PwN<_mO`<t3r-cr)apIh^pz^iX*lrCczIO2g0<mAYaHY=*2r#=(IfpTJw2Cs|)z|M)V4fNDfmyIxqHBIHUw!|W$&AzFW%umgHw~|EE9nUx?8+ISH^LiV$6~)MJ*d|0f`gNzeN4Uj4;ew7^72!O9)wz#n{c+zg$WsuyLBqL95UD<`3|xY@3p<oMtJ9{#{`BXSaVSL#gT(p{=6a}BX=tnIWP&!n=>3W?pq`E*#su=Gw}#87qI8Xx7}-H6)OWl|qO4Q=#L!~$09aTSc_|C@0S1XILjmjt9%`ORVspC=t!X!XeSEk<nFpV@S1JEt&wApIt0sN0%wDRU7Nc_;`ONPg92)BPB)nrz6+R75l+jm_28EoM4d$raeTLBjm9er?j6ibT%M-;m$A$DnQORbCThP^p(yDf(m=KiKAb~WyEDC^G%};u_5lz}lXs|f8IPJ3boQujOGy^?bNOP9V6dDNH`js|#Wv4U)S{|0c!R=QNm4`v^Kuf1}4(wtu_RuAh+weLMe+~LTJWLO$ve-PrVuSeb8J+TN9uz~uiUO<XY2{i^RLXk@C&g@KJ<8v+0PWJ1I4@OdfDGml4E7)bI^Zrxl1=bXD(O7U#h0@9^4a2dSvcXS+`e-3x^!-lFzmOz1DQV*Gr^V=f)y7K9!CBWq+Mk-htJxv&dh%p3f*%^=OA(W<#P}%#mI$mSis20GJVc=MW>+`^Pwa;9cMadJLX#b4uF$=q~Z}W_LD6@oLK@Q=24dMNl1kslLP}D>TZxCTk10jJzsZJ7WYS>EL&aD35LhYz{aUmIR8Z91KuReQy`8k{73(@&l_T{B|eFuzefy#f=PkJNCe@urrng9w7OixxV#7n9-A?&8fitxiS!hP1uCUH-cluizQQ`(1!`RFGi;bBpuA)5W8A?eCLSm0(l)<oN7D2WefCfqC^dnPyVqgjy~VZW{9_d|Iqtcfi(+r?7r?`R{B-ssvhY6_eiRnV{z==V14ekVURR%R=^Dc7O<p<t(W5@RMm_Uec00SbJFxolvo|{2C!au|5uO{zZC3I*pu=YpaG4$QHfWY0=|>`*Q#+~3{u@`0n6Z^onHXr_-V7Q~SxeyZ$mvs!IVPywpr**c#MW>~d!JKj8@8SponE^;!4<9=b#=Q#f~66Z_(ISwxibP<Go(@SNWMYJd`r$E&VEbjXz}ze!MG6x2ZI`bd#sMN4K(f%h2w_ya5JP4asJ?vKr!mAN-N%9qS9|#;L4HEQ@rHXzWx=3C?Q%({d%eQfpkjhi-A#2Fuj5&CqW&e_)@}@MH`?B&SJVS3z?=ji!9VqcXxMhV?STUW3>rIC#+Ed^LXdLupk~CCX%!=AN;VOAlXkKT0n@|w$PFstN%S0MU%Wi&f-#bKFz>z<-RzQ`dgI6=!t?%rza3Q{H}*dU)!wIQ};l<$cysq*3ItMlcT+M_XvZXzurGMIvDNKW5+*%m4_Zrj`st9j~=JfqiGx7Hu(>CzizkvL;sKp`iBRH-D9qEble$D8U6(SqsPO;ao0cC9h5lXW*A^JNyZcy;EieT?u-*%+q;wS^DcFRHqG*4iPXsRYYemRTf69jZ?Ut!M~-*5^v8b-<Y*Do^g8W>cKY~jiXqeSU9Z!HAGk$uM+wS%qzrsJqK%neCw&A%FA68t*OLSMPkd-$TC7FhJ5C>WOY|{#VFUUpBafv#bl#o<zVHE22X4BPSxX9a(7Z@!DFc&S%v{Q@&nNNdPyvXZ<iV`KUZH}NgYhiEjgWh9R}qZ`<>@SpCN?4>=DJ`BKZezMLl3wBcY~jKB2p|DvZFCw%R)Q_tEI$LEsNDgRA>x6(!z})Z2$YW47BGjilkw<j*gDL9WSyR)CnT%%n!3~i)1mLwKxo>hbJ+b3B%|(`do<%MoC}_BJ`Bs*}L7zu1Q7Qi%z0^8%CC8*LQsy1&`m}`6;s6xA>#=kijqf2MChgg)vYAy4}|J5ZE}`(E4am6iLhoV9_cw{u!%B7{dZ<kOp>)8>?HwrLtAPrv$){A`K{C1hFMlE?mQxCq*vxzkF9KTO+JC)xYlSACC9;z9ms;PW*OdqVH=G;|R!2QiBA}1GC{Mi6*<okP4jyDeN*mT!EC+%ypuo!A!6`6^pG{iA&b|I}hWQm?~ZD1$XxA<59=&_|09Yp~kSa34tL@TMKF(5*-l5FRJP&nJkSWSjV7&RK;;MCH0v#;wUJTrr#IGn8a&Z)Un1QisU;G1{pJq{#NRkQZ&iUg1MjCLSLc<TdJ1fq$h=OIB``Xi6Bz1>6iF&uioCf<*{1zlFqq`P_^U{H;iNHP@?bfk`octg{$>iye!o%x1n~YR-1*cS^d4KA!+ryzpM4V7qrgRNf%hjXfLI3QT`G;_#DKgHpIL!!ik(4g841J0;V{PLMV^%BNa1Uk(nXl#R>4|Z&ph{^P*r{U{(xciF+--nyRM(<L@PmB1tt6GudzPbyn+hrN>!-tZnPPrEqPMBh;rhUF)Eu=$frLW=(|0vqyx7Yzsh62{2PIk(-<rywm(xs<Zl_@YbJX1oJDOo9GJ#^oF2V|1N$4?c=**HqffbF!kg<xI*D3t5%Dk^X9KY8`*2FPlV%Hh0$v`KlpEVKqFUv*pn|hWnL8tYZ^w;Moh3kV^f%Ry}Q2=;4UpgyR{+-uXQM+t<C|gK&0XBHi1IPZ(q^zQk$uZzI0dg4`Tr(M)={#DPuw8Mxhj||M4F}l){6MpN=uu4Pyg#L#MO5X>htV06}p9-{1N9%)U8tt%Ewvwecg2h^+jCgcZo$&`lj>0r|R9zHS&#qj~vx)if(f?UsQSV#-hi^)3S1t;i;ELC=PDlBD3SBagw-TaS`>_6e@}L0*9)E~(K!@v1L%@dv4XR|^OY21n^YST0H`ijvL3Xo|^@E--Fc^$}NcFO1_Ldw>1Y1%llDt?~i`NViZX2zc_aUROq^?zi|)s|e;8`xszA{bC;Hy)LNFcq{==7<5o!c01F|QE&F>jdy_W4iB`VXezp0d`)%+D&nC2ed|ZzUEG3+I?sD!N~tN8@gt>+m;Dn5ch`3jxjViqd&w0ldTwn-S4s=AyimHLeuW+$X6;h7v3AkO+I7sLq})_Xv&Pe0;l5h<UKWJEjCfh)9@A9m0s>ypenhujAt-LtRseI-kVYgp=44A7gIO3W)QohPBARFpCn!1I$P2sdUEFAC5iy{1KMQBzzdfk|TUqDtepYQz!52e7^ZsXzU@xtI&(fm=!I@QFiUm|EK>#6=m_!+##^DKGD#@r?PlW7RnVnx-OR^aktJJ+;Uk|zM12L6-?+Nef%IN9Zs)D7cP^Ce^4M_}2-uS+(s&4?Z$is6a<AA5AYwTYeB2<6PYMy+v(&d~mAf>AuC#9HbFo~Gm8MTt9P$rwU)I-DaF41La;8evi1_@wlifv`GEdPIkU?zJOcUsu5Cyd>Lg99O-TcDSd!$eKvZ*O){7M;Jte?P$VqKtC%14xX2cL(KKCYZ_`ej!FNU)u&5pZc1Fv8Z@O!e|S-L05f5v0BM4=E$cR-E(ToiVdoaQ1FwOOsXKmz#imiVOy2`VzUO#Hu(FF4~0oSEv;_!HEa7kxOJ?VYC;)OhBuWFFNMc1C_XVFr+x}*NFdB9f!+B;*&yXSSvB=T2>5zGkl()&2s=X8sp3_~`Puds=@)FR!HXf8>ah)Pf5IROaW;~lF;8Gk%WV%FN3Xklrf$d3kj=V}9aR_8OdCd`0=WeWO<=@^OchQuI!Mt+ye<SN@qOPqL{nsmznA>GCcTuhWlA|*xJ(yC?xhRR__cYA&Yhpdmf*iV34M#<VJzR|3h}hNAQIZU&gy5^NRf{&pmMPkTY!3*`yLox<xlnm?dlsT>;!s*ky^t4A3N~3GpNsX;pwYrC%a|uYD>+^oTJhKW;Hm)8hD?4#A{YRMam>Cy)3o%>(hzc!<%7hJI3396#m{dFgMbSX6@QVvAHToVCaWEg(9JiLpl3b`lJZSVTInzt3dS!H-T-bt`ZX^Q%MO88AA2-f8AhS$s0a~(Hea7Z?6HpyeQRo$I;iP#vc5PZgYxB#gjndXa(l<=G+r}RrhR}&I0Y!-TAv7Ft=)E^>Z}{uBON!!XbLR{QPC;(WL=`6c}ELsU74^;>B-41dsspS3|;}sjhi?F!Sg3Hc0-6Q71Ycm>CJf+_xjlSFEghVSdip;gpr+SpWUsrB?f$)ir*94;IlD*q!qJpD%7p7rH+OyL9PR-ZqV_-hpQ^H&|Ij29?5go!`9KbKdAX7t~ipOxL)@%LZR2-RvhXozlwDtUIsuSchg<oeHdq*V^!9KM$?@1u@%u31$*l8ADRvk7(GD5cHR3g9?2k@d_F}MpI1;-LH9DPDDpo7_T%@z9Ehj{o~cg4<2X03#Ut)*~lq{Imd$}u?Rn@EDz5w23((0ENbN9-37XBa#sp}VWZe(q?*ltlqQ4Mh+wo-HSB}Jq_hKAB3x$u!7HacvXp~54M0UKosDfc)zwcsqQ(`R%KZrZR^&aT69D|i@aqks2|C6i<Ef<i=NiE|MhK1;ak`<ps3@xRjPPSoXmi9pzz^e~X%#KAWCnbpNV!m=>JSqH>hWY{99cul^kzt|h&7>L90XO*6{&htN$+efznrf_G}4@h!OYHx`Cuf*7+kF?f0dcJ!osPBJ)ZRea%=&AvOq@!2ER78Vzz-WwUu$Gt&EnrmBSRHz%&!bYD!Kh;##!V>skfi5;!U;FnppMx%>6_A(0GNgCjic>n;INCmuJXbv1(Pu<>oiM<Z2_NMM{pr7MLfq*x|(%?*N>3OtZc+X5qUfhqHy)y57j)f3n_-}8*3_xMZf+W!W0qcAYjdgNwwxQR^%(}_H`MZ564Z2y)<@h%I>Y)aGdGf+jl1BF%}k@BfAaIrS$x`@d={?mOiI``_(qOR+h36@xlJQF#pfc}<<&~iR0$+9*av|{u%gmL0E#+dq@inC$>WA<7~;X?-+q_<0aD{bt<XEF#1K%GWF9RtvsP}KY18gkk|la;wqFUF``jM$|%<U^pgJh4tEJ}r5~NgSx+7<;u=>Bn(<Ya+b0n$>f?M*M3&o&|G%h#XE!RnIbW7?@$HGNDe-GVnEyi(<DhQBcnk$ry~!55Xu88H7l{V0?}^x5#iN4&nAJGyj57SRM%OS#^$=VZGYHy4u+CX&n`^D^K|7q^s3QGK`G~Cc}r#QNfkcv*)6N1@X|uJETKCc)tjpWjp)Z`41KY5-HOYJ{^l$U@m`rYw-yiaV5CMf9s-zf0Ghr00Z4P<G{m4;&U(Z)aSvu-8nr!yLj`qc1~X$RvD5LkxRZiJZLE9M|VJgVm23fE6l7Yo=AsMuLnx*B$*G<pd?J%_31st0Db({ZLe>3I8P>`D?s|?q@gK!Fha;l^x9*E{dRlpkOcAPFiYaOIJH<KBj>QB$tF_Yc>GGv)&>zwnQE{~oO(l9ZaA!!OGD%#EcogCVq;0r`|rbI$O&$6LJ8tG*IAjN=UPe$Bas6CFa;#P(=%QWB@<`{O`0`{7}(k}?ys$#6MHtJfp+3voJ};(8gEQNpdCSGNJtnk1kK8ZEO)jR+F#-rTY0ewfEdrc!XI_octI4%7@DN$P8WAOsGcf$F>v&oaOD1-ii05F4e7%g0J-vFk;daMHAS;>ctlI#_DC7`D7TWWQYzUtLvRoTx!7IlTYo<9Fh&}&aSI0T<SyXDbRy|rd5~^TSM2}|ikW`Id#gKLY#VRDK6b6?u5_7u(onfks?=cRTKE0(^*z37I)NY$^o=5aOo}CL2hyl_ntC(>GT~9^DGaDc)z`DM<A9jV@UHwK`i4R-o%tjjy^~er!N=VvHJC~P7_6*v5m2GZ|04$;*PUAgRhxxD&$v5`U3$hTT;ZXq7JF%u2#E~(gy63L3*#h5KtGL%!vkv#W&`Wv9T=nyY&dbbg%FV$JSm;CJiphZ#K=R6BC+k7lqymiD$_&?$Y9{gy3gE`CoYe~gdzE2ZcUPa&s~?dE|LFCiu#@H<skAs`pz0Luj*t~<$iM|shSN+J`x@`Y!f<9JMi0dd=kQ1o|D6Cl04UOHPAwf5t@SxXeF=1y^GGGg0{Z}2IDMA%d?vB!zP~uxgwmhh<=Np1aY%QOIep3_1SvQUrWeSSKR(5t|LVBHeX06GRA<;g>22*opxd~mL$vjy1mA#TwlXlDtCGZb(K&rYpRNR4W$L@#jC2Jtl)Ulu+S3?GX=_x<OL=HCwh!P8sJZxI?CGx`H=Dr^R``Ioz+hs^6KTN6u+b{NWFJzSDZ6c$y^-Qmk&9HPFqY7_FBII9W7QCI_GKTpb^*FublP7TN`W2<18SLz?u}r{>W)G$}&=&^+uU)0(mgxQB^U>ChvVjyqauq>?P(Fvb9S#;APLUTkz*bH4940H~fP7KB(lPMmU-UpUgqv2g5SCQnQv?=1%y(Ru3(^xWQLl)A)KOpF!0%(ypTGX)o^A%cmv@uUn>rO0rvZOgnin^;N{JQ74tbYxQi3Ro@yZNdjejGg$S;`a$d_1y53{^v%i28wwAVudb$8R%%r<-)Jeo<fX<cpicUzR1qyp2P|CAayX{r#uNyw9`*ipx$F!++<N}ij8QFpQB&qLOk1VV0@Y>pON%|^KKH5#-JY4?2EQ^0&_eX)27Cla4TZ{Gw2d{bDuN~$;0^2wkZY~$HYMYFo)tEM-p&pu4wjklbTOhp(LIm~u9+@ey}zl>hJn1gO>d%>SE~FZXTS!C>(^eHt8PtO`igoJ%6o6=!RQ+)n((%vGyOg_GAIpr3@;UT3Xqu&Gnd6L%Q9@!^cVzr)n_2;q50jx!<)i`Kmn+2S2Y6bDCUUS_O6~vK79bz^`tKW8zXop&a?3He=dRm@ZlZilGy$ur(;!O8=VW-y_=qEwbe?&qu??jdWMnCrf4{~%T7AA0!vY#V}1g)7q`X}%uCl``nTF%8w`KSufs^r{Jyx$4aLZ3{KcwQ#elCYO^laoP6K0ssxC|GoFEcX+v{TDcQEP?@ZZDkb^}`4uKLs<HEy80M#_ZpP7N<24dY?Gg0}aM2!+nEYs_F;>C|lnJ-n)_)mgXJ&rC|LBkb|k*t8E!Y(y8oNbBSjSfuPex!w6w3zJ>vmM$(SQ5zjY=fvLAFv|;*NA~}}@^`SBvEZcA=JJ*Y;+DVsMT)ecDm)2EOH9|ZYGPSrZso1L#zonMHNaV|z1~vcDDDm3>@c`GyEr?&KL7aPO3O$~=g<Kn?sJ1U#QU;FczIV))GpRk*Gy})dH$;D${lA08Z$q)o+=Pmyp~yi3W5|+EFLg^<$z)-J6*Pg^u$vYZ?jx77diQyax*+sD&wj-Q{w6LY*5TM3;?F)8W+z7M${+zbXOw>E;iDM%R>|;$vxiywOg;dt1FD`com`7?M`pp-Y>6#mtNT*<IE<YC-@k0v8q7TclVXr#Zf=9r-ECxcAZTW(!rS5%j#d`M)sGapNx1dSGV(bR=ya|FiTn!HEYycPaIt>MEZQy|Ce_MrwZ+xV3J>SQow*d>5Z;#cf7`a;oTd2Q=3kS;1Mj=i0+r5`$|-RVRLsecYT0~e=&HgcYB*t=6b#TFWOs}zWLT2yyU})<nTlaiED!7)!s4Xc*73k&41SK7-pgFH(Cm`@T*jLeM=@EPWaS@s6gD0b21KeDfVUPwTL;_dpXWqQV@jl8-@D$JGwQoXFaLztg5(fpb^jqW$%|{2EPAlYks)h5mDO##=n=uNaAs@p(BVj1@Re7ZJst6$^+z8amYe;qa-ZrvmE>l6f)M%Mqx*1FwtT!@Vd{OE-2j4XYI%)qqa7FlS;DWR+m(8s_h2)=l;^-#ip2rxky)`79CeDMNMB<|B5vrPeId~hGTK&bMq=NA;m*Dm`R9$ikkV6Rp6b#o8(2wYq~4tMrWvje&&%5ly457!z;(k+=?~dH3sMz-lC>pJK<avuJLDW5Ln>(T+^1NrIMlL<1wSrgy%`>+U#yJV#4IbePWk5H=<UORNVYR1#YVMyu^OQ_W*HXNKNZD-5>;bU`C5*UR>U8l(=aaNsx*tjc~s}_{oqjP=e*b7JKF8H3?dLIIdx7M3GK((VZ$|xCN=iTpk?F?6TO624LWrdG$90ZGU~!Zk_n8>EP*b#o?K%iS1*yORV^4F$OEBch!5I1(DQuSMNG`Oyy>e4uel61QBIPFMBOyHGQbsHkzQO?{$T~)}vi+p`xch(cPRqtBa_fa{QM?S82l2N(L*;!#o!$UGIY>F%$lUv6Odvipx5wCY@Tq??M5ghRYpu0qnVx0*EZgTUpwo!xy@mBEC3k>mH<D1BL>Ufl(vYC58lQ8~jkqm1+!UXl%ffph+yv%*)!fw}4$w-117Wu^R*DSyHcz<jS_Xgx1y2b=D_ZHu`koTBm#p@V&CQ#o<64R6S*~#)=rhFYjTcMLD+}XZwcGg2(eVzXn<2SxPs?OwMX1;3`>ljA++V3eh8Pq;%D7EqI|V>HW<Y<7!vBn4(YnU^wkjgn)@I{I4(avxtR6#g$0AR4p*({Fd*Z390af9Z|02<5?1-(Iu}@rJjUzVIr>%WjoZDN<w|LM2Plp%4KCxz1_05#`NVoef8Egh!Uv2Kn^rNh`1D7UJ2HJb}4JXQ-WHuE8sb=RuhP|E-ZsHw(w!SdH2UZUtRxn_Tl=aPOQxyA#H9LE+GTIt$addjV+x*Q?plfClGZJLE(kI+0s}d3v}rgP0JjAdB!N=LZ)Me-~ApR#@g;keOzEI^>EN}+nr|&aZyFAH^hruTHjRG`I6l*tZji9UerKOTN&A0^reQjXzF*E*lW9_+1Q)A0gGiaAK{_H5Q>+#Ef)zNKE#FPc^jMCFjPH1#~5>AU)Q*qzdysxI*{LCWUnO>3Jgge#mn623yf}2p>Ong!@)@^O+ha{A7|ah`1T7iHhiNe+uO@zfoB!b1uRTkkY~6(-*}m!1ho`)I)S6y+rQOJe;Hww(as%r8_o4nghaU86X3a4>=@baz>{Sx<knWa$U;P7<A#ya)?9TXdTkxmgtDQNstdsJItj5#<1O(8OnMAXDos9h`*msam0*NMT9UX)3H`!M4zh__sLQ3A@+vepu)<Bl-i%lBX}4#c-hyYmJH7T^J#q;PB7~BF)$ek->j^1YKPO1U#R7uNwSza)f*lAvShZt4LIU+9KWc7{DhXul77w!XyvC-2qo{g?8LLVmBN{8d`XbuhHf|83wU>B1gci#6IgH0tOkESUG!iyDOV&bl)qL9`K4@*|O1B=ea^mXO-BXlF_W<mpu6OKI!bgM?OXPdhLP%Vza?8DohUi<tov60FVMcT|gp|-M;&UxuFs!5_qDn-LybWO`l}Hkiu8&>0hW;#&+%k?tz-e=|Q0K+bBW$<6AYephWTb8*1-h<0q|y|ALH9(jiM{xLKU#v0SjeNp+n<cv&YqVW_=YuK$|Bc#S~=3j7XpcbBNU;vDS_F3Hk*+o2(`Q!pan@3!~##9MLWN|&bLgd@jo9ejY(<PVfeHv1q~obJ8pkD$5Ye8>%V_GyV5#74`Vz)fmgZuF>zd&Jpe6+@L`DWY$>G>kj6rywHpEV;?3K$i>n(fG#E53@1mhHfL^t{UyrrNhP9ILs~SJAZtKc}cw9L=E}h1=J8=NhAumc$>@1^fdi&(GqVW15UWf?&J+2k(P{CC#C=O>o7ome-0u7icLmEd#G<}pj%4A&07RT2YS2sGe^Xv^r+}y4AMDoQQMso!qM?;vGYX9Rd0|k1?zvYamLmfphnphk-62u5*FjLd#`@VJh@#5p<+l%uL?}pd!FVC*<AiM!Yun0mBj}52fhmv^WHYs{Gw_ln>q^46y0mh`P>I3+$lut4{z$Al()f7;3P{i=AEu~oe@Aowd5hSA&O38!0r(1$$hb-!lYNaA7O_fd8>{M#ZX;GCM$^lN-qLbE<;=yV^7C*8iUc}>2^p9R8d077PM?lDRW@C|{m&&EQ41_sNMhd^k&FezNE&|<5%_CI3OB4Z+>mCD<MH%|7_3lRYLoXzE=0yh^rkZ1dP;^tdzbj27Do$Ri*}Uz!wT>+ziK&W^nkH)lT4J^i_!8tT=c~3|C>JB?KWm_N1B*)jlcm`m2^vGRFtg&Y*`hd9qOO)eeeAT?H48${b^=hjGnP0>&2_PEZc;{GG{<H1Wp$3PkIEFY36B)M{8UJ}SI-WL{)Sy^i2_CFuP;WJ2$If%#~NVXJa`^*LpdF^Jkuw^Q-r?+<RBn?K{eK;ltPD;A4Ql90RD_4yuz1Gs;UEUWg6S^jb9{DA4A`rXRHFmoWLn4%KQ>&y4)j`V}SI8-_s@8BY%{up2)L(R!i%Qd`WS$*qP0Jd3jf!U#m!yE>pS&%{w~PO{Yc?*QAe^st=e#Lvj#RkFqGwM*}R~D?;#k4SOA`&`s(085oNS^^8CYPcw#S>eZw-Xiz(^qv0*RGSl5By{<TFrz{1sdd*|!yVYZGU@?ZVo|-(I8u*}LNz+h^Z)ox%R(fCE5yTXRYpQAcyF?x7+SI&~ruUgER_G?2WWR@O47Wlx2B4G8K+^Pj(Q1i8*W?`|4oH*H44V@kGE`(_lcgD?I2=WJ0<qv=O%j8bnx|q7Gvl4Ka4jKw%qT8;<u+GQ0v@ZVA8QI5BAeRKU#zL5%S6h+qy4Vrcw*`fx!+}tlI&$FhlZMhY04Vng=uZzavyT)w(8nRS(ep;N4Itw9bPN34Y7|enlPphC5M{Gfw0?I{VysCm7M"
MODULE_SOURCES = json.loads(zlib.decompress(
    base64.b85decode(PACKED_MODULE_SOURCES)).decode("utf-8"))
for module_name in ("colorlib", "adjust_colors", "notebook_workflow"):
    module = types.ModuleType(module_name)
    module.__file__ = f"{module_name}.py"
    sys.modules[module_name] = module
    exec(compile(MODULE_SOURCES[module_name], module.__file__, "exec"),
         module.__dict__)

from notebook_workflow import *

PALETTE_SLUG = palette_slug(PALETTE_SLUG)
if IN_COLAB:
    WORK_DIR = Path("/content/rang-workflow") / PALETTE_SLUG
else:
    WORK_DIR = Path.cwd() / "cache" / "notebook-upload" / PALETTE_SLUG
WORK_DIR.mkdir(parents=True, exist_ok=True)
RECIPE_PATH = WORK_DIR / f"{PALETTE_SLUG}-recipe.json"
use_arial()

def receive_source(local_path):
    if IN_COLAB:
        print("Choose the artwork image from your computer")
        uploaded = files.upload()
        if len(uploaded) != 1:
            raise ValueError("Upload exactly one image")
        filename, data = next(iter(uploaded.items()))
        original_name = Path(filename).name
        suffix = Path(original_name).suffix.lower()
        if not suffix:
            raise ValueError("The uploaded image needs a filename extension")
        output = WORK_DIR / f"source{suffix}"
        output.write_bytes(data)
        return output, original_name
    if not local_path:
        raise ValueError("Enter a local path for the artwork image")
    path = Path(local_path).expanduser().resolve()
    if not path.exists():
        raise FileNotFoundError(path)
    if not path.suffix:
        raise ValueError("The source image needs a filename extension")
    output = WORK_DIR / f"source{path.suffix.lower()}"
    if path != output.resolve():
        output.write_bytes(path.read_bytes())
    return output, path.name

def make_final_zip():
    archive = WORK_DIR / f"{PALETTE_SLUG}-workflow.zip"
    return make_workflow_archive(RECIPE_PATH, WORK_DIR, archive)

def offer_download(path):
    print("Saved:", path)
    if IN_COLAB:
        files.download(str(path))

print("Working folder:", WORK_DIR)

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 01. Upload the image and define regions
#
# Upload one artwork image and draw the regions that matter to you.
#
# </div>

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#fff3cd;padding:14px"><strong>YOUR INPUT</strong><br>Upload the artwork. Also enter its name and object page.</div>

# %%
PALETTE_NAME = "Your palette name" #@param {type:"string"}
LOCAL_IMAGE_PATH = "" #@param {type:"string"}
SOURCE_REFERENCE = "PASTE THE OBJECT PAGE URL HERE" #@param {type:"string"}

source_path, original_filename = receive_source(LOCAL_IMAGE_PATH)
source_image = open_rgb(source_path)
print("Image size:", source_image.size)

# %% [markdown]
# Drag boxes directly over the image in Colab. Each box gets an ID, name, k
# value, and note. Use Undo or Delete when a box does not feel right, then click
# **Use these regions**. The drawer converts each box to original image pixels.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>YOUR DECISION</strong><br>Draw the sampling regions. The Kashan example can use its saved boxes for an exact replay.</div>

# %%
DRAW_REGIONS_INTERACTIVELY = True #@param {type:"boolean"}
START_WITH_TEMPLATE_BOXES = False #@param {type:"boolean"}

REGION_TEMPLATE = [
    {"id": "main-detail", "label": "Main detail", "box": [100, 100, 600, 600], "k": 8,
     "note": "Say why this part of the artwork matters"},
]

if DRAW_REGIONS_INTERACTIVELY:
    if not IN_COLAB:
        raise RuntimeError(
            "Use the interactive drawer in Colab or edit REGION_TEMPLATE locally"
        )
    starting_regions = REGION_TEMPLATE if START_WITH_TEMPLATE_BOXES else []
    region_drawer = globals()["draw_regions_interactively"]
    REGIONS = region_drawer(source_path, starting_regions)
else:
    REGIONS = REGION_TEMPLATE
    source_figure = show_source(source_path, PALETTE_NAME)

print(f"{len(REGIONS)} regions ready")
for number, region in enumerate(REGIONS, start=1):
    print(f'{number}. {region["label"]}, k={region["k"]}')

# %%
recipe = create_recipe(
    PALETTE_NAME, source_path.name, source_path, REGIONS, RECIPE_PATH
)
recipe["source"]["reference"] = SOURCE_REFERENCE
recipe["source"]["original_filename"] = original_filename
write_json(RECIPE_PATH, recipe)
overlay_path = WORK_DIR / "regions.png"
overlay_figure = region_overlay(RECIPE_PATH, WORK_DIR, overlay_path)
print("Saved recipe:", RECIPE_PATH)
print("Saved region overlay:", overlay_path)

# %% [markdown]
# Look at the overlay before moving on. If a box includes a frame, caption,
# glare, or unwanted background, redraw it and rerun the recipe cell.

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 02. Extract colors with k-means
#
# Run k-means in CIELAB within every saved region.
#
# </div>

# %% [markdown]
# The candidate sheet orders clusters by their pixel share within each region.
# The rows are evidence for your decision, not a finished palette.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>YOUR DECISION</strong><br>Choose whether this extraction should become the accepted candidate snapshot.</div>

# %%
ACCEPT_THIS_RUN = True #@param {type:"boolean"}

candidates = save_candidates(RECIPE_PATH, WORK_DIR, accept=ACCEPT_THIS_RUN)
recipe = read_json(RECIPE_PATH)
print(f"Extracted {len(candidates)} candidates")
for candidate in candidates:
    print(candidate["id"], candidate["hex"], f'{candidate["share"]:.1f}%')

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 03. Curate the palette
#
# Choose five to twelve candidates and arrange the ramp yourself.
#
# </div>

# %%
candidates = recipe.get("accepted_candidates", [])
if not candidates:
    raise ValueError("Accept the extraction in step 02 first")
candidate_figure = candidate_sheet(candidates, WORK_DIR / "candidates.png")

# %% [markdown]
# The small cell below lists the exact region IDs and candidate numbers available
# in this run. The region ID comes from the name saved in step 01. The candidate
# number, such as `c04`, appears below its color in the candidate sheet.
#
# A complete candidate ID joins those two parts with a colon and no space. For
# example:
#
# ```python
# {"candidate": "region-01:c04", "note": "deep blue in the central tiles"}
# ```
#
# Copy the region ID and candidate number exactly. The note should say where the
# color appears in the artwork. The order of the rows becomes the palette order.
# You can choose more than one candidate from a region, but do not repeat the
# same candidate ID.

# %%
for region in recipe["regions"]:
    region_candidates = [
        item for item in candidates if item["region"] == region["id"]
    ]
    numbers = ", ".join(item["id"].split(":")[1]
                        for item in region_candidates)
    print(f'{region["id"]} ({region["label"]}): {numbers}')

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>YOUR DECISION</strong><br>Fill in the list with candidate IDs from above. Write where each color appears and arrange the rows in your preferred ramp order.</div>

# %%
# Copy candidate IDs from the list above. Keep 5 to 12 rows.
# The row order becomes the continuous palette order.
SELECTIONS = [
    {"candidate": "PASTE_ID_HERE", "note": "say where this color appears"},
    {"candidate": "PASTE_ID_HERE", "note": "say where this color appears"},
    {"candidate": "PASTE_ID_HERE", "note": "say where this color appears"},
    {"candidate": "PASTE_ID_HERE", "note": "say where this color appears"},
    {"candidate": "PASTE_ID_HERE", "note": "say where this color appears"},
]

# %%
recipe = save_curation(RECIPE_PATH, SELECTIONS)
colors = recipe["expected"]["colors"]
curated_figure = before_after_sheet(colors, colors)
for item in recipe["curation"]["colors"]:
    print(item["id"], item["from"], item["current"], item["note"])

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 04. Adjust colors
#
# Make deliberate LCh changes and record every reason.
#
# </div>

# %% [markdown]
# Each selected color receives a palette ID in step 03. `p01` is the first row
# in `SELECTIONS`, `p02` is the second row, and the numbering continues in that
# order.
#
# - `L` changes lightness. Positive values make the color lighter and negative
#   values make it darker.
# - `C` changes chroma, or color intensity. Positive values make it more vivid
#   and negative values make it more muted.
# - `H` rotates the hue in degrees. Positive and negative values move around the
#   color wheel in opposite directions.
#
# To change several palette colors, add one dictionary for each target inside
# the list:
#
# ```python
# ADJUSTMENTS = [
#     {"target": "p01", "delta": {"L": 8, "C": 4, "H": 0},
#      "reason": "lightened the blue to match the central tiles"},
#     {"target": "p02", "delta": {"L": 0, "C": -6, "H": 3},
#      "reason": "softened the green found in the border"},
# ]
# ```
#
# Every row needs `L`, `C`, and `H`, even when one of them is zero. Include only
# colors that need a change. Use `ADJUSTMENTS = []` when the sampled colors
# already feel right.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>YOUR DECISION</strong><br>Add only the adjustments that improve the palette.</div>

# %%
REPLACE_SAVED_ADJUSTMENTS = True #@param {type:"boolean"}

ADJUSTMENTS = [
    # Example:
    # {"target": "p01", "delta": {"L": 2, "C": 0, "H": 0},
    #  "reason": "say what changed and where you see it in the artwork"},
]

# %%
adjusted = apply_adjustments(
    RECIPE_PATH, ADJUSTMENTS, WORK_DIR / "adjustments.png",
    reset=REPLACE_SAVED_ADJUSTMENTS
)
for item in adjusted["curation"]["colors"]:
    print(item["id"], item["source_hex"], "to", item["current"])

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 05. Check the palette
#
# Review source distance, color separation, and pick order.
#
# </div>

# %%
report = check_recipe(
    RECIPE_PATH, WORK_DIR, WORK_DIR / "check-report.json"
)
print(report["palette"], *report["colors"])
print("Suggested pick order:", report["suggested_pick_order"])
print("Color vision flag:", report["colorblind"])
print()
for view, values in report["viewing"].items():
    print(f'{view:14s} min={values["minimum"]:.1f} mean={values["mean"]:.1f}')
print()
for color, values in report["source_presence"].items():
    marker = "check" if values["nearest"] > 3 else ""
    print(color, f'nearest={values["nearest"]:.1f}',
          f'share within 8={values["share_within_8"]:.2f}%', marker)

# %% [markdown]
# ### How to read the report
#
# - **Minimum** is the distance between the closest pair of palette colors for
#   each viewing condition. A larger number means the closest pair is easier to
#   tell apart. Rang uses 8 as a practical separation check.
# - **Mean** describes the average separation across all pairs. It can look good
#   even when one pair is too close, so read it together with the minimum.
# - **Color vision flag** is `True` when every pair stays at or above 8 under
#   normal vision and the three simulated color vision conditions. `False`
#   points to a pair worth reviewing. It does not automatically reject a
#   palette.
# - **Nearest** is the CIEDE2000 distance from a palette color to the closest
#   sampled point in the artwork. A value of 3 or less is a close match. A value
#   above 3 asks you to check the color and explain any deliberate adjustment.
# - **Share within 8** is the percentage of sampled artwork points reasonably
#   close to that color. A small share can be valid when the color comes from a
#   tiny but important detail.
# - **Suggested pick order** says which colors enter first when someone requests
#   fewer colors. The numbers line up with `p01`, `p02`, and the remaining
#   palette positions. It does not rearrange the continuous ramp you created.
#
# The numbers help find possible problems. They cannot judge balance, mood, or
# the character of the artwork. Compare the palette with the source and trust
# your eyes. Return to step 03 to change the selection or order. Return to step
# 04 to make a careful color adjustment.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>YOUR DECISION</strong><br>Judge the report and the palette together. Continue when the colors feel true to the artwork and work well in a visualization.</div>

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 06. Prepare the palette files
#
# Enter the source record and create the palette JSON.
#
# </div>

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#fff3cd;padding:14px"><strong>YOUR INPUT</strong><br>Enter the artwork metadata exactly as the source page gives it. Check the rights fields carefully.</div>

# %%
PALETTE_METADATA = {
    "name": "YourPalette",
    "persian": "نام فارسی",
    "pronunciation": "how to say it",
    "about": "A short, personal description of the palette",
    "source": {
        "title": "Artwork title",
        "artist": "Artist when known",
        "date": "Date",
        "geography": "Place",
        "medium": "Materials",
        "museum": "Museum or collection",
        "accession": "Accession number",
        "credit": "Credit line",
        "url": "OBJECT PAGE URL",
        "image": "SOURCE IMAGE URL",
        "public_domain": None
    }
}

# %%
draft_path = WORK_DIR / f"{PALETTE_SLUG}-palette.json"
draft = palette_draft(RECIPE_PATH, PALETTE_METADATA, draft_path)
print("Palette JSON:", draft_path)
print("Final colors:", *draft["colors"])

# %% [markdown]
# The final ZIP contains the source image, recipe, working figures, report, and
# palette JSON. Notebook 2 reads this ZIP, validates the source fields, and
# places the accepted files in their expected repository paths. It also creates
# documentation images and palette-specific software files for review.

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 07. Replay, verify, and download
#
# Reproduce the accepted extraction and adjustments before saving.
#
# </div>

# %%
result = verify_recipe(RECIPE_PATH, WORK_DIR)
for key, value in result.items():
    print(f"{key}: {value}")
if not result["verified"]:
    raise ValueError("The saved workflow did not reproduce exactly")
print("The recipe reproduced the accepted candidates and final colors.")

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>SAVE YOUR WORK</strong><br>Download the complete workflow ZIP. This is the only ZIP download in the notebook.</div>

# %%
workflow_zip = make_final_zip()
if DOWNLOAD_FINAL_ZIP:
    offer_download(workflow_zip)
else:
    print("Workflow ZIP:", workflow_zip)

# %% [markdown]
# Continue with [notebook 2, the Rang submission builder](https://github.com/mohsennasab/Rang/blob/main/tools/notebooks/rang_submission_builder.ipynb).
# Upload the workflow ZIP there without changing any files inside it.
