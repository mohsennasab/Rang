# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohsennasab/Rang/blob/main/tools/notebooks/rang_submission_builder.ipynb)
#
# <div style="font-family:Arial,sans-serif">
#
# # Rang submission builder
#
# This is notebook 2. Upload the verified workflow ZIP from notebook 1. This
# notebook checks the saved work, creates repository-ready files, prepares
# palette-specific files for software testing, and downloads one submission ZIP.
#
# Created by **Mohsen Tahmasebi Nasab, PhD**<br>
# [hydromohsen.com](https://hydromohsen.com)
#
# Copyright and license holder: Mohsen Tahmasebi Nasab. Notebook code is
# licensed under the repository's MIT License. Rang palette data follows the
# CC0 dedication described in the licensing guide. Source images keep their own
# rights and reuse terms.
#
# </div>

# %% [markdown]
# ### Contents
#
# 01. Upload the verified workflow ZIP
# 02. Review and validate the saved work
# 03. Describe the proposal and confirm the source rights
# 04. Build the submission package
# 05. Review the generated files and images
# 06. Download the submission ZIP

# %%
#@title Set up this notebook
import base64
import json
import shutil
import subprocess
import sys
import types
import zlib
from pathlib import Path

IN_COLAB = False
try:
    from google.colab import files
    IN_COLAB = True
except ImportError:
    pass

try:
    import matplotlib
    import numpy
    import PIL
    import sklearn
except ImportError:
    subprocess.run([
        sys.executable, "-m", "pip", "install", "-q",
        "numpy", "pillow", "scikit-learn", "matplotlib"
    ], check=True)

PACKED_MODULE_SOURCES = "c-rK>>vrSDvL^T{*yZjP=%QF8buHQQX_ZQL>1@@dCE4D4OKNVA1VvaRzzu*U(Q3_F^JC`Myhs0@H7|2|&C5)D5t)fh0Hj#9&zaLRzKA4{m&nM-$cV^@$j29hWRj$lsQ==?dvVSGUW|h@9D4l1n+EyV8_}119D3(LeCy>&GRa!k@pXKhd=Ash%g%pzLr=Zq)04BKH(n4Ay|d#n)sOKyO5&`k8v7jKr#B2o(I5)r!NSX;>3kC8^z=FoMtPWe?}NcO7$#nrd%>jT`Q3K=b)(7MQwMKP=yzK+H;hK3Fr{|FCijXmvtSbDd3YU9!q4Hv8;6q_VC>JMN$yeKc{1~o5sFS*-lusQdhvWZTQt2a;rjREWD@ci35+QA(s`U+$M;b_PUZxW>N#WZLmJ5}jE5Kr5F+@Cqv<S3b1$ONFs{s#Uos3+{g@GA3GL>08k(>3bV6@hY50$MnB~_+9R}44GB2Lt>G{d0kG=DcA1}Q_-CXMvefquLD4K-5UW3}mlF8@LZ?tAKsd278uH#QfXD64JC%w0)=Ty6B>6Lf=Lg6sOV2+QD-_@5I&_snOavgu=eM*yG!a+`mNy9LXKqh1An~*tV>X}9~hWV7hjMDokv*&V72ux|NCsc5rqOs3Wc#kFu;>cRwk5nnjF?dYEl*SPeI+-wHk02S`@%)Xbqijs%JBn^;c4=CUKc0O&e{**F;cf5o-TBGIyN_pYX)yb(wt&9*JO2^-XQ~hSX!3pUFMs_T^$^cmL7D~&|LUsU+U|6>cXqd%Uc0rmv$wOi+rih)etUasZ|A0Y9eb63s8+Yr-QDZHM$x^_PG_gv#n<*;x3jm?URtZ&dA+r@#kD$}*PYkhHom^zX>YZ+J2y9t>-gt)r<W%Vi2QzgujzGKZT_>rzrTf|_?H$et)z!up7he&zCUgpNY7(xV%(Z!c^b|9>la^Lzi7ydG|cB|Y&9Rnxj(*&4kGWR*S(<*b{k9=kw<IHryglw+YNd#nj}GPbxZxBTk74Xue#&3>D@NHzKkGEh=hFlGMEq;REkDR4esnT8m%D97qif(?p?@61npyb(C$7wJ>JSkpFf14ogoK+fd>#i43Z(3&15zX4$*^xN0$C2(O(wb#zcKvU9V5ndIZv-s^Kk>c<aN-r8mz)VuwV<BS4MOx6&Y+1~U&!R`@Df{CQ0L!vo*(Msr#l+@%*~-X;;w418-5PA17cKkDx6Hi>gZgE9CuErtwhK^i&+!=go#(<Jrh)aLoo1u@wfu|@AbrA{&caWPLv!65uTqOQV8I3*qdSc<X9_h>}@MRAq~#Ql7RiKc;=T*ITujFY_PHE^%rw!Lo;)lldQA@HCe;WPkW_$ipo!;>^kQX(iRIh|*@*AHol8B~taWJ-<ErbBHMRA;CH6YhT&68ntt+0-ku*ie-|qeE0tV14U#w;SGn^ZXRwL8tWn7T@>rweOITRNnNu-q&Aa&Iv#A=(|JptV8IeVe!*~vNA>1lPC^@)E{U%8mKjy$+8*f^*{`l1`3YluCDtr?SK9N$fRYz-QM1zt(FRRx~<o=qI`Pw5^so7@l?JLSl!mPwZ;Srzyr7{(D1UVgNoN#r?DES_Eu-Bz26j&ysy1MQ{cc?fZ}&BID&`Js385CXSK`%CPCk30S}8`3A_>_@!tE-9&_Lpwkc+GQeh;c5$I6+I|grmABzXW?58=N)3Ekhd;5C?21>mo8UXHy63PQ5Iv?EmSM-X?j;>m*7LDzO#?jfWWzF=@4sCceW>vV2!lq(lS*5O1sbf{@-hgLrcI?Rv`kK<|tHu_6bxDgJ6wH><v%n&t#|E^QO#M7`Rpf!H0P9rtrDuu~K(8>cCZ2B=&%1a|usi5iIOC=kXimdl%&D2A5w9R;p5zfx_K4A}CWbzE%0N2SjH{U{kvBT|&*+4n2b0@Y6o2-aU>dE<DjrD;wDEXGyxVL%OL1A*{?3@f#*0~!`>5aG-^1{hq@|44RyrW2+4ZTRpwaODqqnu&ws&6wL$3k)YC&_{<XzZ?W-xvpnq$HgXg=ZI(_k0{aYh?^!@MFsUV5eB`67`?%lw5b=lNR1XVD(*U68C!ThRiX0XtY44QN}UJ!%q#yhq9u(#P#M_h?TQ_2Z|vz4u3#=cj)m1U%}^YL+I1$!k()9Qg~f)BdjTp6<>*k<ccISMBZn-Tj+o>rSMpPG_4WCl<l>cf0#6x3yot?sj%pR@`LXx4+-zo~R=tRO!C+`t|;eS?$*^hT*&p;;r4iEs^*3ciX$$y8>}{@Ab0~clT+z?4TwIk2`IFczbWVv-K>*ozA{Ui|y_1>ur%6cS#iN*Z|Y~Q~~a^h-vS1_hq<yyL;QO`D=&P<=*ROJKo#h?l7RQX}4&L?7F?T+wMLy);0}ni)Ux|b%#*K0(N`rb-OJPKY>zyI=wjk_@Q_C*H0%G;Bp_5n54LZR+`o<G_3(POjS~BPtH*H5p@r!Oq`_CV4}!dsuiTCzbCUOpm#MRu%}(Vhp8#=;8=f`cTbiOAxkP0k@qf&hpsq!q2808JQ$O}M5}M0;B9g7LySeShYZ^+>0-1p<J)l9DoK4P4pEawZ^>*0Yf;>XVX5IhB_>?IZx<{23LV}UhWz`rG_WG0b7~Bd7C#K}04$uSkN$QIZ>8S>{on7<tmCzMOe->=|NC8e+*MLGl|1eWBUWsl>o#o0&(#!Kj#*4S?$Abh+-3Prp8w!MYJzk`g3%^3;(w4_Ld9w0+oN*kD=AVt{H>uy*`PB6a5J=whJV0*2so@?2HqI}p1BausvyrSn8zJezHZ}Ubj|eMr7Cn+RA5AwDh$u4zu_@zopovWXB~lZ695}xr0+BohMtgRk>hYYWAv%k!U+`)`m}j*69j$(LMbWTl{%(`Rnt5p31np*`fEl2X@5n@m)2O{;Z;}dwmivtT#ec-nA&1OQL}N@#}xK?w$CuZXF^9!j~jX^4H?2(g|{)cBJdHcW$f_?$K5*YNlo8WwK^0W>KER(82O5tf*Pm3gUL$y%~JVGA$w>MoxOVTrq8w7M03!Jy4$s-Fe6k_FDm{A#kab(#kZt571?cw4%2Pd7Ti_^H@)30vt)-kq_-_qBYc?oo4&6A?e6V};wLJbu5vyolMR(Fn8U2X9i-aDgsOo|d~EZ~V9vOkowjP9>gy(H2rnz|RXYRK4rBy0LtUyj<Kj(6y`jIC3hbQTZdR!pBOxp_K=bDV*GPkH#MdzS#2g63i-~{(0KqBf$-sK@j-QO>$#Tho$`U|dJ55-%8-KvQqfODCSfXJ_*ZYpPg7&6S+?$3$45I|>LS|QXck=hjdI}>Wid)vxewg2fVa)bZu}!1#Oj%X2zbgS8cChlUJ_%LNw6eYKGq#wViU(Ql<@bs7L=t)m@!=oyC=G|k3L~nfrL-G4rH~dKV<KB=#>z?)W+b+WFr$}9M$KJ0TlH0R!<+ThFE`4J*z|ru1IFe~i*MQ|{f>>tehQh!$7rF-QTyG-jYDZP5B@M~Gz*gBS)oUk4t7sN&U=F(3l-8_X^W)6Ntoq@iF+7{A<PQ~X_95e#BI+==1hqN&2kcHT#;^$LEmA-wrE>{6^+!vDu&AVb`pAnNs?)(aWJB1Rvo8Upn9y7!v;Tw^)Plp@1v1JmJgM_4+tYMaoRvyRQ5+xitcu8Y7o>gJsh~aVn~23B{{b!ts@@1l8#~O9MW>aGn%P`Di2bq@`p_s1~)C=exYxU#vyXBD@ym(p^(fp1gqhqm!!1b>*o5+JetT{5<L#6iO`!xgFBBacv+s{tdH%?A*tn>X&E~-7b6HUJTyX_CRe6rVK<RCB7T#5VVvWj&Fx4U!{M490Uv4Ma3|KJruC0}Oq3{)2y7&5#5BR-EXQP~!F1+js835unWj$wah8WOFBlG`ZviSF6O_~7A(}?NiZR@rKozXhtj}CQXX<0EreQE#FseeDs9)wo(u!8DWFRIfV6zuT3|+y{n?l8H-#LI;P3VTTf*C&E9n`KG(E}TedhYO~rxa9!vHMsjjjA>W_T$igc6E27>7T!Awp-7Eco{NH9AXaqmCG>Z)rV<b98Q91e;9bP0|D=ABZCb<8bD%}q<J{>xpno9XmJuUcBK@yve+3E19BA==S{k2KF*L+i&*t>Q&f}(E#`GY9|J*C4y4h6>>LJ}+{Z6Pb4Jb+iY73Kca!8+ut<XCt|?%J@q8Mlm`JHi%O(%f{IFxsky($2T-9L={I1{(dKvbzc|QwtUr4(t#YoAk?g?g1PQ%>mFBEV~R$z7Cx*G7122C$T`Cp@%+b1Jj*7Z#RCeC!yS;7>oi<e+CaEZBKval=Bs+=Tz;2a8w)OE%-!legS@$y5f*gCKxO6sf@isIsM%9|xwlt-UKeMn^lBI+BR$Pm^Pvape4#9;=SqeWR&(n7;f<vP_hd?mdRx!o9c!*Z0xW(Gp811484uFAsGfr{P~RO&1nt2dO3AUX5;<2IlJb)ZZ5F@Gxx{{ntM%LQk1I6QLebnQ)?O6K(J7mM!axn7FykuWw*NdEE_hZZ;=Q7<6Xj~edwNi7w`H={KTa_*6o6-|TNP>WgoqX(~wChstZojsQ(-zE1VJjuSP{6eBU!>MH8WkiV+qRm-C!v*$0o@z#C<0Mba4vU4yy~!L8=L4!nZH!3L!fr@)_aW#n_+u75kYcRd9$+?Kcz^#p0Q~#kr8(7MMlXr7us&Mex!PhGQW~H@yODWVP2i8!O;K5tv{y|?aK|}-BpK1PES+Tr%vQT*^W(GHPp4;|a$-5fSex?kah4fU=6(Fx700E_qSMQzQ>=+8(T;AL6zXWy%ZYF^TAiWK&szymkzdSjqtOyqrJR~4zF{@h%E$9*KMtaa@9*P)i~cke=&kdR=a^)f*4fdA<G+2pSf&73=Fw=%J~<>ohdxg7w~UK|*i0K&2L~9Uvl1Vlij`Oh1@<xw(%Ue1J9Xp<Yi$i3siWBErH!UHdl0rTd*FkYpl{2&1kcqNdyjzY4_jE!4Wl^ukbL(WqCH{pbqHZgmf!EQ=@!~`5)5e$%t0Cb?5THt9861^^f^g&x@z|7TNL=N1;4D8cQhE#MwfXTe-3DV;*F-aaVOuf83gQ~!ERR0#xg7WUU8oe<Da#%`Dhe9fK^|=;NGrZShI&FY<H|z@J@Nm@>JStO_F;O?Hf<3W~pr=@hs1LM@E>jgyo^TCU;58)Yr08i|A|0Q;faW?zwe4N&2)1zE(XoY`T%P_&p)vLy~_F=M`C!1nY;y%myRrarQ*${7lOx=ug4}?@<BtWR?~cC+HaOn6S*BwIFZz^6(+|i61AJ(!=W)^L(_q4?rxPGF-6F5N*DM9d+;mKf|Cng^B0!AQG=aek8k$d?&1h>Z`D0YTm*f&N`?EB@_~zB?V5<@aJ%0Mo*&!yPZZ^7HKg=?bO`V#v}cG+9-<ymdruDT<PK5V7p0;WRiw0xc{(Mk53}S)zRkPZty4A{PpH*48y71Sj9XA)&mb^4GV>!F$iW+9!yA88hS?;$ET+-A2?!$(}^ZX?@x!IZK5Xq<jZ>JK`Ey_k_EVNE%1xDcc?nn^LMihgIaE!&{{CK+kvEM3mLFpch`YYOTmDW_J$mepgY);J6-YQ$!z2V@xm{|vw9Z4x@vE}4mL+eo8R9&?ml4}2d-72B$%y*S&;^m+pZByGh#f$=oV%h+W5r}$pRkuc^sH2E%p1vlWgJeOR+~F%;V@ER-e57%*?9QSWIjglU%@>Sir*1%8<Fs6db!cEvV?u44$;ae^CaH2N=Kfu^vV9h#X?Us*35)be1n*8KHTBza4{WWB>Yv=xi?(vtfZtF=|1OdVeFsg`z29c*m8WN$gz@SW!eRttCvS^IRM=SW@eN&I?P*fH-~bg3K@aB=`(nxNEtZUHC?+U278&*E7K8>71==qhOMSE=Zz#f!*5x`4wo2avGKuM+BOXYRBcYRJfO}Y^YKb;_h15&~?^PH?wqLmY3e))cTU2J=%}30%;4)qkN+F&>;!*^6fTEZqr~kUdYdBIE>~~`94o4@`c6cdd~)S!kN?54SK_5N~^&@rngAaEwM3LySWXRy93i`3g)01s9>zL9Uo{#%i5M7A<u~*q#iY%o?+tDHQ+4m$oi?~8Wpy^d`N#ftU=8>({JPnH7<xrv}uNuVZmk%y8&GBZMH(*zz`~ce97VzFj`Iv&o9&ZZms^7(+80%H6Lm+3`kVZ#P6n|$49NVNP+RGhCbXWoglAlen9Ara%nz=n_0HH?SDmTREiR<;KEK3OeR{ZDP(=oLr!?xH>P$P&Mi)&=o#~RV`uoJs*|{v(#xP=DlsX!2*Jpd^LnIAiO}_f;gAdI02ygZ_iz`6Gh=t3gaee^$h>ica|NK5q(f4;sGV#~IuMj)asTdzc{HF#7TSm##t>f!syMtC8F4}^yv_%mM#`2fN7ECnrctOhY7<?l-MD9f#kQN3&C#TuVES#|-6Yi(XUvFAnppz4bp|&IN!(LbC1RYtBo%u@Ng?IV15#WGAFN99AmHpShLT}&A1fsnygu<b@a7fcjIc%e`_Rm>)?owh$8)%<#&F<BCi7f0*QRK)+({b39rJUjxBE1lC0?2&xr!uEWKNTr+&k(Wj8rP@N-S9!;&G-?4ug;!I}5>Quj*#6tS{S`DfEpxwN|eSJ!_LvND?&W+SaJ(iuUNO@`=)+POa(PFiL%{(o60RFNvdR+YZmtVNsU)b%s+0qLs}i5lH8sh~lo=H;ookip`n1%{l;QDNLorMQjpyv|2BChB{m$$lTzu*13FE;A%c6uV}X$TEC=SA3k2c_%RF9&7)g{kFi_g`{dVXG6`NGF5$(K1qh$vmEfSCY<HvI4TQg>M2q;%g9p>S?}OnYFs7t&k6Ik2;-_pP@Jr?-u74fVdVCQKf0^Teo<-s!obdyW?hFMh<%Bo{Vib7|6~<a)YR9zDmP_S%FW~icGK6tg&c4Mbncl>-4|)C>F#&P0^!(!n%bw#o0#<Os?!Rm3;G8@S26tFc*YPY&s7o&x<a4k=Zy08SG-An4py-E~?PN4+d2bj9@Z;1Q2I(D6Z>C8aiawNO*KrmQGGLK~RuD-1U6Rmy=n5_GlgsJFaiin)gG}*`lLy8?CVXVJ$j2NinM|@*4pv*Ug}1q>a7cRWe(-vGcdPl;*7nY5uS?SR<|ejLdeu2Nd$}!(e*Nb5MqBM}yZKen-ww9-nqLjtd+qJl)a-xNBw^a`9-M7%HIHBJ*qv@2ynDIN4`ze`;gkK4*lF0~;L_Gi427RkHd}-3p(f3|7{!Mndp<OUg1MEZ4w4EyX^Cf7LRDD;B;+UFBAHWnu^bc2e#m~bUT_;=6XZt;O(Q}Ms-dDmdOHi!EOdfFuj5+Fxp|=jclF!C;M=r<7n)W;NYe@<Xj+kVP0Ma<9gP5@9`NHs-qef<_Vuzo!@s^BzHA)$t(Oh#j3}<fV^;{BR)i%z^wv>&J4e{r<zi-x{o%umWC}iK5CT3Bw6a0qF7${9UhXuHH@6BgbNGNGDPo(`)@_>1XMTsh@;dq;nX8v<>I4Am8oEli;Mz@BLZ8)*{`xxm+P^wGen;57X~?gan>WCT|4#?k*Dc1*Kk*x}*rm3*s4cnET1(>!{LseGC*ev_+QuW=eImh<1Z9u#;t^iFcP~3_XOmDExSAFCY0VJ~=r>^37c>5>z=X?f3B66-ge9ELW|M_biV2Zag-ra>U@ZR9I;LjHNrjHhYnW;{F&96Ac9V|}J2;3@FJ9_?lzesu{I;Fy9jm(fU9NSkY892be8!=^m5aYq#cjuBElU(flXe`I8@yx7h){yeo*zIss!aGN{7QY<AlQ(8*dz66(CZ16;!K?6hO4$ds0n5*lG+ir%Jm6i&0_($)+Jf0X>x%4A<Q&W+Pt!mx(*zEXo#n-Rjo1wEcjD1aze{IfXMW)U?EL-odokqet5Mkpko^5!RH`7WGP!ObTp+vWFF7vYK#Q~nT0`)6NZ&Ag5?*D$Vmi=a7&oEX(_!0m!Jk^4EXIE?-o@VZi$ZZkS(Vu+EV+Q%|@`$O>x(fE$vzBpZX0I51ggR=V)l1bs7{D!14f;c~IK24ovJdYv2Pi4=Ox}!*jtxzh&d1YO0nmT`Zt*ojgP=pc+;35w%}>9X=9C=6MFt?Ys;&FJic_sKyPW+AxvgdBI0C>P03d&Zkhu3cESuQV=)XvfSQ*S1QX-8>V5{fPk5qqtOrU0RsG*5f=5jZJ}&>t52F+q_gU?<EG~i?!B*V{BaB7pS<5-Q5Uh@4knb>qJ;mszCiGzk%pR{0=YCH1PM_oO^06(4f=0L(4h}!4LoT#8o#NLz;1+wg&{Q@q_nc&bLeYSHfpq)`xG|zM_uH}^O2MzB{frzv!CQSNjP{ULuO=gB8-vO>p_F+_2f9U*8>af^~{N?a8%I<V43eH$zAV0N$+TDyRRfU8O`H?9G2=FCn6%#D^7L-gFeU2v-GT*Q`t{Q9RaKCFTD5382)LO!FWm{bwBbx1Q|rEPvf`O@i@<C*}<z<<HeA~HZBQAI7y%~Td-{J!5OF9?(QyW>N-A)24S2T4I7ZYKfUzSW9?u9C7xCyY%fsdtCA)}{@rc!a~xz&5|SucFImZK66A!i>5A+nu0UH(X`&tzal@owr8ps}YBou7Zef9MPzh&~ygmntdPXv``JUYon@qKkY&WMeBdBucA>xp3(fP9;DqKJ{+!{<sfuSi-h5!7X6t2uj<&J)%%M`qAiR|vzB`GPn0yiB`%cc6e?GN0nQwsQd#l3uKdle6<Wtv0Na**fMdVGFzboud|-4Ir-5TeeXPu^TeMw06n%hn4OJ3Bo-`EYU419nbUHH^aNC&#CsPI^C`oC9lM;f2^W=Pf-7CM8=clFS_8xmX6+Vm^UofaL_`?*+RBtlN`5w0T;2#|aJJ^$MBft#m+=TQJQ?yvEsz|5#x7`o)O&N^2BMqsc;yDH##bCdqlx$T?L}CGEEd-qrOB22wV(v#5`q0u1T`l*kX?hQ9<q&DDb&w?RpaGn_?e3;UY=Hh2gjwm_zA5nD!)?_tPaT8Q~qx!6;~)+2f6?`4zut>ck{2ck}8^FBK_{MTUf*Y@V?o0l?(O?;q+KAvv0bgG%n^6>^5TkScfEkK0>f<CPcJbuIW6=DBnTRd8~5>mib1^m&s?YXL`?bKo$2E`iqoR^D<-+<Af=%XnI_qr=K;Fj#DmdTTylvKVaF=fh+Ov(IphE1*`y)t+_j3M#b%;&CgurQ=H4!cx8&gL+wWP>O=<Y~tNG!)@@*^!`EGu+Z?hlEFIwdgK1n>MY~!8jtJA`J)8Ogm-bZI8xAGKsvdF|NO%&2j=Cm&wBRzr<p`i<A4<(_KJRoz3%dG>+-6jBM+bc0*U-luPR8Mz1JfEf;mhVS~VnM3bD`wR5h^lwAv{eH46UPH*ds(RNcw>iqoEp|`TN)yq%B6CRG5hT<$+`~PS$#!Sm7nGDrx)FOSzo^<x)@E~YqO_R@|c-nzMNCAD;qp**RN#T%(lNCuLN|Vj)S!8VCz~O>vc+08DM8mY-42Z%aF#SyRzwB+bs>lzLf2pQn<T=}fl$Yk!run>)5%jdF<9M7x%H}l<#R^RNt0CK0!WY>EM$Lpe5Oa`Lb#s8vPN|hfE6O+nozZh`(*9D;#I{%^D7O9<&ESIQtQA(NuvM5sr=NOnPrg4px;%NyM+&O+fva!{8rbkB2r21Rs+Kx_kTOkGwq?0_Dh_6YRB*DMq8>$<^2_Xi$}hBXB4z|=oSX0$KEP46k<5>embkj!9Ni5|TE?ln`bN4rG~d~+_6ePZ`l~XL(6^k$5A}_{K1uc}`c0ahof<9aW9L+ZQ*aeLdF2tOc7o@bvro2y*n4+*`RPJ=!#n4j7F%AE)9RmV)0u+n(6caI_%4XY0|(?}ph#Z?RgzPm@!<fUm_p&zUH}-Ja@&BVmWS-PNi69qtMsKd5o`60G-rOSr@JSOMBDI;HCc1|XvOQTI960Mzv7q>di1MK`HXOlbHX`?TjkL-q}}-tvHmzW46_+A-LNLEl2~fMJA;&v<H8Q-&g!%|*q=XMIzcIx8zkyCkn5pbrKYdC$OLPCVf~uGp`Jq#V{Y>O8^`2R61w^ecy=%d)e~>#D9Z#tHMK|{KpV?ED|mrD!NifZD}Y}^L-i|39d1`!t2<3!?jP=8=01?)RnC8S;62LAr#gAC$X;qii*ejWHV(QwyN>uhjBbTel})3i%GkR|jX=)CMr%}`KGSTG$XMDb`oy{JbVRW)ejx{{s3tQ*Eiko#TUA1e89=QKa+B_mRRL0~<(oZhfXQbGH5$hn(Jo8lTud&ZG0EAAn+s=V*FciiFRaNc24yMGI#>pidsqTg2ZP>{l+ODc>BXe%!6cLU^f-%t4G#%<NDpYT*gVi?19&7xr+Au$d5@uD$148z)bt*?RO>z(=Hn;tLH{0y&`Y0Gyi_3pN;40nu!j@E15P=Tbcmo-mU-%nFLd$6v&C=IXeeH}hsMy`<hVtK@UY$5(fLD>3AVrx?YIPRZxSqs+m&{6dToVuronwr$(}uqgT(R6=Ww!6GZ)2CPBWv+97?t;j)tC3dm7~&&a~5RxO??mYMk{W<ByPvoor6*%u_8QkFxep0v3Kq5;!_k%^-QYuvZc+U$<Nq=Oa{Bv@UG~Ls%K<IHd}wpV)n%HH@+uAx9Vf=iqZ72VzZ6y;4qp4{(8^MS)_>g0QUlG^N6=&gU_<7sbJ2*N4?Ytr|F^p53rWq}1UpWdzteY(s{?ottxp6$^!gcjP|C2{se)Aek+E_nj4zX3yxeL1`q^gaJ;kqonl)d(G*`a?5PEmvT+8y=jmW4gd3}lOI6B|Ck4pC|?}DZZ|o=2$A)+_=K&iN4qy$<?!Qx$M6br<~L$?ZeG8j-B-T1`n%g~69_HDOXoOdWt#&GKEqJTykKjCr3tcpq}(~JNL8`lH1&)*M=7O+0sZ#srZ&o2H?BiYA1lN$gm42%Q5sW6!x5i-j<jyL`6%EVw7Wy>aAmKn>le&eYMWATxV3W`jB2gErGE0jwn5H(%f=$fe#_}-5xvW8T&aRLH<bqNP#v`$Fzx`teocQk45<ZNUNo7ZIQ5<iEk0O4=yx@6V@NnKwA8G;{TWP@0WG+GwbZ*%8zt?{z$vGQ-n6F|LA6Eorf5?at!Y(Jmf%H5$W^_CWkE{a*x0y^gKQBG%pnv<Sc3!0d}l<k#2y=hB&}uM2T{&WvY&{x5EJu#B_%by!|$XhRPq`=i>>T*l#=2qV`*sYuTd7>6FI9+kHmK5*#VNiwneDt;gNWe<wfk))y7xDy{&e456;eCZSU;u^tbtICwNUe4}X2Vza0i!{B<<i8@1_ao&9j*t9Cos4R*O;u)DL{-IqFh`<?zs+8^Ry{<^z6=mt9*Hw8>M3?qn!$$%XLS_3}2JCQ`!{>Cu+yuriZL$fSj02^6$2{-#gZv!UyO)=IVu;IN~*yFz;bZj!w9CX?{?b*XOGq_C0w+Edr{lF2yEhi{HU}4~!J|D~+bY>5v=uM)b_tkI*|Ed?8NQ*Vk4)$jc8wL1qURVMCOn^tJ7L2#Y1TVb+=tNDoI%`R80?qS;w=z=6)yn1U`Vxu9K?THml6$v;ScP&H4hG`{2O)Q@4TCgcl*i*}GV}q6TI-4=f|z#e6(f)WG7R}H3z2=fK#tCGEegpJESFMCwJ27ZQ6(`PuoUi0Vf#ORBaI#e^E|1UuD!jzZwB);BXNS!Iu4@rn>?8h#+%{>bAU*Udc+7g4STJ`xqze~B^G)t&-{(<aKptS&Z3h^whkfdvdf1)nuHJE+y*m{+Bf*Id7siR{2_#-w^2;kpkcQyIwUeqR`lMV=Xnwf04Q1}#vf6A0v{IIgREu;I9Oe?T`pU0_?R0ACKIbsxd>v-R;6$SURe~GmjAL1t84|a)>8kfv%Ndm-ui}Fp}X+grG>t2ag04eH**bUIQK$^{bVxSaHdqrB*1V}@X=I2HR`EORdk4nwx@i)7AZ-|>UgJ7ys4H-7o(8Dezo841f8IM2o=zzZEHcmg=uX@ZMVb$qIhGf_LJelDS|o<4zwta-IT>=k%%W@ZY2Ff6~?3<^QMj(^T|X%BW92a!Prl=jHy|ZJ}j69GhfL|ykTq6G8!IeW*iNhCXqxqF^~C|dUI!<-ZhJ`TJw<OT$QU@@_+;5SR0i1Jw22}L{;YMy;2VgajRKVyHlwxOxLac&Xtg?`rY5v`_>oqF4b8Uc+%cpM&RQ7C4Trhj0<T<XrqsXoH>m74IU9u98V%D5C4&pnr_f6E#l$?`uK~tsak7I!cmT_7|s^=O22hQPp6H)7H#Co%xYq+$F1IuD`PH=I1NGCzCBuY*JeJ#V`}rY4mOBQx3`8{6Ya_BQSKq@HlUXTsVPY0rk91BG(QyLtUW1m^rs2IeJgPjhe`mw;#R!>sD2Xe<J)|EV^z^^>d9Sr0p_NwmW#l6^Rtphw(9FM;$&69dkyPDKD#$ObH$4-{h(9iRncvYqRC_>Bq&hZ71FMEw^uf}!Q0SArAQ)s9eA|Y*`XbXCESg=roj3A3l1;!1-r1NH`Vyy3#cK&i@iqS3!)DSHCz2p|4Fe@`l9$}!<p=wxgouw)7e-xIo(PFVSYyM-v-&(zuIehJ5`)p^T!Y|TICxMtAM-Wn>vaD`f;atTr;0e_xkly-Ku1<TRU2)CBq)n8)#^w#GBLwJuCJ}=7Jjy9R|x!Tb#u6klS@%=qqs4B{lXd+4Z$7ey_#vaseg5V3u~2=3=;_Dp}8rMo5Nq2ES!9M(pIRD2~JQ-R1i;G`aCx`2`$E*AOPS@#KEFtPG>>H~6!ehg0}IhH$8#Pvh*MOX4%a5)fg~fxz7CjM9dAvc*qYJ9xIcV-<y}*zDpl>lqNlN&NdJm_)bnCN0!yb}-<Snpzm&GqQLwJ{7pTe2Ad#__i3OR4B>0l@(not<ds?+!gW_EIdNmg=ph#K*`!@xJ6mGDVG+Br@q2nx$vDXNS^|DQRNP4s%!>95BNNy+b$s#2eqY!C22@45aM&Prj8*bj0zPcotB8jnxi2&$C19U%iq93%O)d(2KRSm4Ezs|X2PDl)3<*&eQ?1qZUO53-z|iFY5hCl9z_$9S>;Qiph`s(goq?&R)%OCS>T0`4AFY1c-NCV_@%WpnMtuy-Mi)WKy4qGsQkN@vaUWkBVAfmkrWpyb*QKziAl&C+!a;r17Kl!h$9(<vP7HC`L)AB?Z+bK=_gM%pHm8?HkD&hs-;GYNXT74D`*Nl+0~`)Yqoa{u5g1!nH|GP0I4a~<;lAIzX!(5`YcXb#IC25-JP8s#h*7xE@y*@S;pU7ZGab@zQx}Uw7fW@9RDB`<8$Mt*vk}Axzn%MDDt(f;PJD-;xHZ;FL4-aV|Vas&nT)D<l@f!EaiJneO<9elu-hH60=Gbrf}>5MJwH^7?-FuP}}J9tptT>IxVzr*qW_#9vmH8s+tmpjN;8@)I(+Q3-eC`$Z;?uF(g##l!ESbXmpTbojlczLoxX3I6&`zQUEuUtW$=o3iGr5&1ZjLZ#7m7O;itUdiowt7AiJUz9UayMapg8G#Yl@#WQs~j)d&iedw6FNHgsyiKfXlK&Wd*9mtg1sRsubeZX}ggo*DCy<Mmx3;bTl?+W)a!j{YBuyMI2imWx8lf-YWV;Fb-u8su%!=sY7q&@iZ4KDzv-zApN-e^4iz3HULhY6_IEY%U9UFPn96tCi^Sb{d}gA_3WJ<v=o=>LZfeRgiDYh79TO47+jF}liD^W?5kZ2<FXjAAvk&o<&EyPrX2GApbsmHw;CiOs{S+q6!M*J)DOdzZAi5@)<>mu`ynRmB6t4)#=ngf$Pv>VL8qMZ^XxSTip|GaeiQ`&wLOB1%RY6BaNG>Z|{Hg}jni5{9vP^YwptMc`$5A-*>n_Wo2mg1^IT&OWJ#1X7_D$muP)C*-Q`@nSX(t*E=xw+BSrrkkg~m!04$f(!tTVDSpFF9VM+4N$0ndnr;o=$pjz-vS5$LF%ssgo9IC@@&z{pZe<n`2)O8Y&eh^32yG|A?8mathS=;RI<YvEve!CxBpg1wcmPO=l6G{5v>8;v7G+}>b7(x`-`(nmv7~5^UT@<couSpl$B>t!EBe=&Fd}awYGDGeN)6WjeD|f$Ys*?cJjg~Z4Aw}@!IxvsBf!NYO7?mc5K<tx7PgwA=~;A$aG_c4@vbrqUJ<G;a{r_#`TTaD@pY5rW!i3U;VM1@{aJ}uQW8aA@LOb=ZlXYT9N@T8ZCSwqej8Z#UCVzmHSC)dw6~`kouBh(L$G;F7R!W8=Cnm9mOv^)qMFdk_@g9fwxrI?StK<tN<+KF0(xFs!@b2Wh72hqso`gM<0#y?q`LlNrgt~egt`{@*Z*ofIM;RdOhlb!&tOGl~(_nj&qLVf@67{uBfgmswxML`>`st+T)(ukK(Xy7cH`6hH{}uu~9;Fh?xLwf3m`ltfpsv(qmJ^5?3&Bf~w|<G@~h{cXqd5$=9Jesn5gUW@kh`7!5I;t4-xUrEadUXk<Z;SRX>i8to6~Fhs!lwYC?x5436Rj6G{-^xUHy!5BNHxiFSfa#E3|$7j7wFDF>ShDi!cuQ*5UcGZ7KB?GqFQI_^)mw=dv#}#Q^9p^f9zRvtus5)R2IB}?ar4YLm>!hxkgAiAMC-hlIV2mzOWxn;=7|_CeBOT{ESyB8PztpMyZvb}^g>G7p%=Hd;q3Ix<$U|H8OWzmm-_j}Wvf#|7yc|ChR;)Wvc=u5$pK2W!D{HO`Nbc~b`^DhgnV>~m)^QUo2^)FFbJR5YTRcLG^<+59Qg_gj(pTfgiEE6J`kjl5U_f*BN^{}e26f0!7kH|5?A>QF2&#rUwGDNghL*UZ-u+gW(;A#Sxd-)Xj*87lOlmy|0`+yoI!AnZI>bo@REdwh*{keu+=C?^-d4?WT(9H*nhnO`H0XiCd8<0`+#Ck3TdGc|bKp7fI^m)i77_&=cq$o#^ZGvQXOT3a5->QgCz4yFH&#Ko2cDaM!6~c*f)BhZ#cQ`-E3mFIw-T*mTy}MYkBz!Yog{^CL^$l-ul5Qql^#Fm9juTC6K{`$d~m-A$FiOL<@9?`8d53K6N!#R7MSxN-gpvWqpk$E=x>>q@NW{LoW@8tPQ~%C7Wp!YY!=AmT)#LzJvlpiQ;E}8!74pAB1*}(yE`?-g2^o*ARkXv-U>G>N=v0fsn#PQcbH6jP$(Iac6E98;GmCp-S+Zsd(&j7hC--c3~Rd5ff0&N!fKBS+wJz!DGB4xQJTb46}4DFqvWvU#iml<wB(Uqtu-u|Gu5C<JZtrIxn8eQZWe)tQ1H{~*~*e6_uoZ%PZHc<K`G?d*LiYX&#jaaP9g>Q;W9{hW@o%$OeWL~RGKA;7)0B0?ys%Hi9MUqz>2t6v59W1@yZkgRtU1R1jLXc=vH=kd1Gy+{YQkc6&IUO6N70h5Bi-pE{Gx?!;2K=bal6b8L8nHHx2tH9DROg{2;jTn)G2c4K?+}BDLW!6+yEUJYuDAd*F<FoLk8^DV2O*T4<mNHnBIgZT<PY!|*f`<(3rQ;cY0vbSmjz5lFXXi*^JC`%FLJ-s(;led7k~{iZkC&?fViR#dKxD0TDH^zIIe$9H&C7lEJy`udY#z=9=?19{dvbtCE%nh**-q6t;0`VKrR91zJ2Z;Ll-Y+!P;alp*6_4=tc@NwhOOr{Y4Zl1hi6ELpI|0V&C%i<PE)D~uN;M^T1COsz#S6OJv#lAF2ga!sSA^KF!(md%Iu%j_CJ+#*#8`vT4z+h=$Ma1PAOhjk!<aEwDey>i5(LstTvF(zSDq0#U(nPA3Nx{{1pSdSbT^@;qA=!ND4U<sfu8Uij*nXy2{fqVaAm|>pvs%c@GFe%;UtLLyW;X>LDT^EWq`~tE{5k_4Mzoh_Z15T;&kfv6w31?!<e(i|+3IlDgs~{+<8KAQAWddPtS0^N*(SlJh(=MwzC}<sakWHBS(Y62*?P}kODIcM-TtSpBLsM>FC<hMV@T!#S&MXMMQp|zW!a&vuZbvkXhE%oJ9~h(NNAUJMMb-Ykpk`FWzkSqXtYLAZYLTR3={{+b0h(0eDsMM;HS?6mE(e}$N7fk*zVB8>L>SE`EpeDUosb@-Zd&$oJ*^kxWun7>xmDYwV9&rrFH`jEjAju<Y^YCk*2p@iuJ^;jTPZ>9I{1VNs8j2->6l}QWl-<P6clYcv9pcsyJxV_dWuyIvpINL~bG9x@3bM9(evHeO#GtNl5ux9`M+2O1Y@fj-|mTQ)2jGuSl*`FQpc_6aJ@_LyIA<uvJ$iz5|!esOl1KSCaLt2Y1W)Qyqu5HPf3?vRf0To!q<fDqyRXNwxD@HJf7Dw#Gt|0vS(ko(=|fAa<RAr!iI7=5*y1g?q+UR}m~rwaS@qtQ27SQe)##r)^ZGh?S*-Hm+wW9O<}`0zt&1gMYnTb`Bk`z5Xi7sFl8`E^`{vR#~`!xNLq|zK1gAgK|Q*XBN0auhIlbA$E5+5&~qV!sISmN1HYkNfHck1G{Oc=`9;JC*yja6jn98o*vE=tTW-+Y{WFh_duF<-E`sR`Bix}+~}*@>@F&KrHWU21*~Xs`QEE@)h+4E-che2eeW%QamL1iCOxeg%;6z-a#JYqa4%JN3b2|^D_7XB@G|u2S`5OhY%@^xpni7{ys0b*?10*CnoejRMUI$t@9HV#)2GI|Ep1CcXWZWF#<T5Z|Com%!6PTk1+s$&Nylo~HjE1x-qk_VYnz=yW}zvFIB=A7QAMMvUktKQDX>rlI_@hHdvP?LATM2w>c81;wMp^k{5k^UI5<>yxq*#*#xD`QN(y{wYZADc?lN#TsPeY7%m|`eYPY&b{7y>!4*u?T*PGBnceR%Wi*Yx$X{1Of->AUFs1Z24m(=(69)r-?Z#pZOcRF)h!2zzS+UzXb>&Gr8mmzk4ZD`s%E;MS0e@O3a6qwJ%d~*Hb&znegoq0C9<V0;8hAxS{M^T#PE{$ye|H|GWV#ZvOO1s-z7OGqRvM&;(9Z}&?aatz21FyoCRpwSX+N<4^o3sZso|ay3X<$_M2Cp_4T%4Sp9ABP({BU7qq~$ntY7yt$#13&^Rv(vlg?Z&-O>@n(g`4NEnl9aO=72E{GVig};*;!U-k-y8Mj+<*@L$<sU&>BbbRj$ORLR<`x6FCQHmA&W57olB>CWYNHa=?v^A!_-)Leu7S;vU#LLY5d=)h*9jkq#JlO(y58=y9-bvJB*Q4Fuj^}5|T7__&GYv8q2HcTb63CRfoTrQqUt=gyiM(h%=A3ah<tyaH{RT#3Haj%!P-{^zvKN5f1<F(k`PTzXjd@x3qv^s27u(upJwpa-K{ORyteK=Sud~Sjyzc5nJgg)AxK3%_P)s72yZ^%t;HYUOc(pV>azXab`VjK+Xhl||xArk+>dF$Z%I^)dscK?6qXleOoYY*^Tf)m-`2@I)gg7nqiG3R*0fN}Gm_dBLpiTkyh0&n~#Ro<belMg2nwV^67^<z!Oq0Pnq7<|oR$@N~$^O_hWrhH^TKYh!$CLVZ?W;jn}SXbbP@B`laM-qeFf3-F}T)$9W+adhl3uGkmAY3sJK+R5k4pF<&COsWMUS@~FWLI*+qQ3CK-+&=!@2q8Z9D@msJ;!yQ8DCJiV$4>^rhvB8f0IiJ=QfvANUH4`{Aa<!lg%a{N0~}jVK$wn*^27kKK*O#0ojZstx+^kF`uh<fguYX%D~J_ghbRdn0Ptv1YX523R<&GDOWZ@-PkdY98kX6eGXTSxw#c9wre=(Io6^&XFFwFRi^Q0br9O%C9Y}B(pt!{^6|LdXv*@WWo<DxIX+?f;y!gsoH<@A$xPk+!Ue9%_q@cxMD78S#E_QM?V3Tj;TzXm#IoYbaifOKf=D-MkW$<3AK-q{lM9q+d+^m+d2vmG<sXhcY&Ky}C%)*;lyS_0Tw<yNM^nEjc4aki({S_ZuW;J_>Z-l@I@lcDJnlY;d#34PeV^?DDhVxyvx0e6zUNsX$-HmcLuZSrKJ2mEkf?-k!dcRbQ7c}}FUq=&#i;pxRiLkoXhV7^$?1=LH|K%Z1*pg3|K;&jn)K~SJ1b11EK@06@4^KW6FzA!_1&K8vQDnaQ44sl1Q71HI5Ag^Jr^keV2R)A(jEt2*kX!$(=bQ(#Pw<*R4q9W)k0lB$W5&SAEaC@#z=<78aTN%4W*lT*}C?YpgT~vymH$Z#!cf{R6jY%m3?ywZPNm`u{_bTGp4hqcPvqW?~KN+f&($BcFJUn6yd?I?_uRlIrAHh^*e$Fk9eD3!!&7mMm9z!XR{KpOO_2I*0q$1_2?TZo94C_TxiR3fBnU{)|D<U>$6@sMtiUjQqh(D^^5E*Y9ldzC0Z{v8;rZY_48+3DgvcP6g&A~oJ3H%^fjtHl87%%l-;4|hsRP%sBg9i)&Etot=yDvx2)_jhx(bld)pF3(Wt#a-dJ`Jbt$;M672BVt*i!4-PA%%0nb^r>Y7+;!g45M4I9?c+kgJ?;`05;hs!TDVy(6aS!=^F2|4hsWfLlDtZ5V)xudEYfp~~$3K#mO3ulYWVbaa(wmEt8j8Y<nT*Hh!`#m;{rNhzkxPn^C;Uwd>JI^TMs*2igm=@R6zPW7Uj~s@hZ7aZVQ3HQlOUag^U#e)Uu6~D#y>v*Hj=g#qv{@$8K7tM-Dqh^SoF@`|h>hiW9b5WvM7<z`kGayXE7UCSpP^>Ek>8<YFGUg<hDMK}W$E+_lx|hw&>8cJz)3F6PA`Fkv#z6j2f3OXxzSVf?L{(2tRhUnO0^|^hU59#%M5i>3#F%XbDVqox2ox1hFGJt%fOqp>UzOKCOGX05!Z@=vHngpS@=S(t;MS>M9em>1So6IH8-MH_EC!|J2I)c036pzs9hSj#OJi=;ha>ceCGD+Lgy=*Q4(o^;yNMp4<>TrP25A3FI9wBCApCn?ke`Kzf!=bJ<H@4#CUfO+FMo6B@{#p1p>?O^>%llxMVd>kdcc53eA<kn^7(X1evT#SdZdB2bvx&Ge;Q(+ILGPx$(TjW}KtAdWjgzLZJW}8@l>Kq`P&@AWm;zV(m~;sMHrX9#=4Jx@~JEVYRVjX{$}M-q!FBTI#yet-7qdZraz~vzJMChxDUvYrj!)A5lgumG9AVA!&N0Tke}sMBgatgxGQ<gxFZ&Qo^f9;#&Sdw~~(XDp5J|R=AavJV{i#J~8Dw^0NYRO+OOVPFuW%I$!KPB6{l=IE?6wj67^$pxe|zDs}D`d{6We-;4k6drNSLg$^BFKQeATeO@2nJKB7~i<;i!Q$y?ciXpLcgh8~mB#`ZAwHnEc(8`-ZQji8gZSXu;==sHUzC}une|v9fB&899;p0=mXb3<)ar@~MQPaK4zkWKoum(PjVgyj&D%T)pii^^F!bOi>^zh8rTnY_YB&2$~Qth4{y*W9%xI&?uo4V~?byPUeo1V9;zV_(YDoMY}{`2Oxt}KiPrQmUGG`@ZjhqN5Byl6^{Wt>fKn~hfNUf;uoh&0~)O2G~ne5yFbVf9N94g^zR&`Rm?JQ}3gv((~D#-(g=a(!|6pu>u1uL*H$u6-tw&2Qn&6%rqfXkD7~kK2?4=!N{&E27$Je?qf~;zW_eMv%eGET8WVz2lE(AJ5;Moql-RyL@+ka)Cg2rx8UWXhD6giIVSW<f+@F_`7@jQpX}KnL;x#L1kGUz_Wrs>FfZ*lr~nEK}|^z!(CfOu=s!9)~HyJ_EIP~4@S?o1nU8LJRs9ciB-BHn=RRy)R?2Z%r}eyoUcV^sbhw~>L6A>(j=b8gGh~!A0=5-{0jPn$Yp9{p1?}g<h%?FIWI<bzsTI{Le(h(-%KqtRK80T4Y27Rj>xJE|F%YVrN?0x(kJt3fHh04;WlCLW^#X*x=4(lycV<N*mG?eTeqZ^Dq5;rtTkY%)p{eBAg{Szt>Z$y8EN}j4Yq4YRMVd>E#^p)7$$Q!D~_lwhC(&yW(&0E&U#$YAoObI21<9vG9{U{uJ+AU!pIk`aqWFsUgOKXGSzBANa2@9g%oG?VxTx&acZqWU=RJ}#TXKW(sB4uX;=;qo^QFPoZYmJ>C?@#hre#9frjvaYb;AC1%p&DnIIVeeGDeJ!j~geO#obx#<qA8<jLd^uJ4U!v;siR&6!q=`lY~Z%7{#k0hSYf&ye(pf_`R3qGS8KO=~dvA^Xi@FssM%<wJRXuVP8MNa-5ZpXihiooZQJojhKMKBNlu*g#YcWighInzn4K2)B1obJk%BT@`kp8)sADk#UpC(hL_(yPCEJ-BjXrEV#8*X0-8W*Hxi*MpIy|*9|-0D2Kt3#u&wRYVv60zyrmSm!aj~P-jCdjlO&$h!loPs#)i|j2&&-w5*b@^;s&G@TQDpzXxs7ZV7ABfQ>c>NZ0DcyCs;eOFNDqkj0~=ZAo}2t%8tUl9nb_a1`eWM8TUSNesSJJym;{>+fW_YboC2dU5fiW_=aI;8Df=SW?(w+1!WyU`ZvLCvpZJ>vt)~lVG<e<1T6xXfIMZ)YMc&Q`AroTx|o}eI%*d%6lhgSvDIU-`eR6cqzwr*ghWALCh}-3Uz@aW=GTfVjA4Bsslxc0F-;dU!2n#P;SULpBe_~P=cN_Tn&&ejCh}oqgm!bO>M~)1H)vHz4{iC>vylRdw_>vNoIjsTk!b2h%50!-4=_xr6vZ{vu?n%k9~-P75NR(UQ<rV)#1=Ih~m}z)A`BK+xI8lE$w|6P?qS{8EZCNkiAy7l_#`(#<Ik1==CMUGJqw}>u%<Za!K_^dMT$TTiGkqK{TD?MvWn<s0qzfGK=8<70z)jI{!kkXP_q`R?1=u&*vntMz~OZvXHc$IgKxwWUu=3XhM^*kes+tu4Y_PY^gFfIicuXK$Hr}S6w)-E`}%0I1AE@4dUt%C*s1nP&~Vi`Gn@v>6yMr{#2sg`2$IK)z|M6cq;JMk27}Z;fhRUlc=w2`{yU0KK9N(e!OgYj#;SbSf5B935j0CQnJ*3i{&c$7@8i^^A>i0Jr`E45+aKpEUrFGu38?bgzpmLeH;D~{4~D^;;fbDBjwq3@akt$os#?P6$YBUx($=`HVRaUWdPPx<U@m^VYeM<#Kn6@XsMh9s?ES4zlAi=oQT8>sLAPHs)v6cFHUL>{9NI}?Xc1rqkE`sBVi-9)s^bTIK8dikTqR$kgaWGL}g<!FFH2iXbMxN<Z+3^dz!rSACRig^HHJEEOJO$$0`v?!Oxv85J@4iHfN_H{X*=0^kpz1pfqv$1^xMhhO&P0U5?$IorcK^gRHpL9N<n%NC4bq<bCbktDGR!gP2rZ)+}YIFfJQgS%VPLno+-@UxyTFZ<9d~{1E6kIFbkLQo;~wte6jQ(Oy3Q%+p&PF^u)pv)9wlP469N__^f_L`sj>a|CwL!XLDumHbv}4sNd6sQxtqUAs+b3qN-DZ<><j%qPS$b`^^Cq_S_aS>Od!=1Nyw2gFA;IIQsb%Fc#8h(r7_5b>Fg@BgfBp6rsI^$MQ2{yX(#OP&-rQ>wO{1;r4TQlRO6G*)qYbPqY&eDo=0nutX2nV@N5*B1yirv1a?l!6Hy2ZI?aKNFR?dyq`02<}SYmob7@joRhs)3~L1J{!bo<6~WFroBaYS<HC9=4%*LSaY**zC|Zl)4HYP>PE817Rw6FvY{KzAJj)PAU&{Z<B4Ql6n%p4`N*`)$<t@%b|M`bq~2ni1&SadOP-;E*)_cH1aT#{#-N*=3F_|566Y(f1af+=QG<%2Md)JeLTP6+THd!>V_d?{Qo)nTB!N8k6Gb-S<;uf5+}Uqy+K{~ZRIF+aLknFvDy9RaP|#L$OXN0Qn9RQh@}dw70-2;^ZIlMm^<L5pZb-TmF5^8?#Ve=MjgAFHjV-7DDG7x*++h#F;<04ZRS|8Ppja?NZ;vuKWtRofNS7R+?mUqwQq#XPsv^0WJ1p)-jY>CT6?F!~O9mArsbW_?wr*;=8>G;WF(@td*I;28nFtuV39b4W2qrPFwh3E3<S9-q;{pz5hmq*Rpqp|>JdR2u_{}*g3YIj9U50eCigH=n6fHyOHYturWSbUdBlBrY+D)&s+a`9rwX4%glr|b?{+r%j*W`VY<7pUsVSC7<DWniN(;m*EL;v+|(|f(!Xp~@t8dHH#?OOuN_Kv#cl9)k{1c}=KS?l;!cl+6ehf3;5*OFm<i#iB^o=yO-)`E4o+c3@OZIk5bR`?K&dO7J4*$j40+1-)z%Gdpoz#++$bG_r&t#3X(OF!dI3@D~99gg68IJCP}nfB2MZGQ?M@1D<{R~kV{4zb!P3uvmM5@G}(sv%Wqzm+GF<(c+iY|AS(D&DeHC6x`DYnkX2m&KQ`j(m7uI&@6$l5ziBKW0&^dBD<H+mgky`{hdq0*Xcq5h+?Puc7R|vV?Z`tNo&w!tqOKs@<?l{ic<sbkE9STTR-<WLQLQucXqdvzJaoCo-&G38ju*;@<5N+Fy6u>&!52&s#Fb!a_Q2&gWO2=~)nmlb*gA*u2FOEsbjFauo^b`o&kHZa4~G>kU)5K+H)e>%g)`X93YDRd%Qlb%em2<>vXX&GWhyrS29qElJB%Z5yoBkX4ORAT{-d2j{U~S+wsKv@3#ArGU;n!zq;M%^n86v$M9di<bVmexqch5Z@K8jO<bo`M;sWv;t^1oVP&8l9jyA)6+IOq;yYfam%@pV*z2Mqer80z{70sI2tZ%1+J1?6)kNfG7OHdppA*5D}aQnuNu-v9WE*inQ>!x=90>nGZ$L4U}qZI8K)4oEkN>Gnfd3rO3r6&Pn<&z)<If(uU!7<MzN~8Ydg->NkJxQU15VY452EKSSjwr-0GGs^HfvZvTqjb1{paJ7<8W^?!M^1=^0}#Bvjirig*Ck?vu&&OZ=(FS;~4nIb7=XFbTb$IbC8ANt+T|N9iqJz55BjQhylAMP4-hhrJ%*z1I^ZQ)sb)+e&pa?9myh`o867(d3wcLzyVt$ryn2B+0gv$zEBw0$-oC7#uW5y|h%ZhGlJ6-X!(bc1iRBFJ9{5HWZ&+-5Fb4!L~A8nEpf$!d*q2E}7>OwqA!RC)47S{(zGggj0`Hso*-EP=$%atHK*9nP6ztJ4v8vGN0knjKKH;)30n0<m{iE<p@$6A`B>KN-W8QmP!y!7VyW2M=%m|yW(&E;p5Sfcl7c67#)k1fK7kNJfrf{nZ$qw-tor|KVDqZc*4(e&^jfQdOyR_B6Cj{1dSjd#>*v~9d*ZOt7t;uhqNHU+Z06ru!n1@Gd5$07>ZK^xO%*5dN6nAxH3fKfFMZ+SP6q@2E#U61^5MxW1jVfAugL}d7pwT^ENl>r<W(!F_Hfau`8*Ecq@b`)9gY>@_q=D%hT__m+&J%RRY)ZC72`y3s0k@L4$m+LazmC9%!Ft0l^~KBBn<2XrN+`^?`;g0xy`{2McO!9%oC<_6DJa*?z5JYPiP-uNZUF1tTMmMk~zz>H((@EzSU@K@QrRME&cy_}-dBLVIy^D@>+RmLTEvf^<N*{%+}kf>lL1qN$>15galv!rLilI6uZqBD-oerTZ4Ox^I^pRxCY?u+Ace5zS7B1Iu|oLnx!Yo1lS<lasf^;<me0N5KK^+N2+arw}X1OGeTHC_RLl`X#}<Bo$aY9y~LJ<;PC?26afScwp7cUK&+Z?vMxCkqpf{LnxKMI)Ir0|9(Y;_Iv+PCvIQ|1x6v73hVO`{=j2S<6DzK-dqP_FtVcs%7F7UTv6$koZR`7WY7ecoP>}(+hXS|9(v_-$tw<bXhEFwJ1tI*i9D2kyS0ty@CNp~@_bLq?BaQ+p*{1oX*GCg$sj<izIcq{YLjU=j7ZP1B?f@hPlgM1DDf*xhtvw^lO9H)bNR@DeIMX(!C@N4C*L15YF?Wt23odXZSg;jvTX|TT^cmh*Nr*{&w&D6`D0F_;wz$2)b~E;-m$@yvB1%iJ6Q!usi?WR#P5`@<{-{`m-&)Bz9aXfT_LFvZA;!`1cNdQ!GN4t)tlqDCze^oz8&QH#ZSd9>s)Lggoxp+ONLvj1Kz6H#&-SU=SYWrz<{5!pEG}-PpA6%_q1~u+tGu%Z9v9`BOYn4;T~W4Dzau!b9W7O`zD~B$?Hh_@}q12*s@8g6dgoE_7TbAN2KEMVN<)+-Q~fz<|GHw!t%AQV#8Mz`sLOcs=clHIvgm`MbxC)NqtbVPFB2~gtzPkM1o03@}s)wrV=|-n%EyKiK%90mFTqY<nA^cuSFcmS@_tb5pF}rZWdZFA1pUj1--EKX{Kt%StralRPmRd#l+goZqR(&YF`gojf1M|oWklWq7t&hj*Wc73J|9wx#Q}QcVPre5@-h#5~IR8BtqQ$QZDUMc&FPo>i$9yi<kY3&syixY(Di}RM2|&cW`YK>8gmgi)f4u1bl86BY`x`jQ63b+SSy4sAr%iw#&XNi5PzQIv^Db*Ll4JWtIr;po--POJFsr5M~^PQ&LF-q!i+>j*JV&p%j~tce%ByNkVuhroe}U&WbB3L@YR?LGz?h6(Qv034c{X@hEYxMCKOQDVpsCVLYIHE50Sn&hydcei1cC%94AVie=y<xL`!Fu27LdNCl2N_fh{l9Ix{?W>2pe9vIHBp^FGJYsEoXj^VbNT)0fdYFa?Y9K%^AW|5oUy2{ity@?eW)~r|@A-Llrp@ee^3!zbt5L_A39(+?{yGlf6Ru!6}tbEq<Aoedp$282wP*a?1(>Awg&%%KQAB5Mxuz1a{(p2~`^EZ9kA!Kv-+UsJkSQI}S*fMr;nb`HUyCvAQUy{_cW7mJlqL#FPlXbMx-Ld@|M5<CZ#QoZ2{2k&C3^BOr{7^&AA2g^Wjc%iu$dD~MZm?-|D{2R}yJ!kVatH#*#<WS_(emHd;j2`AIxPpf+6(^^<3Gw(JigKWYBG>%Z|QKRvf&dmQ%jZa6T)@(uU^sCs+l5?E(NX*4p6V@$*1<uk7QPe-e+No%_Ab12sy7`w=~05bcPQa@@(N-&v_vIU<iRM?BieSS}O<PprU~O%ZSJIqL?q?^nYzQ)9{&u!oxN`37g}{ifR1<RC_cKT04vK)}-WvtCAeIsDG?4e=AK6FH8~)ZpXBiJKh~Z^QicTIX!OtVG2%RMbHdq98D%P(?g!4;MZt6$Gv<VLO?JfkmtkjaC=Adom)}~Zq;^qn+8MN_(dpJL^Me_7KPr;BISz0+bUdXFk9orj5feq$Wse*!y=y{=nWVpyZ)vsqDrV`j_z=8)z&Us`UO&2q^~t)61;9nJ%Az<V#s%%QIQO~+$6`6R=*hfaty>vyd5N&RTjUbZ1I~w+*Bhexhom>EcDH8Se^1dZ0tkp?!uNqY5hI8sPyk`2Oe@tlIM3|La|yG$!LTHH8m=Vwk(8GC=@4}#GA@k_@adI+c3$a(a3l2duHp4wx%hM54a%fM+zd;fz>EW2llxH4+2Np7&2*xbr-N%2j6kRdvU!-glh1L8$Gnj-x$_f9rwr?_#@zavPW(<0VXw8Q*f6qlI9E#VMsETBBnlGM!3PPrTid!^xQ{by_$&HrQB$g<NvNL6-!<T{8j#*dbaN#oJylK{D(NdLO%c=)Rf*WmX#CIJJ98%n6Q>RT=A#*#vMHO+CW*SL}(C*eARZukn><(QDa{t@5O#;5m)J|u%;4eKmfBbEg~GSZ1fQN!Tu1AqbN7ay8@U}v7!n&N>_6Ut*GQsvo7pZuaUv3Em$1rOX|85)wotf`IUEvEW;2*&E5hV>6lLx_!_+|XA^au>;Vo{FL=oGVO`Y99TTuEeh+z^IUBDO5&(c2iAs}$YI+f6BV1(|@~c9yF=9PhYszqq?5_Grn#*OJs}AHGz42o$NI~8MeC!gF1hS+*j^w-95}p^o)7yTageG75hM#Xt+9>*Ils36yTX)OKkb)TDhK<HmtJQLro%k4|D|vOWbwk^n-)`;f$Yn1(^po2ypt|~BfGsSvcI$N)1aKd~VjzBI!sp<c1wUUB8W!cNmDyEZc2C+Jf_a|&5rP)~{q2I28iPK?YjPS5Z5aN_`=p-B7GXtz^JNr4t}WoS3Zj&^MNVEi#pJM88@Ha#Q&>vTU~#$wv<<_V*?Bk{gKCJ6{D8E~Tyl_)gZx09uX#US{BVKRXxB+N<bzKm<=~79WI26Iy*QLG6Qq};{R$_Sd>9lxc(-9pyWK#IwdFFk`z&;n(lsR(s`e$a3X1<uDTM>RFBUYq>B$2-4)fWQ0>sJ{+{BreI=+(gI-VNq6su4_{;jMG1m%~S7-(^-C(w9$quez+XwJ-+-Kz7%`;bpGMNw@EAtT*r4(>h;(p!BJp>Aw5@Yw8=KqXNpUijMTb=AHx_O>-^wXIsS08G5wwh=*pudq7+4k}0(pi*!KJK!gq9gH52%I02F0vK*3eqt)!6v!!9IWH3g1JZ6qdzGB)J4-5qFFTIX7?q^Vd!Y`aTE0Qt!$|CI5zAQqa<!Okukv5R<$J}UOWDP19mN@QQdONX7*}_`50#eX%%%YZ)~95i`c%vnfnl2eOdRF#iZ&Bt>ZhghRS@?3gLYlSk}-Z}uzs>iIvWRvIO$qfk?(>}4LP`er_L)=YxyIR!jFD>>+SEu>dK2^c*yrO{}G$f^^2cvhHq)%*Ks-jph_sIjR1<`-~}`YU^bYL6zn&i3NwLDcK@^?W9@V;dw(`lPFH|u#y;IT@wUY;`3=L1z`{O3tgj8ULZ4{kunxfZeAcx`o~vxz>{G(IVA<n~%ZsB5DUR>newxg)pSpT0;&vP>q>{RcOjzXTbV%gDQkFR8O_<x;4JD~p&QQ2fb3mrydv3>3)#`Q~XOCH9i?N&fH{WMysoiUTdPN=Pk<pg>eBkD6N2)BpshmqL=POhIo_0Rh(`P;A2TptJ<ZN=fQ(A=fp~qLRhr|oE-D8gqQuqDJbAQ+|TN(exC~*gMIP@P;;Yv?r&t#$D!*#U+3?_7r2*atNBS?#lW<hG%vtqecOhy8aI!Sg`h9pvv8<e4nf~?RdR4>s+3|*I0gNn_CJH|DXye#&*v@CSX1{Qm~3N>cfP0zZk8@T|AbQmtyY}g+bE~O|u4-zUI#p-%pJGY<8Ur;|Ej>TGz!xoxu<XcB?4Tn{f*6{CwPL?nz2+y>=^@w-UZZrvz_7RbbwE?n<%wYeQ+8V86k~Sw2rBc)q{~n){vhknw;a&r5*_cMxFFrCxANl!HB|W7|?x3<fsI*Qu4%9k`X9>J3*4?To2EB3e#+Hq7tPQ+M68FkUxdP=-eJUdYRj=O<7?flH1~-H89kHM_Gq&{nUA5n{pAgfW9CpnmCBxn%fFvW=Xz+<t5c?MMDoIzOp!ywJqRQ%PS(;UI4Xchw&>1b*_SViHAwgWYs#|~IV(fWA;@?6{kWFo-LLy8=`?5T=#M--79$K6_z_|%N)}8IPCFF5B)n|4iTSZm55{;f}mndWel_;?&;9N9Y6X+*uJMrNe+$`0#ds*FG^wzzz`$CzcU>Z#pMA8`&eiYH)<@~A$JwEhBVD*@K_|{>$W%o7wz3zLMzpYkxNkY><!VwPV8Cf``IW8nXN%Uc6mrtY%+vc;A-Q|<eVzS{w-`e?2(``?u@yx@VD|ZupTyB?Bj#E;qv#eC%gd+vJ%L*z-6Ohn~PR&8Sl<VA-5A^NAVltMJreDjfYiD7WwMxr$M0}@oF$<>-5f?d?)z{=YuE|y`%l!(KZfe)|It#<{OQ+>v5&!OQB7QN8GQsaQR;2AUQ5Q>0?5l$?R-JV4iHJtIghJ`qV3X`o!VZ+R&k0#XyCqgw8`>u&pIuo->isv28Y!h(E&@ghw|Y>P&V6|JNIO(A%I||zUCDbMpoEsS!3iWC9yM4W3i4QVvtjkJ@jr3MN3|XHg|}Ks7#vt;YkdE)m|<V4-PvmryF3>nU<DoCvP-ZVjADnW(1TWyz#hNkq@;*aA!+)dh*5ci<Udq!a2sW>F!e1ifT#`cC>{K8df|Oa6OUzZZ=6hqyn))mC~Rsz@}wR#=fJ!8FK6(d1$~iV#@LnyI3uxlKgLz4usDShU4DG}-uvf^j~`mz<v1c)SOquSOK=D<nZqoRvGJI*p^+>w9}r&&Gf59cQdOY)h%=QY3x-f@3|p;-mUoh+QIX<pHt$cOOwv`ce=TOzfSnD-;WVH+0aAA9*c-r|M*TTJ<NIcm8zA*RO_F>p)j}QjGKwBJyavxqZmjE=j{%B!o;;k1&Hhx*vvDyjNE2}9V|FuPAdd;QNpj0{()2DcVCwp4IOIR_!23Ree;5bONWYB3SY2q!ZoWK$Dr=X3HcXS*5Wy@uO_mO&AfW8xaKnT<XPhv`Zb_~ZIweN`k9m}a!<I@nmEqtJ7(%POBGfpXtW(RwRzOd%uau)rB)CNV$o@fmAlzCfEF+jqdd0a=k#9#tFCH@7Q@w%0u|+zH5;>-a=q(jeBT79!JG!_yxqyNRp%^z2QUA1F;oWb3dl!sjdAx<kpAu@zyI4&7$pnubKH+bp2-H5S1iPxD;$(44h_YYo;>Bh7u)M)Nl=wjS7}KcaqCKj&&;H{az3?VbK)>c^Iyc-I-xTplUt?KqxWhL|z7L4$Kh%|`5{#A~aBM8U87=RTqIMay9Y)a^YoMwUW8{);li#O-MrCJ5_3mBFQ)M2gG`3eX=AGtX;#_sV)FQ2#a59uEHP`X`lglHXRL=94nH<xdR$J;{zZgW*p7U<2)h^yLd8_BU?VUXrFiy$H>`#h_{Zh3Hig}+5!->3;pmVn}J!8W9q>ap+&6=Kirzgj|o!7g&o84BYQtkNtU;kXK_haj#<^3G?z2k&4&iNNVfBe+&K6f=TR5}?NuSoQ?bOr>UaXe{yB=q3?8R@C~&k`E*8GOb{YNacc(@(y@S%XL(v<>Ki31p(m@@==O6OM+*)qMsk<2BoZ*K8^MRwe;cYyc{EB_UPErat$3PHoiZU{e!wF_S!~706GIkB_Ya0DqoN<n>z-P(7Z?r~1~xz0}YTEL;bT`r>&~Q@C&69AIk}0p_P1IKZD*or9ZFGM4hl-V^8%0%~jwX?)-(&yYrS<!*(0j_a3M?7%Alp&q()!<tIoDeGo&30&W!d>u^ESAmv+P~^b97r98Ag<Rjf+dzhw+dv&{B;mVJ@RwR~C3q2>)M-Q^K54;^*v(9;wy^cH3=FBf#X=~qkZt7vz3|^bjk;qCem;*$;=R)X-w;bq?SDAGi(%(Nxgzf}9BcY5`jRC^p`c&XK{$W_!*Z5yAL8Jj<MWfF%M<VN=*`)QcY1m9{=)N5-+HGXE>C_qIrl!DpT0jj|Eu@slfO1S-T?Kh(%c_YD?fasl9wlcq5b#6(fbqi_44S43-$H*Bh~$IseVzL{LTCE!|8wd@ucxh1*+2zZ%_UrQ1u9?j~@yMpD8V%78UsSGj#w@QG<Tflovc{Nnk0a%<z|XshUv3vKn04DW8w|h^!Oz$z6p@I*}@GPCpPxy*~h4w<QI2wfWVMoUVf5{o5Vy;`03T!w-rc$^_;RpCP3;XCL3JhWgZn_w-~n{g^rc$f-mRp08yHuc)_-_5?E*mw!Dw>4E5a3ZLgE-=CbHd^lc#Ef+Orf#{+ih+}>D@$9VWV4(8WZRPuq=O?E>d_eoYZn5E6!0<z$Zbe0_Kc}vKUQ=CW+jQx`+|XzfwpHb7Q+TLczc~GHadLi%5q^|)^3&1TkHFtQHNAgoV7q{jw^nsc&6O6^i^AZ<`mLK<ex^(eb{<1!|A*eJF#6aj<yprc$$rxGKFK909w*XyL~-ZpL)f@<f**ZdO4(Y-P3qKi=+u-nS?QK1G@ZFo-Zd8vo001iD^Z2Skkr&8@irCo-eYvo?hc<k|8eldXasyK53Tr2eK;pk!?(BfMx%5sVF5vR6$H=rY4=wWFdcOKW(Z6){g;4Z2}m_iEFokoW4TSz_8!<YJGHQV*`EzRZ8&sq{%bgLGLPK|CN0Ul;ad;bhS;df2h5_4x?upqk(>CJ$e&#?lDM4yw?-s#tdrSYG(*@f?2}J0$0W$*4Og&R!XfNV+MX5VxKJQ&)fnuqUsz^<Niw+0l<tp8;~--rHD88-0dgt67niTNuWL>co5M_#^98t)<ei;Na7Qeg<8q{Tk!xJ=aK!eUY7Cgimj0zSSu8Nf+A=jywh4~dz=VS$CU~KZB8~D@doU}nYr(a}Xxq}_H*D+UI2@#btfayQ`2$>6IcGN8Y*;6McXGUWesn?foaNfAvx#cnU*4ZFMlzEfhJRVt>Kfx9GUl^01?+=(qg%aD{#@TjlZkiFIkl-Z*!he}j_<<O)+_WN20g6e&7;Yr^)Q`yD(Rb;C`a=No=heoyLM<RnA}vXESe?(JI}D1YzwXt5o8D&uQ!QV*b~DT4<8eu2nQM5tsFu;Cn-mc!h~mC-vu-6kmwe~sxD=26^1spq^Y|gwIK~xLaH}3^j3xwsNi9qM-!7ch4hJF7XD^aT#(-Odql-TamPPiTz-7t<4dGCo95o$UbnO3zM#K9lE8=8R(5F)Wr=<zUa8K)2gy9nU7xp;&tXjSz+tLGeYGBg{c8xDt6UvUh}Bagq=Y?k>Ug~&S1+1>{({G#AZj)WGBvB4rK^`dme(SuP?p={tsVRN#iQI8`pT10vY+umYj=dp(o@M0cl`opsp40w{<2hzRzm3oUn>7$f!JP<E6cZBS6IR*&pyr#utH5yqCOn6AhtwbT{%qVw8S_6F$bqocxC2P=T0a@g<N;4Q{r74*Dp3;1o%&A;u|@vGRNJrw0rE}rn7X_xjSNhVawg5S`qH(R!o6;0xsrWs3cvyaht;qJM7w|CXkoai|z~-N-jvgG7PI+CuU|b%F=2OTS%i(+yq&eF&ZWN-cQP2)~s0rc8>Q_wF~i@4wb!<xqjJncmxmL%RnU^>F(@QO8l6GZ-YF@!u)*{zlZ;=N=cGcTRRVL70>@ZNiRqc3gcD9Kd1}yMjKj)Dlo3kvNv=cg?hE5u~&H-y`zms(v_bMY1LF{nbymO&QqfmX`I!Y87v)VU%&X)CYVR*@5y`hogGsq+m{He%(pY&?6&njxX9&31y=2VYRL?f0iRB~s|J1Ws0~fkEeMrmU2O)jB?2fZvH;s{&EY-YG7*3GXtU&}Z(qq%l{%+au$3z3E_jTE+EO3qNs@o}Em2qcRu-x;`DNcd@^Gok`q#Gn#o+R=WaWML=nN8I+i$;p#r^6Q8fAMS%N%~Ohsia8I0ko2hcY#s<xU;C5vz?pN5gqAkqw|YZkzU*4Kaz^a)gs^UxhEhQB#tB+0#}4K?STkocT$`b}7<?*$axIYxx@3$@(i~RCl+u1<EV6k~eGCF$AlP%AM1KboQdISyET38Qh&v<78c<8x&G9wf<!JCYfm{0WA8Pmi&qxKuSLYpP8l=;FUqsO+PsqVEB-~;fUNqi4~E1J*i#V69GM&_m!sAgQp_=k1Kuxo@DoA5uFLOs6>-LxZ~88kfH)lx8eQm^b-ri$7vWSS^Rx6&O*{Jg7K6#jDF;O2(qBx^gfN>UdQ7+pJfNHUX2$+YKcoipX4Tz*+MQJfl<HP?(QyW>N-A)24M`>fVoM+`Tq3MQ;+q1Qn;@-i*Pxtm(qG~tv+m4BC+|M78wt-F+^eW^Vev`2W;yK%)dSP;gZ{w)V)cjT~~W>U#OI=?nCV^<v!%YjU~4+)!xs%@?xfCHjhdIMf-9l_S2XpxHM;J1C?9Fo7Nq*4K)DVl-o~|J45YeBsyduo6K*U#T~6p_lno%v(7!mHL_|!{`telpFi}@PkuT*`MLM~=^1+t_<E~I!&}@Hp<J}|)8hJ873Na+#;p<ze<3Es2W;iWaE1J)+)`aMXUq6mFbaFb#}J|52kBrOebyJo77Vc@`Ag~2nrCMh9Gc0!pb-9Jz8f4n(L6>!yr42?hqHTR$(mPOi#Id-UEPl76t;l<P5Yb4BcYaZ>u=Evjx{b6Sc>X_eaU?|?Ms-8de?$4H}BZiW|Sv+FyXs}aE>>h`ce&{IiWnp?kW%Ef@E&hO-f-k@}1Y+X?tILopyIyeUz{Hsw$;0AULx|!X=RvZvI{*B$}Yf_iri+V+E>GPvz;Gr{O1Jv=2Nr);KM%PTQbOrCL$e3;J0yfrzedbZND8eo}fb`7!w>J4x>$PxxBZ&Ovo;RtI0Zd`BA<lo&G)>9!W(LIZs)jRjgnwcY9nRW%wTD6vrkZuNRr_r6(MIN{OjYZmRSi3kl=6v#2l(yin{;oAY4szrHC!bhKPn#nvQdqA9!duO}}DB#_WgIzK5r2mVr+p{W`Gv;Wd_7qHC$X=kZYwc)Q%n$_VNityjArXZ3Len-vi?@6Mv%poj1;3~{k5?E-r=&ZF)%t6)QTsM<D=N<F`gW4^X<okGRJXh;PoYLdA6QXU+b-O?xalX<_l{SW%`?koRKq&NmZcLMV7eTz#g6TL4?iujKkL4o11%RkBRc;p!Dr*93ZUt|4#K6ExMzh!vbwNZpZD1`2V0MGb+5j!!@jsz-A1DB*lIMaRj!&=oYvt7R<BM>tPM?)+K)8H1qN!uWtXD42Fpe4tQexX1G!}uC_~hfvB%5!YjEqH5HTaOQZHCQGqd8x%LkHNTm&}XJyJU156;;^<WRm;vVM<rhM|-PcasQW;Ikj{Q4(xv4bg<SgXMQFE8YN?rRBnobMY{`#YCe@G3}*mjDc6KE0-8+vUEymF;^GU)Lt%Up_@Iuik~%|7X8)rC2#d|u{vxN*B9$OgYz2%q6KKhG>U1set(W=#99N|U;-ECS(=cBI?XuCiZ>-;7!xC|*y@UO(N=LGk85;RYg)RvDn@nVa9q2D8JaGlJ1_hI%=#B*BWqhM9t~%OMj2AO1o0qL;W5M|8hWkbiMeJG&$w0S^?#))`D8F`+dBjleJFkX;*)hLv%OUL`eqn1=NWA$PJ1Q<M!}edEu3}nd7DpEcy+Y-w;TKkHh;bOnyt^)eJX2!q34G;c#|t(=p9`gpPpis4V^nz`67g-$LGakJ}{G@DQEfH?hxRf|KorEm;e4h{x|P`{ICD=-~Z+R{Fndh|NcL;yDh;M&*MQPX&t!in3goIUI-Q*-@IoJMGV94R5C!WSYDb-uH{Z9KeA_2wR~s~tSnWR@Hi?EDK~OF^2gKiiM5diYn4rZ&SqqYnm1ld)5`h0EZz5AgjmS2?5Cr%lgrDK9($EJ+Bb5GH|%gNYlQ@T;%_Ek>j)W?-~@w-<=7i5Fi59DntjnK5Ug=GYhkH;;-hcjb5HE5^RInwp#mBT*g<MD>sSUqJKeS5R&embQQ8SDp!_}zV`>%>ai_~?SW%ccx|<n*?V%LUp%pZX)1~rl#<gBQOGfEZd6`#yb=BT{9c+${How1l++{}`Ip12J(gn&#0s2X&VhoT3YjYUg!Yw0wkW%)H0MU<-xuicGWLI~r_QW)A&CD0iNgvm~NB@{R{9P6J)1kZ4Na5yiC0FnpnB&2#n=k5rm{`jWD}qI!C>-j&twgL?hgFK^r>i!ngik#TJp)<%>^GrK1aq)|C1#;1>)IoCGI=9{Z&M9Sr45swIQJ5ByEM-N>Ppy7oC}wPLeybB=g=ga4s39Xa}<?H!$qh{kFXS>{N6&SR_8dY1mhIeBXduM%{Fk6_j-61(3nDTXObXS7LqXKj!rTr<7Gbp1GE}!d1P8`SvoXh8Hfh?dT{FC)FrxvXb}!yGq62A>9|$H!a?1R$gS@CJz(c9$;zM}IU=j1apw39{^q>2E<i?!Pm-j;DS}&0a69h-$0#9^Gni!MGU^6jF2mnF;YaH9uT<Q+9GRgvmnX|4mP+e;e>q-)zjL0DQYjOq^6||-pB!J(R{g_?_v86lshHA4QSjp9kLSlH-s$^t$)}Q#ri0lPat%(KUgZX9jVu#4(=7U|lfPub{~+<}`OW7-=xdpj<<KJYr#fjayW)yBzp=Y@1QbG@T=D8#2(mEhn14`MUn))CTfE6<P`0UxK7}h?!BbhY4yb6+u$LhA-d$dPx`3xyN_1+awWDe6nVBpDTe5lBbyk{{t!9loDK&wAxUpBx;O*iD3w9IBuu)3HKsEgWxK&nbtCU!(zW}jfcQB|Gys~!^o1@ckLi)>Ru}eS8inWN3;O9Yam`phlGO0r(k55(ur5bRm8j&YY=WJIRDJP!d%IH<yVi~d9PbnLQ%|SFLGZ`_ms+0Q~oIy|h7qW-?gMuY0TW0lKXV<S;?MKvQyeW9uR5;a=1xp-iNQx1-g3z<L#d+2W)ao6m>25FoUa_lK=-QZdu_}XI3%NRZtugZyX15#3%wIi9ZPc1j>$T-&Hq%P8BAIcv?e<RDD^#~#V>P2!vm^_Uo`&?pN#@^=7d<#5^EphDT|b~WhH1|chs7Lr3@}9Kg3?`NJxJ0`9Bbzxcg{Vit0~KFu_Zbvb#K#y^QvZ3e%1*6^Si(HF5jJA^nU(${%2q_oX+xvx?YqO3*;ZTPrMA5Vi7c%Qu;B#K*@l7d#yGf)SX9^22@6%jA^wg`Tf!9hfDhZ<h=Lc<K@Xk!8>UeZ+Sn;w#m@*MeRfoeD9CBVauG;EBDZ>5{)f{k<VvDh8&O0?u`<Yt-TuS<FZZL|G14*w2K%awG}}7WfXUF&H2V`OB*Q?(W|odLV&9cJRCT(Ui&R`BPJY~pWZBC3U$89ou;&)gP2R1dg}YMe5HSX&)m$7PKuu>_sfH-$K>^k$ER-|pPKR?`_Q)FPacqBhchQ%11t9seqGG5@&R_acv0HeFU)8izsgaRW;p{@-+8$sw#S>h)V{FlW|4u<c&>AjJHdwK1U>qHdb{@Cv~nf>RnDfmg0q5?$Np2HQmIO^Ri$p5O}kp@5(G4Xgk1tD2h!#yeD~{l*)u*5XtY{Yjeuj1ea7~9Jf8VY1OC3kdguxX(cN8lGT;O?PHTec2j05u1deuP$jJy1Q(cL!daZHXh^QkA!YTQ?%a)WwSLq%oAuk+>{atDuNiE>Q4wXVs7gamd3xQBW4+>-oRDc(sG0+{U1a@p|9w(o)jb93lxu;NN-!uKSKfLK2u><m40y)t1XhOyN`DeJ)*qe|z{&BlUz4$k)c~mK`2nelJS`s2BijjCy6FY4E$syjSTRE36_FnyT^6?nl+7fI8;~8F?Gj!usc#<%3h#RS+Xa>U&y~+_9CEtG?ox=5c$?e0R@wd42epPYT<Nd0h!ZxmE1;2jjRWk=RwuzbAH&$wB-&prsjSKAc-HdXbzJ2%GS#lPTyCxI@&>@%85W|U46zki0-boJV`wKr&o^RM*LO9<w#3Z;A5ox`#Bo2jLpOwD(=<0TUacA{MtWO_-27Ti2S2kVi_pahCv(=Rlwn|~mRx>MIffS)7@V6Rvvv`(qYI)L14qT5H?x4MdW9tL>@Wc@{+ZSwP4pkYVnSvXQ>jhj?STh}%1&C2;r;vMEMvtwgT+VKfY}fSL^-<AkYOGcuXV>VUT-^`ld+PhJYvYH%*!Iet0cckxD;rd73;)~xK0p`u@I#&C&^(xtmouCGjt|<1TU2%-pA(i%<h&ON=Ryg-@JHOQfm4QW7<7esQdZcr7s~lBrA1{*T#nE(8D>aST7lhcitYovhY1J&)qRXt3rLR26+|WBgtv=e)d=^&t+?r{x1>$64PXFUSAOm30q^&KrsQ8@*!i9bm5IaUOZNu)dQRwXeioRAEgyS@9qJV)O+T&Jcq+trPI8=xsY%t(FtXX48}Z$|cy7G)D_le{!Z?LKvTVS_jfMIOY@)tXX8P{Xt>aLB*N%bI-(}XUz%(3HsoXfQTR*gQsM+Vq8&~psC$Y&}=yJ5Y(tcaA3_~72FmQH#@B;W;P6jI{1oJyU4yf?{f`lt`Ck9td0ZLQkvek{_=6p1rHJgVoA!#1`O*uj$J0D|=1GoUafAit^zaKvtPw|X|z|InZnuK>|C(Kszbv>F*R}WoCa1MZ>w*al{<EM<6!rDsNHmm}iSoHBq6gR_x9|Bwk!7)iCpitluB6iZUTD@?M*Y9}?eBW5-wcCAdZRp&foCNlpF(LS!cIK}RRmmtC<r}#bn9c-l5$r9Np(uz-LO3~V$v}xMMEFZR9jT#7O{Uj?RnRqYH<<+&*4n8hUk-z8NFgS&&iZK@_GrPDZx$|C=L3-(=cSgCXW<IFUYHORnk*=x=ySk@UJ{t!r13~kdj5J5;H<-sl7lyE^vkay93?l$qT4MX9|UutCWV1s#kGdI&)kWmDqllYu0?kuDTNh1z9Z~LRN3awo(AekZqiRpl7btWZQLDDsKh3#yzh~_o1I=k3fHhCzT>DO8~KAbdLO_1HAc+c>v6vsn#8-&{)RHsH43$~<FBqJ0&bI%*M`$7AXX1Mm+*B1<oUP*;9a~|$r=Tta%`-$Y}wZ1OwD(>73+H)!C2qIE>BmFYPI3A7X)*XDRlcFoUK=NZ^k3U&><&5F&cgu&$O3W!LzRvs*0+G_h;m*jt=+N$W>KtgON*TT@&QvX&SJVO*2$mk&~B4Y^|hebT%rSZqkNH$7hU2Pu^miJfYj#Q*yN&ed9ZyC(Kj_SyvgR|0&Y0pW5xV`5$Y~ZoA3hx&wn0U`%_#o0}h%8cf8M5AHQmYdEnB1OP=#j{Yq@TNa#bsMOdZZ`k#H#X;ougFhUX^KJoZLv(yq0_iEZ20kUjM<lcvCh)WC$Ob<Utqt%~96Rr?$n^A-KpF)ck6ZWN$L~&0PLB=_4&eKEG{+%`Id53__jHa|t2)qChXzjP)7$lJi>P&rk*ekF1ghGN^Zv@dvWc?oLFqoeDmT~34kz^8wZLEeyMrerjz9>JE$f7MfsLI68F5-H3)S$MQYzwv4W*`e@<_j8!x<Uz(2eD>EM&No9k}l48#uTBg4f+0Ce4CV5-Cw`?M$71o`kDPNNk8Hjaa3^t1~kGS$bDf2vVcuUbmPy1aB|3a^wO2YowU?Cu_I^t|r417|DhE>I{jR3#RwN%XkSjfpBz&bf%BwsSeLBm!k<U0{*zwJKa&Y&QVyX5U;r$p*jL0imwSLCAawGpNKaZJ^ZO}>BO%;X}oxmJmPz9Xdi0$1E$%Nxb-yRJ}QCU?jCB$^8zRf{Btd`U`BJ$Pdzrg(pjM23}*t|2OmviSjBak+;8x?QAkV9JgL-SOdqIod9!RD9;DP;5K&a<J$N09&}*|;XQ&!L2Ej1K5rN4q#fg_(GS_zmH7EDg88@n3@4t*Ohm5+_HVoj?N583#A*sBt$^>J%MkfKsws0g!8GFo41MdXDkI_GgP}mqmeleL~YP%H(26h#|UI*}ni#g$!EytG#5`h?Iw?170WUgKcGzy$9<lR37F$3BgEp-y$#ZhoVlLp~2NGBONxOkr;^4J-ouED3_aCpaG1n&WkFmw0|XRhm}*ymwELas1;g6aOklN1Rd7#tH_Ud+KFI9fh5;f1(fff(1q;T0YW#KvfrFG5%{kAB;`B@-YXNSFX#=oEwB-N%;T3K5*$+wtN(SSM*ff=7d6{S4%+z%&&hYA)u~3WrlU?SO)*Jb;E*FxNTwy-Cuof7K4#EZnDPXa~Me9?&RLDo<k_Q+KWOR-cy?w@3qmhD2Ie79Gq<Id$!)Cl850P1xU{R8Fh70;RPqpKGqH(h!UGyO!DGc4N;nJFj7k6F~J$xrnEGB@bS;lZyA>@typXyIap@1Be87BFBhrIoq_79lfFI=U40!uXhDjEI~Pm?duIzOFLfuW%#h3Qgr*MF0~TFsZb6@;s7M1QygDn@uSJ+KMDPkyo_*tS)uk@P2G7wOxEToA#oxxqjU%x<QM^O-zlq3R3HNM^PBVsP~muvxPfaYIw-IscMtA&bqww#g<~+3`19t0a5iBuU71pcGQUg1kbojXt@gh6le3!zB67ms<@T-Bno<o>k{-THb33XEV0IiFmN~-?v7$VpQ~8j6xW;2wQ<@z5tW#x+4)1%02rx@=(jL?RwohyWyxK6H1rlvigbb5LC318hLVnO2`T^1qt<e$zAz2StI_W2XQ93kOqc~^9!sx_e(v~p!q^z&*l_x9g!`*{KYWN)sQ|7Fq&AzH($q7`|3~uoNENr(U*`yfr!P9p-pkSe*YJ)o`p3X2s6rhm0wXp_`Vf+nxjz@G3?)IQaIA{J8Z%yP4Z&bXWqXYh2!mK)snyYn@WHK9FyJ_jy9OXWDTG18F;7CzHnE~^abpY3a4|s|O<pmejrevSJ9nGhcSm5m_#~hngs^q}+3iX;b!vgjfDJ;|6D=Oc>Cbk513q}Ww8YUzS6*?aYDlW08-35;C1RLfyfnEd{)^AoIiKQ8`6Wc`iJvaFhaDoK<U1$<BbYb5VWLW0q6NV;HQCgl@^!WH7aqAmYc!2Fo0%`#0kH8GTK;`v}a=}Ow6}-xT&ouDoe%-VoaQ;E&ILz{4SXBE#oWSU@0Er7R5I}7i>a&#D9|kS_+ASCi#{;dNvYP?$%1pLF5CE~L)0Dx|SVGpXOI(Y*?#SSp3+NjZ%mwM$%M?5x!NQ$zpcepka-RrB5mpl9TY=G-Ln`-<S+qNgJ?wN;K1eHmsx)?nV|Ky{UTl4LC5IY0%Fr>Rm7KS<j-FT*{bDZqdCQ}Hj>zQ`$jW#GG;B9t&f>!W^V3fo=$_l3=xS!jtV?ENoR3fx7>Q@K6|H1BTB4rsWG}c-FLPQXUIr_`%H)JXP%p!{xxK2bCwHDK?irLX%#TK{=!JJ`hu-e1JcV+_jgWLhTkLCG==<%AH|F3_71behyh1HoNSrzLW7iC(9^Ji1wdDvTlb_}Q!HWB&#D0iqF#G@+tZ@bw!mR~OU3pM!ft<dya7={L?eOf6_wNVir@#Mk`ss6ado@g0w?LyTEFv9EFBvSo+dm_k$9vBIrgsBGK%!o@41Sx>EG(B$2H=E#O`iq(wiTES3}oNn{NM|{I~$yw{`&sS=hKr4)HcF0b%Zhe2E%WukJ(b7lp=Fm1Xosw{P00yjKPIRsHV8<xJnYYHCQc#A9l;t?-baM(nZ0daFB{WQbYF2ttXr=+R<&$2X3_*6cd+W%g7LLLZAtaQX+48Z4`k%RSd}ULs1GqDqFE&f`yhV)yHA{I{nU~$;aW4YTdbjHG8oqR?4=&&k@2hLZrl8iYeScLpCG$7{<=&x014OA{$|%>Gsga4|OFt;nlv9S7{DK?KeG~IL42!vV?JRR*M*cBgVHWcOxl5y-Cx5Ld9GxRu!mhFq>1hPvB154wFEI8zFw{R-`s4<(HVB=3Q!kA5o0_Ic3j!s_-QmS26jUp<4!(3ss~-c~-4_mEc<P*WGnECgWN&UBZ*dp0vQLPnF2Mr-h2Z4$wHI{zL5FB#S#N>(t0Z6o9(}LKmIB{ERU$Qhn>oWG3Ghf1-(Jq$ray3z_mL&k-vzIKBuD+G^RX_k2os35L$slZlff3JS`;Vnzi#)CffbtA3XBwKzaD^Xd0TqG-_Q6c*#rR%T-}8W4M%|5uUOkD63w@=<9(vEu9x4ybxDS9!K-TK+oOAn#Q)!)KhDR#f#Lb@D4`b}Z!8_pmU^{roBitlZ}>NUr6|AP@dfm?~R;jl<XZ>6??^PMu;{Y3r@=6e)8RRaRNnfv%?_N4*TwIW*&PyL(<v81lwvjn>JCJUDzy_o3h_%XvG~?NESxUJDmr7|?UMSkDMV;0q<*S&aj$G0=t%KHc)*D#MYl$PaPhBG~Q{#tDFbTyAH^aTQ)is-e2L9#yG)o)l6Q{V-y`xuoz8^b!Axj{Sx?^4RmS@*c`m^T)6~ljA_}ePKH-f_QgIfM_Zfq!2PU@@y@xIzkwsBWOCTCIpJL5-OH1zIN5tr6@MNnh_l#t0l!haR2fn*I2%TRYI)7Hd^7~ZjPkSP)aj*=#)tuPRP(ne?Bg#pni7u?8c|I60;M84I=h$WmST4(Lnbxv2C_N@zW?#56a?`;2jXc6W*l)#gso*p?}Imu*jh>CkPu9XGav|<WDhBM1L<((eEbo^luTaDJ}d^ycdDHY~L>;FX*3xq>r8`u^HE~5>7qshp48#&Hn*}A|=}"
MODULE_SOURCES = json.loads(zlib.decompress(
    base64.b85decode(PACKED_MODULE_SOURCES)).decode("utf-8"))
for module_name in ["colorlib", "adjust_colors", "notebook_workflow", "make_preview", "make_samples", "make_stylx", "make_hecras_ramp", "submission_workflow"]:
    module = types.ModuleType(module_name)
    module.__file__ = f"{module_name}.py"
    sys.modules[module_name] = module
    exec(compile(MODULE_SOURCES[module_name], module.__file__, "exec"),
         module.__dict__)

from notebook_workflow import read_json, use_arial
from submission_workflow import *

if IN_COLAB:
    SUBMISSION_BASE = Path("/content/rang-submission")
else:
    SUBMISSION_BASE = Path.cwd() / "cache" / "submission-notebook"
SUBMISSION_BASE.mkdir(parents=True, exist_ok=True)
use_arial()

def receive_workflow_zip(local_path):
    input_dir = SUBMISSION_BASE / "upload"
    input_dir.mkdir(parents=True, exist_ok=True)
    if IN_COLAB:
        print("Choose the final workflow ZIP downloaded from notebook 1")
        uploaded = files.upload()
        if len(uploaded) != 1:
            raise ValueError("Upload exactly one workflow ZIP")
        filename, data = next(iter(uploaded.items()))
        if Path(filename).suffix.lower() != ".zip":
            raise ValueError("The uploaded file must end in .zip")
        output = input_dir / Path(filename).name
        output.write_bytes(data)
        return output
    if not local_path:
        raise ValueError("Enter the local path to the workflow ZIP")
    path = Path(local_path).expanduser().resolve()
    if not path.is_file():
        raise FileNotFoundError(path)
    if path.suffix.lower() != ".zip":
        raise ValueError("The workflow file must end in .zip")
    output = input_dir / path.name
    if path != output.resolve():
        shutil.copy2(path, output)
    return output

def offer_submission_download(path):
    print("Saved:", path)
    if IN_COLAB:
        files.download(str(path))

print("Submission folder:", SUBMISSION_BASE)

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 01. Upload the verified workflow ZIP
#
# Use the single ZIP downloaded at the end of notebook 1.
#
# </div>

# %% [markdown]
# The ZIP must contain one recipe, one palette draft, the uploaded artwork,
# `check-report.json`, and the saved workflow figures. Do not rename files inside
# the ZIP. Renaming the ZIP itself is fine.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#fff3cd;padding:14px"><strong>YOUR INPUT</strong><br>Upload the completed workflow ZIP from notebook 1.</div>

# %%
LOCAL_WORKFLOW_ZIP = "" #@param {type:"string"}

workflow_archive = receive_workflow_zip(LOCAL_WORKFLOW_ZIP)
bundle = load_workflow_archive(
    workflow_archive, SUBMISSION_BASE / "verified-workflow"
)
print("Palette:", bundle["palette"].get("name", "missing"))
print("Recipe:", bundle["recipe_path"].name)
print("Palette draft:", bundle["palette_path"].name)
print("Source image:", bundle["source_path"].name)

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 02. Review and validate the saved work
#
# Confirm that the ZIP is complete and the recipe still reproduces.
#
# </div>

# %% [markdown]
# This check compares the palette draft with the recipe, checks the palette name,
# colors, order, notes, Persian name, pronunciation, source fields, and reuse
# information, then replays the extraction and adjustments. An error names the
# field that needs attention. Return to notebook 1, correct it, and download a
# new workflow ZIP when a problem appears here.

# %%
problems = validate_submission_input(bundle)
if problems:
    raise ValueError("Fix these fields in notebook 1:\n- " + "\n- ".join(problems))

verification = verify_recipe(bundle["recipe_path"], bundle["work_dir"])
for key, value in verification.items():
    print(f"{key}: {value}")
if not verification["verified"]:
    raise ValueError("The saved recipe did not reproduce. Return to notebook 1")

palette = bundle["palette"]
source = palette["source"]
print()
print("Name:", palette["name"])
print("Persian:", palette["persian"])
print("Pronunciation:", palette["pronunciation"])
print("Colors:", *palette["colors"])
print("Artwork:", source["title"])
print("Object page:", source["url"])
print("Public domain:", source["public_domain"])
if not source["public_domain"]:
    print("Rights:", source["rights"])

# %% [markdown]
# The three saved figures below show the regions, k-means candidates, and color
# adjustments. A missing adjustment image is normal when no colors were changed.

# %%
review_paths = [
    bundle["work_dir"] / name
    for name in ("regions.png", "candidates.png", "adjustments.png")
    if (bundle["work_dir"] / name).is_file()
]
figure, axes = plt.subplots(
    1, len(review_paths), figsize=(7 * len(review_paths), 7), squeeze=False
)
for axis, image_path in zip(axes[0], review_paths):
    axis.imshow(Image.open(image_path))
    axis.set_title(image_path.stem.replace("-", " ").title())
    axis.axis("off")
figure.tight_layout()

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 03. Describe and confirm the proposal
#
# Write the short context a maintainer needs before reviewing it.
#
# </div>

# %% [markdown]
# `WHY_THIS_WORK` should explain why the artwork and its colors belong in Rang.
# Keep it to one or two direct sentences. Use `MAINTAINER_NOTES` for an unusual
# color adjustment, source limitation, or anything else that deserves attention.
# It can stay empty when there is nothing additional to explain.
#
# Open the object page again before checking the rights box. Confirm the creator,
# credit, reuse status, and exact license against the source record. Also inspect
# the four viewing rows and source distances from notebook 1. The checks support
# your judgment, but the palette should still feel true to the artwork and work
# well as a visualization.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#fff3cd;padding:14px"><strong>YOUR INPUT</strong><br>Describe why the work belongs in Rang and add any review notes.</div>

# %%
WHY_THIS_WORK = "" #@param {type:"string"}
MAINTAINER_NOTES = "" #@param {type:"string"}

validate_proposal_details(WHY_THIS_WORK, MAINTAINER_NOTES)

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>YOUR DECISION</strong><br>Confirm the source record and the visual review after checking them yourself.</div>

# %%
CONFIRM_SOURCE_RIGHTS = False #@param {type:"boolean"}
CONFIRM_VISUAL_REVIEW = False #@param {type:"boolean"}

if not CONFIRM_SOURCE_RIGHTS:
    raise ValueError(
        "Open the object page, verify the credit and reuse terms, then check CONFIRM_SOURCE_RIGHTS"
    )
if not CONFIRM_VISUAL_REVIEW:
    raise ValueError(
        "Review the artwork, palette, and four viewing rows, then check CONFIRM_VISUAL_REVIEW"
    )

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 04. Build the submission package
#
# Create repository files, test files, documentation, and review material.
#
# </div>

# %% [markdown]
# The `repository` folder contains the palette, recipe, source card, documentation
# page, and images in their expected Rang paths. The `software` folder contains
# one-palette files for testing in ArcGIS Pro, QGIS, HEC-RAS, and GeoLibre, plus
# Python and R examples. The `review` folder keeps the extraction evidence.
#
# The software files are deliberately palette-specific. They must not replace
# Rang's combined collection files. After copying the repository-ready files, a
# maintainer runs `python tools/build.py <name>` to rebuild the shared outputs.

# %%
proposal = build_submission(
    bundle,
    SUBMISSION_BASE,
    WHY_THIS_WORK,
    MAINTAINER_NOTES,
)
print("Submission folder:", proposal["root"])
print("Submission ZIP:", proposal["archive"])
print("ArcGIS, QGIS, HEC-RAS, and GeoLibre test files are ready")

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 05. Review the generated files and images
#
# Inspect the proposal before downloading it.
#
# </div>

# %% [markdown]
# `README.md` explains where each file belongs. `PULL_REQUEST.md` is a prepared
# pull request description with the workflow results. Its remaining unchecked
# items are repository commands that must run after the proposal files are copied
# into a branch.
#
# The gallery card and sample plots appear below. Check that the artwork is not
# distorted, the palette order reads well, labels fit, and all panels are clear.

# %%
for path in sorted(proposal["root"].rglob("*")):
    if path.is_file():
        print(path.relative_to(proposal["root"]))

slug = palette_slug(proposal["palette"]["name"])
docs_dir = proposal["root"] / "repository" / "docs" / slug
figure, axes = plt.subplots(2, 1, figsize=(14, 12))
for axis, filename in zip(axes, ("card.png", "samples.png")):
    axis.imshow(Image.open(docs_dir / filename))
    axis.set_title(filename.replace(".png", "").title())
    axis.axis("off")
figure.tight_layout()

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>SAVE YOUR WORK</strong><br>Download the submission ZIP after the files and images look right.</div>

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 06. Download the submission ZIP
#
# Save the complete proposal package to your computer.
#
# </div>

# %%
CONFIRM_PROPOSAL_REVIEW = False #@param {type:"boolean"}
DOWNLOAD_SUBMISSION_ZIP = True #@param {type:"boolean"}

if not CONFIRM_PROPOSAL_REVIEW:
    raise ValueError(
        "Inspect the generated file list, gallery card, and samples, then check CONFIRM_PROPOSAL_REVIEW"
    )
if DOWNLOAD_SUBMISSION_ZIP:
    offer_submission_download(proposal["archive"])
else:
    print("Submission ZIP:", proposal["archive"])
