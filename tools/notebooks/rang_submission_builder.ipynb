# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohsennasab/Rang/blob/main/tools/notebooks/rang_submission_builder.ipynb)
#
# <div style="font-family:Arial,sans-serif">
#
# # Rang submission builder
#
# This is notebook 2. Upload the verified workflow ZIP from notebook 1. This
# notebook checks the saved work, creates repository-ready files, prepares
# palette-specific files for software testing, and downloads one submission ZIP.
#
# Created by **Mohsen Tahmasebi Nasab, PhD**<br>
# [hydromohsen.com](https://hydromohsen.com)
#
# Copyright and license holder: Mohsen Tahmasebi Nasab. Notebook code is
# licensed under the repository's MIT License. Rang palette data follows the
# CC0 dedication described in the licensing guide. Source images keep their own
# rights and reuse terms.
#
# </div>

# %% [markdown]
# ### Contents
#
# 01. Upload the verified workflow ZIP
# 02. Complete and validate the metadata
# 03. Describe the proposal and confirm the source rights
# 04. Build the submission package
# 05. Review the generated files and images
# 06. Download the submission ZIP

# %%
#@title Set up this notebook
import base64
import json
import shutil
import subprocess
import sys
import types
import zlib
from pathlib import Path

IN_COLAB = False
try:
    from google.colab import files
    IN_COLAB = True
except ImportError:
    pass

try:
    import matplotlib
    import numpy
    import PIL
    import sklearn
except ImportError:
    subprocess.run([
        sys.executable, "-m", "pip", "install", "-q",
        "numpy", "pillow", "scikit-learn", "matplotlib"
    ], check=True)

PACKED_MODULE_SOURCES = "c-rK>>vrQtvM%^4=<?o2po?OW)U{;G`>0g1t!~xjNV47Ck~SM8K@k=SumP|nT3fT${FwPQ?{R+5nwQyo&C5)D5t)fh0Hj#9ch5O9eJK$@ULqqSBO@XsA|GE2l1Y+IqW+5m@5MF$_hKBR;n3p`-ZaR^-iUtW<Ip<~;#)6Il1bLOj<4h6<WrbtUUvT78+z*<pPrl@z43y0=$##pseX*lQ4(iO)!3&9kKQmGMT01e2MaHYrt?XV)7$Gf80BH=y$c58V3>Ge?gf*U=Xcxf*NrB3PaV8Hq35=0ZWxV5VM^_UP3{$CX2B%P^YA*JgrCBRHx4H=z}TNhliZ`e^JL~FBNUysypQuV^y2w+wrF};!u9XR$t2`45*ShJrSmwuj_;#<oXiO#)pN$+hcuE|7!NTLAVlyNN7Gr7=3YdjVO*IvKW7-GdYBPn3GL=N4b9JaI-xJEH2nKK%<}7^4uk3inHSIS_Wb1Ihu-;z50~DdZm#u_{`$S%D4K-5UW3}mlF6sgZ?tAKsd29UT*n`e&Q2~bPkL`p&#89N(kt)!g~DNm!5kkQe_vl}Kob?B$aVaM_c2X=4hK0QCJn<l0-21dZ$jpfsb?C|80J#~GfMBH%%00RAuy%6o>0MgipD-g;XRrth$CxxKTxG8$KWvuQyND^=w!l(J%VI#$MZL$j<PY4?<l&Z*`;YY{&4o;{LR_v`?tNz@6S&zzW;FcmIkxmY76L_zwtjp|4j8kA5FgN{rN9{r5@s0D@fB|;a^>~Tic!P_Rj8h(`&c3cJ_Amc02gl*>7)e?d{w&uVb(BAF9>uba(f<uTgZbv(wq>cJZ^l*X``>w3pUucV2I8ZE>wm=XK|Gw~e2#ciLO+?as|j<2wH7`_s!42Son9z1Q?Qtv3I&zrVkQqWCW@SXxOBy*%lqw|#%yIFO#l)Wo<o$?`Os`PVPLxPH-)4{4as)7WZ0igSN_6&*z0ORsxF9qcxkE+UWCm`^>@z_uIoVKhmC-0GJ4L$}nsPd|0XY16xHdVLu|nh**3^kXm~FsKxbmKxmIX*60vmM><ZPu;tajR@Mu^q}2+czV2*KYjiq1nmqt01P~U@L`Y)!E7e8ad3zp6g;x@FNyxL=r$(m+v<9KqShmj22~AjiNss)PcFTA77{xoDjor9jJ}ly*)*7WShB)b(c({I;vXLPjyIaq+Tbp|DDyUnaAx3Ji*PbY?)g=BXSYe5D;kW!uW2!4SPRn7F&Gvtnw%!7Kc_a&k1mMG&WJ5~_bGLf0f>uvItm8iw-I#}PQoei2*6T|O@2os>Mx43JRt7pGfXrM#N-+tO=g_rHJ^cd{k83VeW->)KL~*b1qr7C_`;9DWFDTRX_68_Ny+Iv%e{U`OU$5hlqOSZj5Zx=qo6uN6_{}UlaSaajL)WCnZ<^x^a&lJiUR9vue;sw{>}4K{05!U?_2!d$Ire)MpAjx>v~^)i8&|y$g6J-)w>R%lZM4_3(CqASx=%k3{rof>1d$VWG2gIpw|O2TpB1imb<#{$F%?X10a)@{dRkMhqhWO-08Mn(~9!x(@T6IO2u3GL11-T+twNrC;$)OszAfbstzh%XPw4spxRrVt@eIXK=Quy22FtjKLLv0!QcoULZgE8OP<v-3z!6bn*}^9ej)Hmh{SjAzk1ApTiB+U(Mg4oj7FeC?Qa;o{e3JR46~o+cu&LHYwhjt5f~`-l4t<9BT6U_l<0hL=U>q$Dm%JrwOTZ`8yZJvx0W^2e|BiYqcN+(Z4@>Y8_Oznok|_6QuhWtbF*VlX3*D^PCqra=%-6s^rB$4jGhG+0lhY$y=3a=p{pVfR0UY4vM)VTlmL2#fi>}dvv}XddxG6Tzrq<ewLo(k{$fteB#n3lIrAj1h_XkFW;HSNho=mrW6ijlsS<gklmCiN=zTD`ZAI}Xp9!YXx~$@n#6TO5XT-bB#<LWcmF@40DQvu$CAp9K4SpVmw<IlPytdK-G0m<|4F!#c_s`zeZrk2{2@Jgk=%)qEag%pp8=ArRd1#IaQ=s{TdryO56vP>A><#mY_;~4)hUc?HCN1+9vYh8@5uZhSw0A+WI&DP@a0cvPX*8g1iT0>T6!IP^Q%HYq$GJy)s;D17zU{p`x;#JqGa=wnZ&tH3AxvJAI^)P+ke&8-h4*xK_KAcxNxW)r@9*y4EL(RXO?5ikBssANw!homXSuEY`gOOnyRzaY^S=H4F84$o5ur-=o!77TZ_H}HelZN^br5gu?rn*@x4+xo-QE?5yL+#ng}A#<%Vh^ONqF383&h)d+nudvA?|ecMOticcVBOd+_+1kV8;fS=BEm9r$tPAr@Jr1-P_&Ue$78Sv@Z8vKil!%{&t4}eNDSXTV&Vmz1?>AnX$HMU|T#pyRSQhG8VAgTd&(~f%plO^5f~n>4*2d%fEa)xd4}YpTs1^6|~Z{W}#^fuwkl_VtaCix{s)PKxN`2ody#{-cqd~J^eeGMFD-Q8G$|R@;gjTc?ZY(w|slDga}zup@_V9Q9N|T(F^sR^yI;q1SVR20|jr3iyvYviali5W=R*Ll^NfL!&XV^Lve_jJbFuJD_D!-J`76@_bD;q`hB}t(O2m3#xUgHuBCw$8J$yOkhJ(=h!<etM1Ayc*YH+)4(R{=4$V3~tJkz51NwizE3dms%BGUXU17wE&2!y`&G@;RLd!9WsmC4KNRPWL-^u&$JV;HDjz}=tWJdgVl1r#KZG3xF&io`rYKMO{v?v>NW&m!6meKHc*bf1R^<?0k0pOVn@vI8+%z}B`QRVA4E=Jc(?_H`wcSQw8WU0dNjQSfMqt;oMhJV%(C^rGHAx8R5Lt*F%Sr$1C$1_HsYAu{l;h;~O7dJuRHz1Uf(p{-zN?0|`JCZ<F)}epR2q5jRDEZPF>-YH7Rl6-uvL08Xb_=Gqm{8Pgob@q<eV*+zOz@e|QPbmwUP?oTuvX!1%&iD~1Zx?4Ji>9e4trA5H&v|;1&8{B_ccboqNbq6sqbL2Qhu{k{!+*uT102BUcBjZtv1mdw4&~IZ7IwMmDG!h|AXRN-P+<?Qk;tHHbjT%wrdM+tAd-}?v`1y!yMAvmZ}jx%=}H?SAcf+c0}<Ll}%SUAC$?4N*BywR^bj(?P5aJKqfx6d1f$Y+|5o~wNLeRlQe{vmG7#Zfocab0-B*N)t7PcrK7&kzn2Q^oW5>WsTw08EHps#=L6SBgKfmuF!{tB2*ittfCB)*Dd^3>dh<QM8OxjHk^_|`fWCB^uxdAchkZwzqCK%h!;r4`9c=~eO{2Is4TBg)3D||quI%pQ@09fvMn)93tf&1jzYoKh?Wba!M&p^Xs$zdv0yyko<z0Oes-9_Od);SjF*y|vvfRt>6X}U0^c3R5-{(;p4viH?R8321H*!iLEjq?Tw$hB1l_tzcY!hKdFOiIzyK=VbtLTO|>#Lt{lo_$<{fq{T&7BtCv`_jS8;|`IGL4VXLY1TTyNw%%(r6z1Vb*9CB*(KtuPhzxo`#(F20<1oq`A@-NrRIx%L^0tFcL$U7Yx!Q%Z!QJo{`L%5(}E;B+|Gd-5i6y!-#FswgM{}se@GvmGSK)^ahh8(@^7JM9-``PO(7sSSg1Mehlkj?1J7$BZn*>Dt#XiMq=W$fwZXX_ofux?b_5Js9}0IaCya$09#6OZc$oCJa{D?!_+yX<%D-MQwLQZq)_D#n=%Y;T7LaZzZ{K2<X~5n?yEx~nP~`C!$mJiX}#CY^_zJ#k+~##98eRXH;V>$9#`<PJi%EX+nGaB%Qe$7c4#g}5Mp>}gg8yEOwGb>B5y?eCilWP$3dIhku-+GH9Z18(!$|RtVvDlANiOlQ6Lf6NZ5#Jg2P#k$xMUk%*#-pmXtD0p8(=44`*I597^8;R6Zssr@=!sjeZehxH*9;Sf^Q^xq{Br$68IpV7OpZg)~t=&xfQHtz5}KOj5vRFOC?xf}uBsirc<(0JECV4QmB6e7rlTT{WTyHX8NZ;Ym*^s0L&Au}&IQZ4T_mq5bUY?ncu;|JH1`o&)hRWSTg{9QZ4jVa%%!)4VvG1k?U7@MZ@B-j_xO8-O%`#4JhkaOiXE>KoDGBxLMLDQso2Gbje+Dk{#KbkBU8A*U9x>f@%UC@)&f>xMoCf~FiuqXXGF3^KWopNr;<oF^1bU=Z&n$*o|K1j}7hzzXB}G)ys(Qkj-b9;EqU$DSjz9uK*y!x;Em!5Q>2>}B(Q7UsT?c2kOxl2_dm%$l5rxz}GP;Fhew>b`X~;2{l~UW)R+L^HQfM!2l&n*vOn>7=uSDOeXT!DiqRbHQX`SE5xpN%+7y6cDNFjBSKV53b_nhgPw5U`3SFSuGUB#o?4UOR^}BK85;_$_PZ%H#(6atSMw+Bgu%v3^YfJvZ|zohM~%Js%!X4dLweXG3<urD2vSugj@$qu3TJ|g{K1*y(y^FSvFR0C>KF;=Jm&IKnLnTm+)i$RTTai{D77V&gO7<<ksohn>dxs>D|v3-OqEq6x}0XY?_e#<tGj;a6Y0wK&l@#-0hQEDu{1JYZ~O-BPlDI2DhOWv-qJ0uZkw`Fo&HzmnOeY?nQW#eN*{`M0ti&$-v8q5+_8PvxJ5V?14PhjLybMo|qjL3y*t~IUddjRE^pgk)(y)km~M3&|mPMS@b}Pv2uHW*?i&s?Qa0^Z-0~KREHUTB+A12XnE&qi)Bb@fCBAC=3zB~KUOzIWl_>zH6g(r=KzvqMANc#mKiWx?V8Px&uTxOo_WfN<rHIW%AXIj%#bqg<Ik=*E@c*-UM`(tO-zY)blap*N26X&gqzXo41IpzN{EX5VtyNqmbfbA)I9MGtEpB#o=^L65KVl49|v6YPeXy;IuCh{NtS7y9lbyP>xYYF3Xo+Uji&6ALlSi8<0OB}xG0Ftv~hKCfFU|7@$soxiG@&LFT)_c4Rg0sN1m|O*3gkUihW+%XnL~;VGFYdK6nZGw!BO5T#d2!2)O>Rg$3O(ijxn?cfTRp6Bb{G5VmCb{WhC!p<O4zkmkS~l+j~Pee>gBTGFJ?NvhLTvsYiEz&9=UWwpGc!GJcp%-i@=K=TuCG`)>G`Gw6OVE+tuvvM|;S=slB`*axptd-42qv!#w`uYX;cKyPdJv3pvW4(fR%43$N(pGDd+>>bEcv3Y>Z4-%SdFDGZ!i*&>58XAnOIoJBmYrHeUsIl9?7eo+t=mb`r$z9k>ZxJVjjY9Q2?_6${98D$$dV*j-zR1^7)g(_Cqm~ZS~fv{5*~Pu3ZN&mw5T{i$9TttW&W%MdApZ~54lhLIKh-2UcZ><qs@H)V(FCOf_;W)^Cj%4gBSQ22E{2%JdX#Fcop(1*=6K6VJ%cYg&kA#7VdD?K|Ls;kl-vSaDs+Eg$px!8ZFrEG|I9_iy>;K=B73t>EEY~vN&ML9MsE|9?lK6o76}qY1o4M4}10aBvM=*ZT|HJ{{)-A+<b{)IF%c#n5V#c;GwKxp%63%!7R#y38_j$@95(A^c3a;N6c_K(FE!J;SjV<)TG~hUhh08<+Mk#05`4$ei8Q$RmXb%ZkAzC%Z(FS3kG*PkTh)}1J>*AIxuP}7*NvQki!vl2YYg-E1o==jhrA}_+@xj&*B$X?akN0=IChi+ndMTCrsnOwJMYZv$ZfQ(tvW?HDYN-jAt0#!fZnuzxW|pzym*z12d(iexG=fEgXI>_6US|9R1zulh>b_S+yFAi7jK23s@5iSomETGIyDRV^^mI72TP^o0j-5%HZ(=<Ci|xqi7zHLo8TTG5s^0<qKFwXkOrN$DrESzkVS)+Y7~PSm08OS`ehZ-^g&GXo?u#aph+cd)EV26j4iS3DfC37sm{i)H<N^!jdu|PM^CV^M^hOK0_DoTCQdnzENt|+C;?l46u1RXY1N1m}H>~lIUJw_clO&1)8FqhGoSOfhMHdaXBp&?xiams?>zIyB0QdopsdBEFGBTrFS^BzT~k-`w><kZJ~LTPt+bdB!OOj-G<3+8qCHEd7OsBXg-zS^K>FVSbVPcY+xsxIZfT5H%z9q8VqE5izM9=8>6+G+km+{FpZ{Q4yu6)#!B1qfmXDvZTS)MoCredRpaRyCQe-g&eD#o-)gQ=VcW}x^oPS5)T}f8MxIdPf|x{`W;huZY}T+Fz!l$SE94Cfp#sR~EKUKV<+SkpGOh2{>TfxH5UEo0p(ewCMD<MkZW?-g)Ow2)7@unB!=2Iz^2+81gx)BZ=2N(tWvko%PozerDA5Wo>=eOdqP3br))zhGgtvWTYNz4c;v|aRF|RjvhL5T`iF+x13<{<alah-Nj7&MNN6M54T|XEOxsVQ!k+yUXcVRd)cK1m*K*^2F8%H=-0BT7(B!!FG$;PAuL0J~}?|zs^18QWUjksY9@r9s@!+VhtC&a?*e9&p6Y{_yoJ<)0!g<7LF(Usbbdj?o+yII*BP3j4z-{##-Qf+a@jM$`^C4gIJaHEjKJ!MrQ#@S0!u{V?yQtmt;#g*{Esw58r&hBC;87B9!QgXrT6ORLLUNO!HTcp1a%^YhTHt>EphpTD~2aaSi&qZ@>iYCjQq#@ifKZSa`Ps3T_rAd;jNCHLXG?~f0qu#+trNXYnl9eGIXBy=&2+6Ut5PbHkZuZLhvW=NS->6e-^}5irHYtT9L1V6Mjf$>lkG?9OC>`q5n%)hg)aNR_<nHj2IGVQY@GKn`WvO3hIAtJO*=!PlbpC}X?y7y$XfdVOoSECK18|nYR7zaLCV@w*^@3-p!!?4;4IXQq%ijuI&FAD5?RG=!m$d7{$LkkAWMR5_bc^sYc1wJh{1Qzj!7Iciym+zz;WNAv9Q4R`H+pU${3Rt?#4`^bO!vMIhKs<MlEyu1ahQsqvWdVinUlEwbxiB=MKJt%jstoYiHmT?_c*#U6s(jJ;t+^Y<TX?nYmKQL(?VM=mFK;H*VoAq#$7r47N2DL64O59`Derg#KqF{j~gs|j^_wi!3n$neM1N5<Y_Rt!-BewXJJBJdch!{gAIDaFdL*1OLhW9Kg4V&qfyIy!$5!^r`|9~?{IoEP0~>Gp)9+Ovw)BRi!8K)K;rL`guX*pXn7x9PA`rd9j_l`ig%nmFa|Q=BeO+5=1|FGlD%@U+L|rA%}s?v(qs37*W0^W%`djLcSd_%lD;=Lv5nHF&cWHsZCUi|H@7$1YIobsFM|Gdu)Wv(V$j}eZ@;Ey|5cNOX}^1Lwz<_jez{|Jx^?jV%YA+^BMb<i?1#io!yX5hwq{}|{Ft)Y8f*_WY39W!J`CCOp(zy1tu%FzRNzTVJi8LA$`T+UKk*jHoVttUm{|5h_M`QJ+W?y&ze;Et5pqxs6%EqcS&(L-6AXGC*ILfa2OYSpzZM4HrWL%<v;sn!Rv1CkimYo|c4O;k1Q7LrA0P6jW=ycJm+cw;_4V*&<G^pdY+z?ZaV;LZLg=(2Ea{=Qj?&vX!p<%iGh^%zA7&&|@HvAJ@PVL}4FY$eM?~;)r+K`&Rfw6x2OLQe+nly;(_}vLJM5L$(Fe&~y<}4-09e=1Rk{V&Zn_fstZwwz*V&i;)!Fg)gx#BlJiXk!0Z#mXIk>)VF?Rlizlg;ywbey!$(`0(8du<lHikY4SBla$9?|X-36>-%dxRH{@Zx>{veR}p359{HS%II{9KnEo19p8e<If6AxZIY|+tf{1!s%=_SqP<=5J^?Y#2*dD;xDaZYL=W-=-9l5sfH7C@grzA`S`GdgBbPUrS3<`XJ^1~+o|5Ms;lR6tz%WIsMO^%4)v>C{Cid0c3jr7L~%4}$6>j_JGP7nCCKdg0feK<gnz_S>dOYfhV;W8sZWDmPpA}U;v_d*we>+wFl&+2j<8j(PY`P!3&6E5$x=;|1LO~3rkT>_m4(!G;P693Jaw&Vl__AspPG>qTIK;nriTR!X~OFym{0P<t7QQl(=ZP{1?eG6*?OU)DFq_)cs5sKEEvcv404<>tb`FPzi32GB1nW=!pu!e=`FYfH7H}ivv0gxRAsm&I>tk`oT6w;?Qb?4!9q91T}!sKXRUwgH&i@umL{K~p>@`2P*4EN15oBcY0Ek=vDd7D56C>I@E{J)1q=O}jf<+OTE29#fWme15V3%2RLMuwe(81iNF<r(89=x5GT6L`;l838H;ih-M2hzXAJM26nV2}ALK!RU=8Q{0+;Gcsdk0>rEWd4-hG7E&W@e5?Kez`7@M}g`)a$l|vgxfpX>O6us?Uy_o<F$vzO?bjEr@^eeuG6_#CAKFP+p4?{^$Av!HY&3YI+Lf(u5EsM5Qzxemykkzac?~KAbi1rrl`#szw645gHbT)Nqi}%7Ra!uTj~k(Pr*b*w`O+ktfebQjV0=Og+wilIJAh;FS!Sk;REHMqaN64XW3Z<J4XcEVS1%C#u3xMI(S^zMmv_z567+qpj_}lH_DGj|XyCs&kx(h)kb2*$E8#95>I>vuaLdKOuDltg^rG-X&xBr(Fi)DT&nm$a^1T5V1av-(JV#JfCF;uU?H8LlWD#Bpl%+fy!*bvb_gqoNl|jyQHb>_$(TPab`4ZK>F_V(o?Usg9(&)T8Xf|K$Wjbnh^PSx6R`?$ebi3QL<jLlG!B431QO}*-Ko3ww%&Ly(Z#@Nx@2SLQ>UilH}aN0>7XV&L(+%4ixo{WMuO@yCXK4Y9ZNfPGv?=<<3LIA>E?$XFXK7fNHokn2-WPQ=kg}=^ZItnUTsJ{YIB5c-s=$-LFehQgQ`uI-ZtG^>^DJxLKzZ@b8Ly`O@|(9#YFRho<Eq&#U$L{N(8J!#TSltXd&Noj;wtxsZ$`*Dsc>7b<pkdVKQ!;-m-coUCdXh0jlpPd}dYempq`*1*CGv1`s-dK64bwp1jUIl_Cf46wy~0?Po)3CiCKb_-ayCw*x1wDOJ<8ouilGRa%%fF!qInvr;ovlaib!0`2p5%HDQD40f*g&0#ZBBD)_^P-V+s-jBTUk|*i>lX~9Y-nduA3FsY)CDM!U%m~04t|`g7dLK$k{D+=i_jMKHT!Gu5JGH$OxYr~j3VE{kiWDL^RIHTr-rRZ^3LDOCi7dzBL^=;oyz8Yc5e9BVDp#u=Ifi6GKfw5K@EL8-Dv4lGn?h(4K%jeb4*)+3I_yzS{r!$h3zZC{>!#_v~DG&fU64lqi@@DRZ-ii#WoCzHSjqv7Zbk$qeIb0Qx5KRS8Tv7*-<T%Cp#&rd{1J^l!r{o{B?#+t|PrNcsz_D@!HJiu5qw1q&5z_R6ow<FsWpNC_3b6#{o1H;dt4RpjR{8(rJf;M`^X_E;O4qt<=FdBB3G;2hmJBW#Vg(#zr!Ue6BIBzoE@?0w0&j!uG$!V!n%$``FW6KvbR0^Kvwf>8^}y>yvgvSKyRO>i0&kC}1rYb;e<Xz>7qaoZGc?uFI5N3#ok+d}U5=>x|KMQ%UMP{^8JD+1l#mC*lbYM@>U<maYANv>0QiWt2>YYBg$+K4ecidvbUXw6dnjr%*iYz#yc6KI>7~N5-UZ$ivBsq!Fdb=JqTyws7EZ!8E+()MTPz+Fu4lVG)>qrutv@wOUo=2g$!w(=hU!Z9>XR^J>$4-pB}g+SGA8P9bIUnucNpCjHfr?JMDn>;j`^LLG=XNUORzz-On_N~0BJoPo~hxi)EkE@xs}tP&Jke~o5vL3Gv%t5n!3Org_{y|*Xdo*iADyyYVWRr<hHxC9Ms_!ESb^eR<L9Y08!rYhUA+&mQrvq362Sx-@qB20NQJD~Clt(=G%0UGBf{DTj0RBa^l<D(_6t~W<_!;+S9>aKo~ZVt_NcB_3tXQBS7OeFLxXYoV*qMuKay^5Ymv$Ip9C4KCiYH$j!f+w#$;?z#?JahKRRuFsNUtWH^P~Py)`KHB|*W|SNacw$Na2<LUrVHN%@p#~XoD3A{i=aw!>N7qZ;1g3QyxI!@gHvuBu+;L99XE+3U1gQN)FxuBzLDn4kM(r-q>*SFp0OrtP9Lp!y%oobYUWoQ6GD%E)hVA5u5nH{=Wwe$nufGHA0pNt=Z0Z6Bc>bH#8nbY4R~je5^`MF;oMoBHV6CjpO;Qhisc50`VHiIC|9ZJt1dFZnqOGICUB_dP{f#<eD}sN`ILmN{sNvI3_|t9n>ord!B0&sk_XVnGS3QLU{5e{WbF#z*U(V?N>Yd0)z<1x)0g{)JD9l-<am|yA0Bv*^6{xo9xSq#TG3)0w~>v5?#`|weh;Htp;TqlXsI&xE>a_qGqKSc)u+!iTO=};c8Wf6t~(u3?2BK>fhwxW%uowVZQxdwkYWZ<YlGaRJ7iUW)N1)<4;x_eSwfA*u|~AZ(l{5BOK41Tw&Lc(nb|dvr1cAH@`^!O3bYQE!Q>v60M)^uw<M+WK1X^nDSI%<WInylqF=&8LLSlsnk+UCwAlb2iP0(EW?|lAsMxWJe?2w5M=sU6kB0g9$$QYx;}Cl3lZuxrBtU8AffV*|LU_O_N0JT^l*%$sees1ZzIe9yZ5j>5EBDYCdYc@#$Pga3TRS>`C^Eqo7@{4Q0PanK1#!F5Zcd-Au+B8N?<v`{$8nH2e)$wm7Ha0AILc{ebeTiRcE!=q^J!0`oWq%R+6{NFeoKwBeq{U+Qn8cGiJf_>MdVS|{z<^XcS!<AhpHJQPZ#z|g5~R$%i?^5%8J&djbI2XBORwy;q)WB5446+HY4Qd!hZ}t1#%$P^wcNi^!ET4C|VRK#w-ZSnom<I-0FNDV|!5?Ja&CpE!3)kGwRt5i$qEt-cm+@y~8$S2;8|jXIQaNNO(u?W1L_!5f75t!gs$}A!+uEJ{y!qLQNRp^g2pfZ?M;#ekixhhI=X31lyYiInnSRKc0LC68`%<m_+&F@O8V%0Y-?dx5X!HT|L^p*(!&J10KUG$eCY>*|~ZBf_7i|-RkddvrQnh5HFqMn3Zh~F!&5ZDf5D@4VEUz@{w}qv?5i-e$&)5<{YJz76$a&tDD*=Yu&gGIen}U#}L8|Bt>aV9Sui(_BqnJ;pU@&bI|S%vBQ<UuC8A&W2tRQec{&5WiYC>`j-011KS2U^DP^TB>OF=qeb*Cw{fKk-rQ6gxI=Z+cEGp;2>Uht;V`5YaQV<=hT_zFDzx}u0ioa3z>Oi{z|c~&^7SV$Q3kZ&`qfh3huSD<Zw5{|Mf9dUy$Gr;sxL*Gx@b+Sin0VRLPD<UEi4OC>c+;#bsS`icwi2pIKmnnSmrw;f+hCY5F}|W^FD}jc9Q)_tc94E?<*;(;T?V>MWK?{@L6nSr=ye<R~bt~V}FgZ@Sez7b$TSWBkvB7^tCNQJr9q>i!3i<x2`t6818MgyL)hU{$hJ)Z>PV_KRdx|+Ijfr>;3I8*y5j~(cY*{Z|m%b8(*~B!EUh21%ut4-R{2B+1u~*N7DWf|K*>%yMu19vvE_vgu^g`XqXJxF`zZzv%3>XbnR~pqfZ+=3_di=@&&MwWtVWXKlC<Wg5MNl{Q(=^n}t38D?-O66U{-Vz0;mOd^Lm1bbNcz>Cyv^2yQt+`2h<9U-kK5=AbisAVqHy4ZSahJNU2qu!*!-^Xy=M_OMZa59fsy;Likjlxo3vdra`s2Y^o0bgQ$L<R;KOPk1XMm0Yb{&aN+!cpOwftS7m5D~MGnXW?KlPH+%%*V-^h6GnMFjwVANfT*>uNFs=7w_Y&<DImj;-?9+dmkZ?REZ3rtEWvUqwN#5@l^InM!vRa-&J?!)`73GkAeiS#&2;VU?R_<vrx}S8jMi}wrC;UAd@$Y=H<$xNV$>r>z-icPCC&vT1u3!6V|nLqbcY)*7I7AxOtN(dS(jZt^wA`I`06&8fz-aj!{&WTPxyxrlHNu!VS|R<w&;+^I9btqf1c+_EC8TrnHYaS^$C1fXb-ZQ9pGSf&33tLx#44OAec<7M&%-iHCvU!6?kP)WLo~qHmtH0#9B-Ji_Z4$V0-H;W`*v;Z<iMOw#6~_2;IyznBm+D8TOOOaKo8WC6fTdO~FS~0oACdI#tmjCfc6z`C6nTC9C6|M)9UvDqW012K&W+zY}zV`XN+6leVn|0T-sV8MWOK2Z-W}soGD53#SO`I5^OvICfJOpG6{`gt?LQ4^<eGdd-_UYRo4S{f?MHDg<M{)iS1LP5Q848q9npFY$)0MayV-pqX(rY??$8;l#Y=C-vpdyuE7{VYTKZ$GIw3wd4T@#<4ai@ppPDiHNGq)qAC07UEX3rgo=NTbQm}{d-qJvg&t#Q}0`!(YsV<S>Q=~dl`X?^OyMHr!X$0A)$>v7INk=<~MjnL~%Tcs66~fN@}`6v$Tkd6X?&My-n3xYZ8ufWW{i{xL5kCD|$L@{H16kPi9sVV?A#5bzB*9X~by=()R7qvb#3(5gt>UuXV6NY`VQQ+?r@lR*!NIS+@bbBuGs`A~(G(<fQqb5NGX4k)uCN2<}&jn>bVg=oPo({j+)`+{d^1_{OTD-PDu2@B++DS1lKT@#ZHbjcnD|XT-^>g7+HMhy3l{@XQq-w)Bfmkyk~xHHs#am5`u7ZC6OU-rZi=;0A9)8<ir7>~-MLUT24PAeL}9>Y4)Q_b)iS)EDf+mflq3gD;?l2p{$ug)fLcDAa8Azx)@)O6iB<pABcSYvzXZhE8W=)#P+54TSj_eSaHdWB+Qe>Frc;Zp|M<#AuaYK&%4pif`&D3h39J;&sh@I^FBfPj#!3#cu6rp_UALP;a22jS_EC7xb*yCz%UwG;|m&zin|6&qHq4{h+VFQJ2)%pJdn9viQ9gzsm)b1cO=HQJRb4imGHiGa4Zo(i!}g%^0zhx1u->)9)|eouSE%U&}AxK)Qx7!Hp;P%VlL4b-%(tn|U~e?_&su`uQ}@4!R^hBP;<C1|0~@&CV!om^WMernQ52yE|4<sEW-lUbCJ7L7c?DuYyT*8*kD=on{9EPN}Jd@jWAp7vocbyUT|N>W*)VQA&l9oLgDZrP2y5pUGVzU%|p7q+N(M-UgJcjfPv4g`09|k$CDW+?5O8>4NlE057WCAx)LdAm|03M|9gIgyNvK)UYHCsRcrOPS(^hgoII{qNLLju~>671m`%?7k2p@IB3~qWYFOLri_9A^k^pR$vb`fH`50f{OlH>-v7-)*yq;26YfzoA(>S^7YeFWG(m_+VrFHC#*qbH2+0twhl+PSxr1L?OOu%tE7iSQUJumvo{7r8YbopMlQYt#RTW8bp;Cv68j_fVyun>j)jj|gmWMc!K`2YK>6~9XEYyB2VxE5UWb-+tKx$Jt7NuHhw1|Y<1+;>uz>{5F>b_=s*Wd~_Xq4G8oCJ`XVqKoB%m0tSm|362NsHL^l(M_Cv!nR)CduV&Ffq&ctE&z0qSLqd_dP8y&M3zZgkt>NxGDBBMO5zeD>jOJZ7X>EEU-9?$Hhw=#@g5&yxKF0Y6ZEtGe1lDo>N~}tPy3DfS<&yQiUlTdqB}jw<^XZY7Nvj`ukRb!Ze*0S~qOX);SN3jxAM92}4Hl<}&J~viODhM*-wGn2{I~Ds@UhcRDmWNU=_y>c*iMe03b4_dh6r8%owG!&Qa(+5YCU-?6tED~2Yjhc>-^2PX>^8!5k$C$J*rwr?5@yYAwdx*bPCcI!TLOkJdzc9cZZ<QgE<HKPt>%I(yH1B^c4x)8#|H;3LXRFMUq7xG-;UPjn*xg0hw*F=%EW^<DGt#u6J&fnCL;6FVoc}v=ZFW>M2aQa<h3GI!>)8Cp-ihP)Wip^3T0orBm4oLAT9>o&0VIQQ35$J(tYC->h=+NKJO?9m+OJ7Mk*(gR=*=nBLHL49@UX4+#hW6P;ykz$?s7z*sm8H^ubvdzlcy*iBiSas3DtqseHdo?|SMAbGvA(K!VA#Q)N|3PTp;-M-_M(W`U<GUDMQFx@LttNvt4u`6NMphRhCzMxuUE(`c_m>On>Szn(<=fm%M0<n(XjWY+7bK>W^?vQMI?|4tw2t1$vq)gb&nUbacD)|oxVLF;x^qp{jKZ-R}o|Ya0H82kbNF_d})9}1>8%K+CkqWp8py^2nbStEg&46+LC9BR{qpq2gvW>bz;MT%t&x^Uk@>V5Mi|yWv7xI&S*&u@8ABdkZQm7y3X@Aq!FzF-Lahi1?skRCHsrBOP6ouZS&0919%p4hm@6PP{C}M+0E-M=e4$Tg?&@RHH~|+ZOCQP^>*^YC~XYQw(;8bb*OKvQ);VZwRUXT&$rh79U<HL9LRKIg%3&fJfh}ALg8Pl4aW72*(*u(@TM9%vS0nNobrzF;IA|^wjuEp{o}=l_bthQ7mXIakWr&x=Hd^M#LE4ov^_k(8AyFev1p-7P8ayL$qmi?m5$;Uo@&1QF_H|f5rMZ<+3kbfq^tle<u0>4@TyUSEM+84Q=`h4&PN}O^6qDas7ZxJ>3#%xtMVRl1c1D8?0P-wg2Py}Kb2PhnvQdh<AP&(oUW*@Dyk|6j{C7HwA$mI+K=L}ZWk@GWQKB~NU>2ubcmS%ZGW=DkF2I=e$!)9#1dC9ae}JmiZr7srFV9>U&+^@I;qdY;AUq;J{S!#oU2XcKcsH1uxMmKk60f<#~SSq=P*RT`L(tew-2;w?TkHZXY|~o9KjenrnxYdQ*u&~rpIT!O)n={!iGr-OrJPM?snCGNF@Wd+EJGFWtV`Mh{qLaT^;8-biU5~Sg1N+6gY9He5DY(6zim}nS&5lfG6}>M_`ODQf0pO+8EHn{30Fa8(C5O9#87j{#SrIi9$E6N9KBmyU=uyPUNAj`la8C_OIy_cUf>|Q(lgr2rJedD7^cqluxyei<LFk1tfR)r~BF9+?k+7Th?(CED0NV#&gs(`fEHwi}hqU%TjmHlG0b>#))f;k@}sBi(o)=_DXZ%-3E2YZx?v0b?n_|G6<@MI<*aToQ9UTqTc;lm(v=YJh=z;YL1G{NK9%y2?F(X#5zZOdOE~O1yqTTz1gemaNL6>9^O{Xa$K+D|C$ZP;WX%h!g;GY@Z1~*u3M^3sB_>s@H*k57#0!*9e64kgY)@5>}QcQp%O4SpC^)Aq&HSUxCfq_f59oN1A-5{D#dHJUMsM!GPe?~V_bH1gpZB7N}VKyZ$vok-LLivE|nfX=N+t&2NQ3PgM4tm2*<LW{Q2}-Pa0Aw(-Vn~MHZOz@7{P4VWX}Dx9D$~m+-F=qMXJ^HcrLyuon3;ifk6h<XpcvK0P@*dQ*whSHUVhHX=&Nx4Szv#e&H#As`=5Ro)6WD@seHL#fsyA$OQedr&ADl6G}@_u!z9Z{7CtZhO;YsD?tQUkq!y(t#0*Pr_=C3ft}W(kTh!Pf?o0Qx&yXL8Iib<i(~^-?ZeFUad7Om^0O&N<3@zbh%!yQf?N3hEVY1>DkJXB=_G%c~27DU_mM5*VlP+UC*tQ5>6rod2kt|yt6Z2FeVe~1}e>xL=2*BIrrCA;>4cKXkbO$tJp+0)_7$K0xJYrS^{E75p*j%yu7hC)BZie*ouoysENU}l?VM!8y7?okKsiMbGo|Q!Hm@Ki<^dh6OKN=Gky@<cuo4SnuePCVv*YLmx`cS3LddixIJ*jJ<hG<o0LkvFD*3C1e@5K+P40D-eGteiE>K{@9;L1U^<obuLz{uvPC-rgMFqSaBp>|i@tFK_I}eFZD^BuODif@MwGgFYI=8v#p^q~s*6C-0e$^RFkrzF$ALWSow^bA2~7xv9?^uVRDB1Y6%L4GhPTBRH8wE0**IY4*n0g`8~C{KXeQGL05?xwu?ZMg<$p-P<FdF#619aH95{D}iAm3i!c`WUa<R`%5}|>CO^E)gW@(=E4A{|_m>$||kPYk*cVMtIup;7e4JM*9cyc;t9luv6#ONSJmDqMkN);^)6=@<>%cS7yy3gE`r!J2~!jNn}^@d3(ao5GIOKd;Wtp3INd=PXG+gUB-Wtprj+^?>rMYEfNj+Dg>ebV6h1b&@?4<p*kGd6e)ljjC*CR#}`N^;N+t!#C;Yr<HR^YOQWV2~!WB36?ge6~rjDWXvnv2PL7O<XOJQkEr0eYW27*AmLoRk#1C>j(kf>I(@~#u$>hK-MDNSrMDDMp<@f>uVy)9a>Op;m#hQEfU&gT~X1lVWdF2cv&>m6&kHkl-r4h1p~!F@*GLP86SP(26*&&pmJQ0^*G<K9NQh5SpDQaD_@Sv{!8Y9)VoIIigRgI6PNh)Wj*nsvo=$-z0_{Np~Xf+mpsklG}838OR=7~wXq^RjzhKxEJ;xu^c%HGS<0fb-KpSB0Z)oNL=^{Z`rb#tRi}evl*ldQTbFFm%LC8fq(4`tTM|;floveqn^G=nv}0-T$&?s=*ejAN)k~>G?u7qo<<Me?D{R#jiSNLrGpf3T+m&QJ>&4x2{#3`|ZO!zil<d}oX(#utyb9QAWm4_DR?VhZwym*{q(H`-o2P?;9f(~g;Au=1wmDsSMd6;Y)l~$`Qmu048!H8vzSP(_)M*=)DPm>mppENU3P(C_q(Bhy=-@vumz_h0Yp=hGGHRtSs>_^)v{e=^ATFCH%lA;md{9p4_RIoz=vA5^Da7vXMnZthRG8dF>uA%aB1wWFZeTYJHN9oS=44#YlftT|*VDt9f^{Z5n~j*J_#Q~puA460yuT{1h8ul#o83hvuT=3#uYeUTF5i1~uDT_C**of0r0>1uAI{iV(4@CDgE>6pPHqYX9`2>;P61ZaY2^z06<&ruU5i1Om2C#99@Os+f;W`~fgMoWP16bOqsS4n?p-~leEQT_x20_f=#1NY-FUXW?C<k1BzWY6xj=UCAn8~Q+lFxg!@D|YdTp~)$SgDk5eJTvE~;oW^@~9^Dg_p*K*#+=VlR%y6Xd0<QT;dDtu`tCoL@(P90!N$E;q1|Pk0j1tE9k}wkCnA=`I6jgDP)J%ZwnprFN@}#P6ik@8I9v?s^ki=&ttCU@`8-HjNYs<r@{a7&QWi_mcYF-eV9t`%PyB^G;`OD>%SaRhyk<d;QqO<TAwWuMJIm$Av}>@ptK+jRNzTm`|=>{Am-(t~1YOmz=1L!_XzM_b5uU+@+E2|6kcVM9i2=QfYU4%R+U_U-nsov?D4!Do)Epci>gnvdY{lM|-uKa+CIe#?#X4Ee(w7-r&^+gNu{1ljF<N5AQFmjI<nwPA%e`o7f@l%j)Cut}w4$tZA;9ws7<ORnw(A&KxktLFPS{T6~hd%==Rq&IrW(9{wvk>`U3{iY{a)o+??J^_Dr$*yfbE?x9*3H{H1$&&FqsV7_7kkeX|dKkFD#UFf3?3mw>Ov=LXPXp$s%as$*xweE&3FpA+-xn8$B2ZQ!@aSgn-%7&?AHX%77fXl^Gsa5-Q--un}^`l3ssMYGXu?j<WGw$`W_7{DS{d?k1d%PCA+v!^`n-9jwl2(V!3ig&G#}*5LpFbS_rw<29h0jfp<QGN?n$SnP)2Hhft=e(n?hU!A&BjFdKpN|W@0Z~FN{oYH{cw@HK1AYQIBy+XUuT@T-tPZ*9W5>2Z0!M_OK>6^Jb@u~O_09YJLVj37%*=B^M1oLD{;S8Q{au?q{=(=bn@XuqBc|orhcr+IJCLg?}M*-EV<r`d0rEP#FUQ==%;V_*2Dwv(G2IQ4C@LU5q`jXe@|kN`>)ofhwB&0YdeJhdx4B39)v3f0;t)E&mn3z+N7rg$jj_dnCwbUSkxCj_$x5v?47mDj$<&PvFEt%Gvf;iSB%*T*%Z*0`fqYc;oRnu3Q4tHga0g8c(U2#<0w<<D$J(SG+R;K*QfuCJs_Krq&12LD&}+bE-+-lLm8NviI9kz1`{vGoxrR3ML}z}Ddoy0s2e-xkps$CyU*duF*mnj#dZw`J;z#9=WM5ptI9O~tPVmOyu>xFSy~GjRz4or8%<fBw5%=WCdVgCU)-loi8IG*C7G$4U%0?k`JR_Jn8-aqk{HsGx?M8}H+<uIi&$1%Id0UjSrF+a4N_{`{T<v-dUAmhZ4bUWD=)4|u>8ZZhs`GJ>BJY^nKF)9kV{N;;ArX>#jdOdZW?Z0{S{8zUtF~}Uk96`o5$TJanCeetnag3KqaBYa8@wy%J)1gB$@9`d+2O2)rUQH8xoZePB=??F>1xD`9oQ^u^2UfuL|^)5p75hB{}_(@8&%4x&ZZ9{J%WDN|Sy)X=jCLlw~TV>s`2DV!~gVOMSPex~!9Ha?}F8D*=Q%E>6r<W6wnj09fL;y0pi^7q*z9zBJ6yJ#oDn2vtiCM72;C5OP!Nzy~Q;i!qX+u?9|VO+)EsUbe2iCFl;+Ew9`*hH=w)7S&Hqa%JCKLff>!Z7ff;?2PHG=^aZH;P*!3R>6UoR6Av|MT+p?*Y~jUrkweW#`+yWgGap0FJYRrJR=(;le1X~*d@z`5$jq?#d`FOludJ63of)}xxfBmT<b~~m-Sg69HTv02&w4G{`y&V7PXNWzY?vNnhnNX-}?PCE){{&BZ{4TFis*UUHTeT9!bO(Cd%$m^uuE*CDb=tgzEpQ*j8@Jw_8^Bm_z-}-o0%JqG;6KAa5)?h`JP9UkP^j>{eC-r*3K?rhw<HT6Ik<HDNiFv4#!n=<OeWxVU_G^8WI3jaaKKLe|=FOhOKPYuSW~8fzMbM((JpMj##{n!<&?>B89}bC`7Vx@}IrJfoCIA=fY??|zF7W9e|TJg%VDayZGj?anibxT>P|8>YoIwQnxl_&tZ=Xxj=fT-3n7)>5*i=;tchs;l3iVlN$%rDLxi25pwfw2z>}h>91tE$4{@A7W#9UdNU`98oXG;A5`z>k2i?_h+ctZsa#8*-McGhN018XjwY_45eFDICRFmB5;yRv(rl;;jHT@-$AbCMsD;JeS4A25vvFjuu^S_pW%4E_A*1=)I#a$+#KiL{<UiQ=ONZ8?K1FYt-4;YkO@wELd3OVV649rO%}e8Yisc;3lX!8D*?*dbIpzDm3`D=%8pEGE&#`M5^9&mE%7-mdN?N)DxbOiy3qNGW|Tx)ptw#5{hf)NcoX+f<x3UeRY`87g}aKq>#r2>Y0omb1u@>8gZ5U{a|s2}LV>{YcfH*mC@xuz6J+F~fI@R6@Me^Y0YN6K64s+Q(1E5$%gj+mf%e^!Np3tZu^Hzmu3jR>vQQ|1#)htb7wK*tGl<jM=U6+G6e{(_jmH&Cn{L}$Nmy+xS=wsTthY7%gO<9kbgM2aubcLD_v~fT-68#`+uCoG+((oVOXYjCTu7Q;>6ZH@6wx<|Iw7_k2_ZICxRmfJlDL-N(XFJTyh>D#ycKRGB~KESu1`$4j{K~ET+@$4wbK@Fq0VP}kBHv-84e>lBO?zR80a>2kV>8V1>Y0B#P{O=``!{9VxdEa*N==_PoLKZ_>MMT@S>*o_|(ukzG6u19AOY`EeT}%S*=DgBee2nkQAgrP#ZiC7J7bhoo|s+;~(!WjifYUFnoL}7!3i)CvHEUB5JyK`InC;7uLY1QH%fzT;&?XOmR_qPq^sOhaTSfnoFS}i-c5fSE}8!qc<mK7gs2Bb5pmytBwi>deifE)z=;!TP5kK>_2aA>&n7-PzoN`M&s)jaY)M{%ZsMOSjO4(w%KUK?)5!fh)CnzuN3TX!KaE-99F*+;Xp722CbAH&!a(_JxeXlWL(M?C)XF34?3)P_L>m4=Gtc>+58sXTp{t%h}NY!|F}&_fL_S6UJ=z+`xBZ?6eo%#Hi8UhX8C+`=pBDJ`*8l|?DYNH-sSh_Cl?5WcN$S7f)>=znkf06MxMG&ihsMuFLf-^k|{I;6I7Pv0lX{tlg<t>Olf0v8Pt>nG2FFf1dIRoZH<ZrX)lF>^I-IRORyf0#{)9Glvt%Jve}ZINsT$m%Y4Ha!1-EqmO5q#tPW!JkS6gw9z<$<{3^+!;wk78BA2O+c>*g{lk+k#<h&T!{UUR(3st8Gd^5GoQ28!VG{B~NI3lYu{A`WxN{_=Xq)+D60Be?7!)?Og&E)<rb&(i9c`atkvFF+{wr)u+RkT#MSZlyitMx`ML0)scTE~TYGt&068f@2)sHQ(%TFj9oF-+!eRvb}V425dY%@%0So%On+LFm=a4V3PTWlAz@UG1Bzgpto$<J$YOyvCP%WvbPLkiyT83MtO&#Xxbm;?!D$z#jU`i!me$rQ`6S(y$yJJl}FnIlE~c)2Ewf4}aZI0}bH?*I1TP3I?fQGC?u``ZJi|3SW*?H34u%8r$MckSCKvxV|@@(Fy=LH)mQg>X!nuDI+pD23St`Ekn{H3i_EDiH_~_Hm$+vm+Uu-!K@z3=MUxiy^1C2BBg6sf1*=9bgE@>b@F&2`j9HrV*^n+l*L#+YTB}`BHZ3V%~^*jbXC}WZk$bpN5)MmOEX+F?P}T@bW@4fvEbHLnbF3hT~~$L8BKw;UN`J~qZ|fD8e<gOsmY^}0}m8SUWS%`L!Aw=H2U(1AW|4Esb-z;GIq3S)3Qps)@P|$!kaRZ{T8%IyCtki12)<mAYH2$@0MV?F6}seKo*adwk6@Av<gCYNm`mz!BLzi5Cw0RBr*70^;GR)uD_GzuBCX7>&3;dn)Ou-gGUwfu%xiVvbhiY#ga-kPvi_d)^jPxlVG<e<1T6xXfIMZ)YMc&Q`Ar|Tx|o}eI%*d%6lhgSvDIU-`eR6cqzwr*gjs=LChZt3Uz@aW=GTfVjA4Bsslxc0F-;dU!2n#P;SULpBe_~P=cN_Tn&&ejCh}oqgm!bO>M~)1H)vHz4{uG>o>2mdw_>vNoIjsTk!b2h%50+-4=_xr6vZ{vu?n%k9~-P75NR(UQ<rV)#1=Ih~m}z)A`BK+jl44E$w|6P?qS{8EZCNkiAy7l_#`(#<Ik1==CMUGJqw}>u%<Za!K_^dMT$TTiGkqK{TD?MvWn<s0qzfGK=8<70z)jIzOS<GtiR|D`hc-=W`NRBU~sySxDN>oW_?-vRD0iG@;2@NKV`+S2Hdtwp1CLoKW;GAWDVgt1g^Z7sC^0oCRsd266R@6LH~OD4t!%d_wc_^h{qQe=1S${0B*R)z5Decq;JE4>NY@;fhRUlc=w2`{ySgKlIK&e7J0Sj#;SbSf5B935j0CQnJ*3i{&c$7@8i^^A>i0Jr`E45+aKpEUrFGu38?bgzpmLeH;E9{5Zb|;;fbDBjwq3@aiX0os#?P6$YBUx($=`HVRaUWdPPx<U@m^VYeM<#Km_<XsMh9s?ES4zlAi=oQT8>sLAPHs)v6cE>3C={9NI}?Xc1rqkE`sBVi-9)s^bTIK8dikTqR$kgaWGL}g<!FFH2iXbMxN<Z+3^dz!rS?~tm`^HHJEEOJO$$0`v?!Oxv85J@4iHfN_H{X*=0^kXm~pfqv$1^xMhhO&P0U5?$IorcK^gRHpL9N<n%NC4bq<bCPgtDGR!gP2rZ)+}YIFfJQgS%VPLno+-@UxyTFZ<9d~{1E6kIFc9bQo;~wte6jQ(Oy3Q%+p&PF^u)pv)9v4P49co@N>%<h?E|$=Lqbgg@4e7R`Oe^Ik>rMqxzQ!bnP~!Ej;Y(-!vu5nNNsi>?#!NNoC(;v%m|e%$2UV4v3Fxa9H8<m7NWH5Qq53K*VP{zW<ZDd9q7-)+>18`roTJTk@v3nNqdoEGUM!lmbonqp^zHqkG8F=A%z3(?leC&jd{iyS_lEG3_57rxZ-!I2g=W`I)H9-GgL0MQ~RFzl;&QYSb=2pT;fC^VuLy8z1XZGwm(H%VNg+HDAN1!kU|f^DR2bn$|5PS2vP9wpdnZmJQu#{-8dZ0qKEN8&4$bqUaNR&qt<ZPM$t9w-f2mAoUg7EKmdyS@H}O%&y^mBZw=pH3r?}Oi*`cmN;K=C6Lo|jT%%GEkYM#7fL&u(el348sidnmI|I!CJE%RpD3~sFIOJk;m&?r(}v{Lr(#ue7+UDUQ867Tg@U%4TOzmd!est6kQaqu5XdAQYoj!fuJ@8=a6{6ia2fBBDqcC2ZgeatYHT_EPe~}m;SPHU7Oy3vu8L^W1jT|GdV7??DZ4C)M!Mwqbmxskk(&OUQ5DI}++lGyYE-%ztEe*=UNWd4Nfo>DXX~b>yFm*57=zMMe+?Fvk%@qzo6xGCfnXBzYMZdtL*C-lGA`g?b{L6147w?I#N((mf@jWAQLv;*>@uXARg}xprf3;Lw@Gn4BHOeu8<|gI(r$X4-8Qk~tzDf~qO{RC^WXILx+d?F98bg83)@2;O(BKInf7oN9r~|#o8If)Mxz8H)R+o{YTpuAws+Jmm&6QuBuLx_$Xdsry4%k#JXBIgx|R&<Thu`S^mGDvwHB<y-G*sKZ<{1fx59^L)XPba$Y!u}%I=PwSHA9#1P)22oa-IGZhiCVS^5cgVn8u<>2L(!!=c@+%CwJ8X!}$6`2P9ad8HAQ<PfW!vVf*4Dj`Myq8d_#_FH))S)OSR#<sjtqv9=FRZ`iYxt57eaanu`>&S=qxkJbFE*bYv^<x&rng=YMwJljJyI;O^AfRZ(5Rszw@*2wSD@$m1zuGT~DIC9)rrHg=)UR4;O82ZRw$-FvOom0|_DU+PI(z9fbRxt0l~C%~CGOoWq5XBYz0M5d_Pix?EG(qc=6rtTnVto4IO*w|fz4Me(bA}vE?1F|u3vmH>V~86wcap=3&fmsvJNb3bQTbeQe}q<QAY^OS#F;H+Ptq@QR;3%(~`7I)waP}4O!JF1yWOQcyJ!;l|}n*LAxR-RSM|LGn_)1zU*P(J3DJTyJ+d3>o-b93h`ah%E&Gik^eW8m{tJohVvE(S+bJ%d3xGLhm`JVEp9nCax5UMbo6L64tSXD9Y@1ut-w`stD>ciM25lf6|^x?bOn%b^;JXqsKZ5tAv135&RkOYeC9%n7VJzzJL43>wgpH&D>MH*SIPN|?TK^9!8%B5@0H6R-6&R7cWuYHIw{B`tt)J>h9OiX5-Y`>m|NYlWu9t^TlUR@-5?_e0)y^T#N8MDH$7v_g@kI`MiCF7+I=#)eu+QzI7?ZtCx=VD9wwpJGp9=|B56}%>nOeDt9L)*DfNe;T;xU5f7t60-g`Y!GKCf!xUEz-!ycW1s_$EV7EO*BIFyOPos0oUPm*j)ne3H?EAaJMi@`y2)JsbhYgpEH<xNs=ZI?tJ@ZzN&ZbR|O)t#}$6>KZhh3TK@LAa}k(<SqK!q)3B<z!lX(jRd0f^h1QDivJE6RI$gcvW~qB@+yddM61qP3ALPnh_XZV0y|1LC*fkS&ksJA;N%yro@s=XsHCzWC4GScmyLcw=4ek?>`(Jc}E}4kI}JM3E1?P%rh!Kok<L6;2nQ>|HH*KjVJsh2dz^=srM5cEi(6XLC^>SV!T|!*->|lwu&Ycen<-vyiHLA0DHKWI%6}2h@m(&fUC!=rU!F(jw?e%4hWKTfR!+aW-x5CRe(RxIObVz7~-;tmiIBpGH-K}9=$xdj*0wdh+RoN#9JXmnPwM4lJ{MhT%LaWt%M%|suH-KFTo@!Sa=#G4I1P-6?!dD^FaGF3kVj;7BMxFM*|gmtPeC~5qQDmK3Gs=^Eg{-wl@eZ%=T*)Q^P$zc*U5TE*KekG+JTyS1&kyXmJKG4RX-lB<f$s#qZV}655NSTVXPlvIGgQ7o-Ei^><4T6s#)B5lt06i{OxX5#CNY!}&2j64_O&Dc!fI)qT6<uwv<9gmo4%jA(X399Yi#8A2KD-2@F>oSeKR7PsB4ItmVO*Css_o<gi3FBwS-p!5)G>X!ubl2l;rc<{^=mLEIm8`L4S;(=8&dudcvxkFxPM=~_;453v1>Hua2{PznYwBPz4b>aqgP+%0IsjxmD;SW6KG`=+%<jr*;1|vIKpbR)q!xfco$;q8RNd`@D$w>&wvn_Vc;-yzUm%QR|hZe*+ztiI6n8-uvw_DqI4{u<<EARKD%r4${8rm~Yn^uE|mJ9;K>WjxHt~Qy5!-(`8TVeo6{baaMhZ4WAbV#jmKIvf;I+u?e*!KYr7aXQxeDeK4qvo@TVxVRF#TNg^QMOG%zDt9K`npl);5ksBD}T&sRQyCViu&E>+&eayG8Q;mawn@GDHSz0m-wC1)f~iG?=oMK$9LqOv@0YvqHW20j9^e^AsCPot9o<%_QW!)*tdgRzxc7(Wu1!+gb*>Db;)o`b--IS+t{vO{1oZ14;b)M_H*Xn^XXK-|CV+RV>^0Kw++bHaKt0cHQeJXUq#joYVNL~Zr=p7GkG0pUmm*l!<J1_rRX3UvX4j>KOz;651ZPp?k*3$H77Zc7M8Dd6&t>)&@Z>nQ0;Bi*Wo~kE}|yYPU?e_b+Y2?B)nxWAQDVMk{{JYH<j3#(!_peNlY~}t3;=DCwI5ucrD^c&ceqgjc^+}cC*le`Cz%JD(Ho+Pcv0B&N^Yfp^CrsEGE`wc7x{IR{MI$Y8+Hu=M+{y5tWb~c5LJuR)9Di$sJdZybB{(l0Z9{kQf!#Ara!{=W=P6!aLozQTG>uSbXefeAYUjX7j1<qJq}Dzk_R|NLNL?T|{GSAmDSm7zw0dX1otg)vl)YLp=jEv0e6ENyPBW*8!<mxX$Y(D6>Rx2URRbSOTj_g)rkVoRUf!Af*uhbYxsG4yD+HyvwasO%lR8F$F#(bXHtRA!5N94VpKNst6$`Pxx0g6ps@3N@Q+<oub)Z5XJ-Ax8hsE>^vWB?iW#Wq%66&saOU+f(u3z>k1VagjC?Tb077;!SOo(V)pck;ep`{8@h-vvsN6G<rr?O$%V^QtfmEY%rTs0Vivjit*cBe)0<e4Va<xg5rR7|5=uCyun-#M2*H&h?ZG!SwyQ*BW>ujn%F1Uw4`Tl!bWFo+3^m2MHf?i@_ADG|@IiR}2aDJIB29%4Gk?>k9YQvTFTF1Iibe6*z?QL#%fzm)-7Uec{gR}n9lQQZ7PX`WoUEgj?vCx(AX1gOA?}wZ<L?mvzz~C*&JQ)@{D%gWq|t2@6B)8a#|<`(Zbj|Db{9>-NDe^&*_bxzJ6itxI((I?Pp9QTS9{@qWc)|DipMv)Urh!w?JXV7R5pBKW@@SOeL}eI{?#kmS~XJy(xt%F!2#+uJ^8Es^COuRqW4*tV)KXyCPL2Z*DcL(6`kP^4SBZkt@k{TelUbU7WVO9>sl)Z;h>^`{+AJt>qRkN!s-9gaHioC35ADk{3UFTBP*u$Gf?f(KxpkO%3G6?53Wjb+@k)qzWl8;IlM4QFt{DlTJCsv1kI!3ALjJ9@w+KFg%v?FoN+Xn&`b|`j)GsJ=^Xd+bqE2$gg~AT!^7<z&3A4|CAd}F<!u@aapM=EToKVE;aC*<Hj9)i3U8}$rNL~C7c<%bZy`@D%ngfthM+fKl<fMOs)#C~mN~k^y;WPgZ0Q$BX_3Cxlu7WqCG`M`P>3Plc}7Jt=yH=BOIkfK^yL_cm-sqJGOH|}q-^m_Aa1IWl-!k!dlvd;H>^&1A2#-(b$4OQptSxTTvYlWZ3iB5N|NVyU_!B47s+UZ1vND)inc6-Qz#TCn#7yRSoorZ@!K%TqtVEB?|WwJi?*gIj}N#Y>sJaQ)PdC~O9%G31P=m7+88ovhjkaQSqI;7!h3POM}%tdiW@z&%HJ5)S{?Vu8TcdMe6mMwHUTCzR#R}7E|TU94`E0$mLjG;UPidVt)=`Rd-UE%VZEA&+NIoRl;i(hTPl{k68Km7d+OP~dvGd^((v!%{0jX5cu-S%w^&wANbf+GlVZYJ?r_DQ<{NkL+-n16of4rzAo5k)5kt;{c}0zViM$v4rA1t&tHPQ}qyYiU#<YlVz_QUp=z;wq97j=ZmUjg(rD8=Da+I#-5?WEop=Mp!sa_+4Ra>w)(C5^3DXMX;i1G{X4q1jFikiIzHqtSlDDX9US<WWvI@tpps$TGr>BG9Hl{+S2Tl^jJICC~$DI@>@H4>F32i5c;%0{@#Fyv2#U}MC3wAPg28rfa-lQfshI9DCWIeO#AT9AUg2l&_}CJAIoe;mngvn4z)ey6wnKnYF0^bJ4Xn6y#!(<p6n#kTI2l_3Q&!VMdZt5&P!EIaWrMpyFbVC#mqIltZ7*^$d$cIc7YEugykUw|zvw07%t7X)x0z+xbNX2R#-ngu^!5*iletCiVRUUpB~9fEnD{2qc9|NH9&Cp89rir3^c8rm@Yh4)dtmo37I0O!jnf?Qj`X%$2%Z;PC~bc)GguQqNyo2RgpqQT;H2WT6HGqdw>HU`xYANc`knYrX39|!q?I$!gCxcKe@t<kQNaL5OrM#{k%7szt@Gxg$7!c34}j`k~@T=HR1^x)lwG3|B(HP)8P)b6v;QA*d8Sg6|P$SNrQ8>JKu_`X=s=%yzR>^RJ4PYMt#S8x+&Uh4Qt&g*z;tW&H){rE>&83@YHH8IfQRBxd1^hUXBcF>%eFS}LeiT5F&Xo{lR6hcP2(Hz`;8l<=SBtqTTX5g{eCxJ?$PQ387)$6K#W9)5f)@oa|W&xOZw{0VW{=LHP063^1VSq}(8SH@HY<4huyegY}Q3+tUmH3URbW<RwVCB3_5DZAW7421WuJ0_V48H6*N@G-#GVg^tjB5D?aStQ0yG1Nx`ODQ}w!O;#8ZO@}4qeJFUh62%n3JmNjKR3N^L?naEN3<iAh13q^VFwet_Td%{3qflhgY<j7*jtjl`n#@-ygK=B9@HtGlTV$RnplwIK)ZUx{7=kd}_$S^*eQ5nOe&qkraOP<6CckA68dh6vIQlr}_8TjILk&WHWqA3%`!b`3F@(No@pB6bCP$K>)MCgrs1<@l==zbh7)W4H;{vYuWp=nR2=UJTvy`)`_<*e#u`LUIZ5Q31WS1pcVQ=8;5lO#^<xHJ@Q;-+h(5<&IQXJUtC@sRY-CC{_V%fJo~Y$w<2!Gu|g`To5+Mkj!uU}4lHGfW8Q?hz1>ifdgTm-8#M=H8ouXt996Au*KzikHMSVLsekxBLrd*m`_n7xFt3cZ+~)%~XFF15`Ag+oayeh20`Ro+xt>1jF%LNHv6HjO=}u`8+J_!rydDxS*mjRSI!N933(x&w$82T%j8Wna>Tu{kqQaG)$ezhU!-wl?1sF`|91(_7Lr0Jn8_j~$vS-C|t(c4i9(9uJtPDw{A~z^Q6$M$LPpDp^jTpKvsRk9B3wMlbD0x}zb!l1XmJKZScok~Qu$!KBS2uD26zMQrtl6+XEL=)acpfBFIEvNvx^`|qmA{~VJ{*g+9EUA5-N>(w-Wm?8D6Qe&1)VHmP!OJJd+QPJq}^x|BJCq07i$A#6`8^QFSRvV$0Th|Bub^ICH_4=CuQS*)`xoyuw`Q!UBCFi7=7gTPnGnPD!GHo@}SZ>-8fL|Af6@gu2^@gq8RkX$s1cX#<4c=DoNZcC*=y1L-kh~5vY3oe!!q412DK5jPHmAt(mc<=kKchp8bZH=H#$zE-4xICIKWFxkiIeq=MMDm{&=<5(U-o&=OTvU(3?0nrm2fM1sy}!M3+{eh&%a!d2b+3m0S03ljebF+n!9nF@(85$((J&=PC!T6t)3>Hy~^_*i$g+m?{W=~SQDjcgTF<w`Vqs$HUx5mchYqJVSJY)zn_sO`juXK=Gr*Y0I?chOt-&h86kj)G}4SrAEQNcd4if0y&CBJ}vs7lGAd>fu|5<(A#o@b|j!Vg9yS-6aW4e-B4EoM&X=l;*gQ0433fnO#1SE^M36PIi}1LW{|U4}ELrS53D)oyIc{bFSP?^l`aePB~6Vsm`)eg%gex>@F*)98Ew%D>^j?`BJWPQ$EnQ3yaBEN}7Hxv#y<mS=K5o(-HBV(#0&CIz(LLR90V;>$oOcu`Ks1RJy5M+v_Y0%P*algGKzizl!+9EXoAG+gOpd*F;?`F|n@>!dP|E!6zab<q`^|V}nhyM+rMn);=d>5$%>(VQpxilzet&8L9Ul7&TH#wOj;@6mIpPES>xC@R4??WR%|rsk)N)JU|I8Yl9O=Iy`EyJ{07!=w`#}W#fP1kdJCR><e$Tk}x>1%+~n+V==?NRJ*g+BzAc&M8FC<yk(bQHyFhZQ=u2FB7r@g<fNpCQXy&jp@>m=gXBL{aBv%CuQ2s3E`X>F?<gI7cY5J{OcRe~aBrMUhP;8=!6<BMKJug<H0Qv(_-|+Mp9Ou9V8+;%1~?<JcR$8esIWMN5?y|L`p)~~#fSGT?{XZGEUbbX?j<+`n9O08$k=$y+0aN9m=B1rgqfs=BB?6SeZ-kclLbSlHHNL$L(4nK(x^!BHk<b+Q6}lC*uNGtYQWA0<8T^Kod7AjbnFe_PNV)Dpz(b($_<eEpC(B@mTIAndl^L!9A1NWCO6h~%*OylJWn3Z#Abgg=h?Uz7NiNd^D(=bFp$Rt+a$SVI%#?r7%+8xG#v6j^1}Nzf`1qX&PczE!&qHt%5J_qfhud4fHq8%*$}}jI!%@ir68c};&8)+J7=6Q#%@Wj5;`SD|Mz*6hQpRhH<jVw5Ew$Mydu;%oUBvJ!&X2~u&<P(O(eKPJ!F3;J`irL6P6K7CcWZZsK~b?q8ASt?y25D;n*S_MTs2KL-dvksS%|fpB-IXoLoS`giwr|h^T*Bukh|S&)x;&SYB`8^~Z$T@-7zBelo#phfnz1C<3+5D#5O*s5n{N5~A!6yZCS!J}hr=4<+6cKE^aExoD5-?X&+lM=!hy6wt5voz4w+#y3TL)Yn*68}9H;lJ5dy`VV!bsRX0tI~*I!Go$4lQq(Skw!<hoV+~YQVvJm}ZSvbR(5UR}sNTJcd8*6<mB#jp#=O%UOq{Fkms+G%6HbPbrRF+*cXD~elgfGiGLvJv(`rlo>lcG)+H<~bwc5p3CU5nAx4pCH0>&vBnf*x-v0tioK{4-=VK|X*5_IlXrguzOAGML0vsu$y@ATw&xAS^;ceC5-RH_}n`^%rI^?qnww7j3fzIU8(#yS7urw<<+-lwichDs+x;}waXmd=3SGma-skAxnaKO;Sr|4Bk)K7r3zNv(9Ha{9>^IBO8egSG)ZFo8@|S-$O7b;8l`xVq0kWxQs4@R}{9-^wIliVZ;Jt|X-D*wp8K&#8_29BgW0E@qMkwF3F+@$s=$0N~HliF|%50;<PT`BdLJxR)CGfraa!QC~byY6|!5n*(gkBEbBV0|)r;Rp;QQl#Hc3vUdb}gn$|wLmD4=<QdYauH3C~&vE@Siye3+Ak;&bZdg;vJ7wK0E`jS?l&^zH`YO;e5Q-eQ_aYZ*vykhXcN@s?avP|ljU;?G3jU>5TnSzTCv_T8h)-JZBX%>Bsx55&ECWL-Z?O=HD`Z<aKrj4vP^0eHg5S?$l6dd5z&FH_Q~Mvz?_$`wP_D?k49A*&i+*H@Q7Gt%ItT|4U|7!b?L!>==lJ~O=<>w7JbH6>;+<Zeyu0xH)3@H~`^%H>PR_lL=cn(E&i~^5>Etg>k2gU5sWkV;)XH}ssO06zpK1SnfAsD|{k%N-?n3=M{y=r#U#cf+lYe<Xyg&VKKb$nasz7!6{_V-11*#qa_2GR1;WMQL)S?1EKT`+r6gB9nro7-uO9D$VWrn}BOVxxLmet_WPWgPyM`WF#PwpyQ(uq`gbNZe@>irJjx-BWFtIe;5<a8Ab@80fs7nkR!@4r*@P$n>k_zWq%Is5QtHPojryr(Ct>BrOoKu#rk@q8^qctyQsv?rLkxctl6Ne@KVQ}{eT`S#@e<o)pqY`Lg03q%)vPaNz04`*jh2LqL_ZY$q@I6pc4?mgP~b&Czp0)}4#bt@`b{W*2@`<m)9+onqg=7vU_u&pXro5Dlo`o-z{i<9$9jPQf3lOK=HegOXdrRn`k1KS0JytS%pYOb`PJ`@Hg)^FX^@-t;(u=5x)`#<z%h0(`ODbG6oNcNMa_falE@i>vrBZ@m$AHv3^6a47wQp(msZc?YFL#L*s$x638q3O(x@~*jX*o<7CScxhmhNPw*iMOes_a38zc6a#X`HzDqMkC-`d1%FF>ccsS8os@)HyWjD2@43is~~u`PrJX8fa##)S3_W;=|2Y)OF*iDVhJHz8Ov>ww)eoM*{Ox?%l>TmX~Us=^S_28C-c~iVA7Jz8@}~|ZHSG!e84Q)s2c_#9Jz^qiTv3WBZ<rDe``b{$2ytaMKgr$!an%~b4-F<-f#uGB^<);r0rQzjtd3iR*k{#`h{f%m?VR{OzHlpG!8O0QuAdP7$BG8dvW=S`?}^Nu{q2%IbVP)N#5DX1b4);IW9+f7rDj-FGp<8sm6eLZ0TQWlf?pqtSwXXWSiiK4NN#FVuBCaDAFijwFk5Ex)xkpjJ7Q;e#5ptj>AD3$Vw_~kl(>|m2+mZ&4zXI?@x|5&yOyMp0iw=bv9AW`}4aq#z<ze!|;=Jt*$W+B4a)~Q@}omFS^wW<<IqPG?{q!oKu@xgPqTq<oGUZZM{MdV$j1X-aML2S`X8Sr;@&jiE=cb;LT(bvTKL7g2_$A%A#o!u=5P7$+qAc5kZEa@p_Y(g*`Eh@$fMbig1v@-O3@vbCPo8C`@?P^<6O24vB6-tm;zcR$*vkOPab1QXA56C8YX7LvLj`feIexc{DMJQ%Ii(X5p_k#RchYzeiLo6nFf?#pQ>0J-$SWvuW<_?R7gl?g#q!2NL-3*~%`>p)Aoa#4FWV_#m0bx$E<G@+pjI9ym;OsIS&zuzv|*bCs*Z39))=gp{yHP93i|<myH9&tLEu6hzHNL8fMPvvl>+$MRa_6v}dYytQLrzj&1ULSK0@O7=58Xzh-0S$ZlN;;vu7ELA+U>Mu*hXeE?h@TKw}7KrTyxw3rAb%iC2^6cZ>04vlKCF;X53t~(3)s@3!PD_0A?{jb}g;!=yb?$^hRLFIwIwjt<as6TgMu7i<CccuxDs$W|OS{JoZaPa>ox3CE7q;9@sukgmZp9RsC*Wf4g-X)J8@D;^u*0rRY6AIKz39$hq2z+(E5oqLbz)`~qb#ikv4u1m#Z8cf8KY6M@BOIkWzCv3VCQ%*Rl5+c=}_4#nd_HLhez<>y$n>+k?zh;rNj?e_%_IcEX?0U@jLk6s+1&IwYBr`R`L9Alk|cFp)g)m{Jpv`Z?vI>r~>2qEPF%OQK(l-8he$e(L36BBwhLGkXB8FmTA3g=sY!Ak;YlQnZeR=_VtUeZGw4}{+_&7-`Fu_vVDob%6vQX&2C%ogNs~lRAAK(sFuty8Sv?(yK2w}kJ`{w-GWeA*41VZTOxpxA`7tH)*RmRH52hSk2Xtw`udf;RjG4&1zV|d?t;fys4ewzo+SA<UlVnuZ)KqxlVA4DBM+Cltp9AwUkok}OIF@DkIo<gw*B?%SKO~|p;5LMvdrNZdzf4kh+}ZabSP89S?<)K8?oBxQ#70h6WIWY<F;v^*$|VsEk`)%_Eq>295p5BmpyF-5LCdr!<pYyY?mTUn7yDVx|Xkjovgn?Ms;^fTcEsBD|xeK9Ye6%sN6X%NM|qVnk99mn!()(HBQzwx<Mf&Q|nKbZ<3jY62PLrY00nH0i^UZ@R?~^0bUt2-Sm@_0frCx8;-~=lvokD*OS_%JrU5ed0%N-J$Nd@|G45O;7N8*7SWkdi%K;4gF8-b2`MV@bQ|7ZPd~CSe4K`XlEvR8<18foA{b9;!{|re`ydPYP4DCQ?R7lP^I3NA>eYBLq?WiO^hs_anJwhv5g7Hm?e6Z9rmo|&Xb{G54VarGobOIAJ@s1OCx!cZvj~^NdMT~<*6PD%B@&zGw8(gvjUft~$6uluAF!<}F#r1Ghf8i#QuijAc3thk{h(5|x-Yf6l>3qoH<sMSRC_=3%8Qwn**q!<6z$8I*iU1Y;L@C>4ODIwZ(4WMHq-!cQ*J*=?hLh?k?4?tY%;%X7I(BZ-78+3&pP)M*T|{``KR|EetO?KKl$<W<fq=Zr)TUr;Ong-4R3K*gmTf+Z;R_&RhUcN7q?0<{F#^#AF!1h!xi$Ia!Ym597Ff<=<MY3@}&3i?CAIeb9ZunQQQ-*88pQ1za;bYqw%ZK-;GTXMgHS||M&m?AOD;8AOGvW|M!3YKmYyz`oI4VyP$iKGm4K1`ABve(Ega)1CcA8QRE2mvoL|8ANIVm+`@Dq?976SkN7S={BVA}d`#-*4{l%G;HF*`Af$Pe<)#e%mP|}{adK}@h9rIA)84?ri*;2BzJ3&UZu1$r5apVBcrw7>i$q}iySn3pzw>WT6agh4*q|0yr!chUY8B!deRj?_WT0*Y;geMU%@G7v33GP+;msdUjxW8BN8g=zKb)UgMO3DI6cRLhr|;}i))^~tlTp~C-4Sswevl5v(I<Tkak0&o^hqgQ+DX`j3P-VW+bmSdm~Wg1R^~DKVK$vPa+BR7>ub!%TPz~k-|FNjr?3U=uacTfb`rHgwEh~+;I8FD0S2#LSd!E<#4NJ^pL}Z}LV)E!OT@{OJecr}RX81<PkpI|fUi(qLuQkga_u&^>ZUre8u`ZS?zFuxy-vHkt^SlRkE@zGV3u-bjZ_w5R=7`ok&wWPCf~iOm?0`qm3k^q-#iUJ()RtpQ)7+O@)fp^NvKpS%6dUROD0hK)ICA1md<)h-zDoR-;XFsW8@8A*4sI#a{TJxYd3|_Mg=9tco@Vs;bJ*Gmc|0zwAyZUgsK{i5tP`d0k?YTuX~HJE%Nf{_2r#*E=~lTD+=UDc<ENM>+qcuP1T}&CXu$!_ZMYg**T)mh$+<oCo&X=P-Emt|7TyfXH_icVbVzLDVRQ!y}%5lb?#v?Lr}{m$$+iWL=f7yQCprZ-trmD0v9Y7{G!IoLt!AD=4lvK>#xa1?K|eJSWBzx+ey-=dHHfv-5sp_&l(jib468c5p(O}{-{vjW?x-4&n%Zw4eJmKsZN`L>2ko9(-H4mc>l?%hVI)rCUwCx3fX@Wd^T>X0Gi(GAQb5NT4yD8>H!sQ?&=zJeTr<;94v^=h0yvI82dVCwR5YR+ZqjPm8+%|r*-&&)vFU}Z9|i!_AAYCfq|MJ?4@X~!EzCiEyo+&f!tjTlp&VRobt%{YjEqHJ2E4)5_(ubGqd8x%g5YYT+{&HJ*Yh4Kb#4M$f0~yY5gAQ3`41;?j{k$z-K??14>wE8=_xx2g`5rR=fey*>YjWxy~BhVxm!{nD)};*uX2-m8-EeSvsY(@}!GtYA=_w(9QmX#bZsUMSpdD$ydExtPUH+rPzAUkUQsf_)Bj-V+G3Z&k^9-^whJvR~(^^9I=sj0&zK0#~L6#Py>;rGB^hlK(Y}1z@^CYxe;bI%8<(^hzFssy2kwhgM9UBc>&jzw?~&py&pc(A5tSpO<*z!xHdvlQY-J}1R+HxmWnkXrO!2O&8=D0&YFc5_T)CEX!p=1Jgq)inp4wgM@_GCbEH;(nwF}=&dgEnCLN$QLWp8h<1}rlJ55WcF`l<g&*5|kZeW2yKDsnE3Q1}w^5f`eEAmbq&~Ti{pf^nT{&9t;(rsD=so~E&W&*HKjyn@Hbs_C!X-+mVCz@G585$|I^Eo`ULL+cjQ0*C`t=uYdP;pg&Z)(#VoG3A%1dQ$b;_ggpoHT0nt8Oz|whr7j)>sZ3<&oN#pVh96jfOi*hL$l&ZvXaNsYc6lBd>qc)F=S#8TwT-BkhzX#*ymW3?-I#k#N8(i>aDWdV?M<*ASZYHQTk5YJ?cmsAl6gR&1uvAy}$OArN6oCC#QdV{l8srd?;XDozvJ+apRx4J>0>l9ClFXgL-d-cT-HCs>)n)oXG6LM~E;nGeaOoi(p%Y&FKKEA`zO8MSUL9|Hq?_0ooNFjDVY?7o*l^r5b_rM>DgC=i+6c<g#;%SWUyBCSkcZK>r$G<PuCs?lVAYh`o6qhCiA%@vbs9vrv5Y(5%A4>qwnqRCB53h1z0Wi<GCc5AOpgD?%dxNyqr?A0USeR?I2kJ6w@^J?9XVx2o{zRB)derdMh@XhBrng+`kOINgfs-&9E>ay0>Rw%J$t}it8oB?Q5!{PYk-7sUElsSZ=0o2!sS1doWcyXf(Vb&?S423QqugBzPBSqa}^SGW&@N`hI(bQwLpCpsUI_4!qQ!N*vVs2CkRR|UD?JGG-L~0{(<pt%RLj<1%ZDsn`Ab}+VD5#)B2kcKeW`{bCq^;Q~>S@B}D%2A5DXX!1%52S&8JAuSMGe2J2g2f*&%>Y!7a-W@!>kjPH+Rk3nqF~{A?FyY3IPSvb<|BMS?E=qjWCciJAI5C#iT~6zH8lGjIK*sM}Gp}d89=(WFoQC{gAL3s^ewcpzC^xt&lWav8QHi`siJCUO4U>)5=oeL~nrB;*f+Eyy+@C2;R7C%GwmAkIxce6rkG2{Q8ADhLg4|8wvK@9DYfpQe~cVU}rK~sMVc@Ex4|-`>apu|JBjvUvKbFu=&f)m+VYtU5~m37<%^DvT9Nv4!xs`<I_`2`OrpU{cg>MIkdL2+sop}Pr5dN{o)L)G0U+`&Y3T6v})9Q@#&k@T`$ZkE7Wn6IDjz|zJqktma82eJKeQ#r{G}hsj~sXVtyZnF*OS*uG3||#3;-h-f0G4N1e!#U$gKSv@Y*efY(HFEE%Os)MbMC;;Oy*I@lZ?ZGL<6xXZy6;<H%hl%=7MN@MpP1?VT8UOzx$<IQ1o3s?K_K}y*(0z^N;;wk+Z39ZIe@`)+Rnwig@6QbyO9Q}RnumDxy4<+3oe2^3ru68gmE}vI7pVj{`v4|S>BsM@s;ZU=`60w5Hs}#*|R}eIRx9Azj;&;Cabz&9=4^Y}8nzF94btjX#5#m*9U@EcHBsVNoC_NG1GXZraY$whox<Vn!0h{kdAe;_ta0}l!l^xMVs7iUa6rudxLa07W;Y@*yQ=HwJy9aHy@zU!w*2A-a#uSQsa0R)tkc8!RbmC|kFZ*^IpevfatJ^+fqp8|vmcyxf(uUX721^IDM{Ny*W+m>-oO~(u>(okpsA1Pxd2VbqYod^-3H*l}d*vK%*~R~#=B~!4ts{y5E3Z^1?8-Kf>ZG18M2ZM)qe~MCRM8z+wgWc!f<NMCLOA39{dT@~XZG!THl(epySCWg&)MDC+4=YlBjqpj$VwmB5q_7eSqp=!GE1vcWQwk)_X&}WGBlH6!EcVAPfw3dGIVN3d-Hs7(_f4}li@jD?I1G-(?ExE(iEMD>Pa(C`o=D^>lB)${fl`fcK;s7LrB}&^WO`eUcG<UpHE!dd6f|Aw<JYxq67+Dfqfml$4S1J5`JJ>5{(7Tq5{IJ$JU%WRZ_+u-R``)2o<-X_Fk`xoFUykHfbN^werWGaO1>7Jd$#`uM#mAd+o%Mg3LN0DbUQ9_@9;9Jx}0OaWDStgbh(_UhP1spI#Pa2-(Q^5t}Sh>!tYJAHG~E&D_STWtdRKV!27DSh=T#VZBfo_$K`Kn`-T-=gjWoCMwU;tw1w?9&^V7;Lm(uf;5n$_Af8zgFIim2ZbeA%~8Fm{wa<}p7^>dnhVH0JODX&G91mvkT=vZvH2|;<A)qiqol0Lp}-=c5-EbF)H_=n+Qdi}?}-g|?C-W~H`uvq04cRnVh6u;!Wlb|Gq>gqFq&N4++K=2)8ftjND_m#u7bka5UQ-4e{mw0u!m9t6JeUXmub$ABX)ri7nD)%KAcVSK47%E2lY)}ySu*cLPRdQjWsa-0bbgJdDpxj=wd$riG=)3!1p*n|4rvjP_8WoD2HGVY_D5m<Bz)63t)aq=s?#R72p5-@9yc(uTQ$~-yQ!8cG+M&TimxYiavsu7=ZBIO|u*_L%Y$qXAj5*IKe)<KLg|RB1_7BDw<GCz=Cc#<-G9n_1jbT&*5?R?K|zf0BYe@_FIloq&RwL4MZ+<x%O$My<0KINah7dGTIo6TgRmdlni712$)Rl18HzF-}a}g5ko$ZUQg5}5}XhcR72RUc_4>uY+P2$#1L-+ZvF@_C&9beh{xo@Z#yNYFcq-7*Ps>z$t%+3r~6a^!(ZPsHq(*Ja8r&!Y!|}@&$pJVe=b)I`acGewjijw?_R>-B3F~aLZ<Xa_FY(G4urLAGnDoUA3s|YT<Gq`e1U^XcOG|y?n6GI_#>+}0}Q<n-$tZ&qK1kD9&W?GpJP3Y2Ly<-eJ3e$mR9!$gzX0*s~ic9+E~W}5jJFBAVywjFmr0uH4Drs`?$}lr#)BcGqi-Xa82xNQtO%20xE1!DIl9rwLN_hD0Rkep_xJ}K#NmEd&5=&Io5TLn@{@24~5R$uTW*j6a9tv-sxx#K=u>h12qq+TXZLWLIi-dF2o=}>%+<=$XD&7Qg%gX;EiNSfDb6b(MU}kunnpP(2M=jy?nm){F_(r4j{HG!%i@$|Ale3+I}8>$rwJ<t<<w<2g4FQ&k-Lq-+2+aYw7cn+aJHf@8Z%sWyRfycgjWz*SOjhJpH6+ETj80iI_S-RBGq|QTJU%9O%{T23L0Lr`Nw6Wg*N8I)OO&HpN{AAR~klxE)XOcD75Ozx5mC>6U;wVA@<kV7_~ukeC^B;!xO)SxI(FSGWDWd+;r>KK%)8&|i!J#kzhy?=splSzQSss}$B`HM`OksH3M8epf+mX3w%t4d1ll1Mby+Gx{(GCEPu@O~tSh>kn+CKR)xiV>$9}HLj*$*|GkV@G>Ss)!T7Yq+dN&Gjln6J+dO$U)RryYG&iM2z>Syqjby1p#m`d7&h&E?|a){%6FM=RSGPFicO(^(;HB9agV{<&i2d?{D9*qw}ag#g7>EUhjRjSO?sSo=3FSjzM}|!-F3q7H6xEQO;UwDd7+&DkSr=&;-Zg%cwvV`r4{1qs_5;^cbHJ{Prb+Zv;gNQJwa3wl)alUR-NWeIXC#~4e3)J<A~z2FW;W&1@D|eo05c>bFZBlyoeYxE_pZ5$76y(_q)LS7`!!cKxf5G)2WwSJSA*ACq7P%sZG^MIFsPqJbT{$$)9jx!H8uX#>l*3B|fsIzVd0T9+cU>8w~3pl;3n<!1XuTH4E@HimH@e95}2;T^(xo`Q}aJ>*oQx<#sRn^Gh9OBF8W!vj=m{zK`IC5V2u*;h11P1Ngj>U=_$ZI&o}pQ4_Rq)m&?F?Wj5Fk8WzUy&oWRJp8-PFafRO0S5YmG2_k4w+H`ucVYrtTf_u5<_Od!%$Z}x8ri4Y{>^A{zyA-{HDt{gLw*?#B4XGS)>gu{Ar&M`!H|?pQ8PUF0p+2)&c``&T<2Qe9AjJAz{^=xx2~T-rLE(N;|ef?Zn_puE>X)4N*NhWF}pi@RL`fMN0)<3wNXnO2&M^$T2EIO!f(6@G^j+2a3k)>S;WvcEGZ?Z!7_wbP}&flpvq>T#F|F<Lv=e+LpL=XT>+}#zCp-n*)%{}gtpD66Be1KFnbXtc8`=7(6P_!W9eoS`{>M_oOmk@RPm$?KyDQJ*z#sYHp-y~d?0aWTHUnYu592ohzrry<DJ)E6xyI2>mya?1nv*71Z)TL>q3zgTF-~n1S%auk(L)xVqLw2EZMjL*GIUhmj3ig;m)eHT~D{C?0p+GsmfQhDrUotnv}w-J$6Tp2rEX1Vnjl2a#9bof)A?g+|ijztXjI3X;N%R8%;q9t0}PIuoyRCFVc$WgeRD30BKfR;)7i>GI?M@MUS(0AO1VQbU#;vPHpKbtm?7%dn($r(2kB5bq(Qvi%ns*f}64;t~(l_=T|b%N0xcWTZwFlM3Ic`Gmx`%21$g_9%UgU6RzV?e@DjF!_y#o-T?}(KK-q)v{xpVB;KN_C9#t-HOwHq(UbVt@c@j%PM#mHnam$PN*Rm0kruakiFvqHL>2`}H;BOGWu&+~UN@5Cj_xw@(vj0!{SLey^buv59C}5g{=v~hou$a{z68viss$dw*ywEy2&u8n>t&5wH<_v~2$RTkU@Mz$sJ3cOCXeXrS<O6XsBnE%XK;`C^e%dYo^L&Pb4K=nPOuNz<-C8#zEKYu<ggj!3rXbo5IsE~n$4#9Cw^LD$cjX_!J4Y@C;lm^O%%sqF#6T4R?%*0NI8?xi#7CanQ}Vnq$W~kxbMe`i^%;4?^-SwMcxTr)uDO_j>ZpJZ;1`9dKrA}2C~9GsI3*yQ{2QqUy@$-A%jGlxE^CS?}OKeuMVH>?(V|pL4Sfv5L4ce@Z)HLhJFo&reS_YlhOEg+@RL>i&$o9azd-xDg5)LowC7UJA=|4oGN$MZtV@}v+IFB__>2$HLgGaQA-U%yxSm7yU&T!Etn^`|8Zlgl;hz``W8EGk%k*17nUhdxpr&U4Nse=oiGMIyfaLz4k`q8-J3z0wN@7F_(L~aOnS|tJld5>Gj7|v90A}ArGFn|YFRYxYoXkyfUMwR3FkYhCd(5D$%Q*g!GZ#7L!!=V0viE<g&ZeOe^Tl&`0ZleA1)*!9{;SbbNvfpOF9gzcs2D=Hq9mSDvCR0pAzzRMv40jzv@JRFVXae+uwehv0zU3(6-mUm^+DkuSe9!$A>pcg&OjE0k#+Z=XzwujJncq&e$qJZ_rLHyhZUIT$;|XiW~F^M}xcH%|j?Gs1HJ~OC3gihB_D5^V;5Sokj~RiVD4f7zSZ_O=jziEdkiE2uakZbOUn<2_OgW+ZiPz5ND1ScdEl=J`6C+uyXk@1mIV1r>362b(ycq6>O<SFHlFe@D!~xI=$Nl-b03eMjtxD>E|?q)8P>GZcc`BjDh`VaMS^w^L#=G_w&I8!iXZu{n#he%<}90T)=bTRV#Bp32X*LUOMW;z>BNkm?ka4GH@qZIq*suAvXOH;_|~^y<Ts|9|RE;p3W2aH@x+)YGS;C0}0vW@t2Enf2Mw^V?&rOfE%5kPe5JXpWoMDLR_!V7}vt(6&ec&tCNYR0b-0-zv+V<C}je0n2_GW2?oEqKO2HPO$iTv8cg4S>Yf%PxcfNL-vFN#AnziG@%e;$;rKl#9gxqohgkIj=4}ox?vj@MPc>513dTkgVNT8#U0P+xxv*6?s$=DdK(jiX6XFXk2x{5sU|IZl$K{kwTyGv?fx2ODUM$^KafLCaQ%>(SS5`@gMdfzG+;N+cXWlxlAdF)`)kHauw|glKo;S0S`ENKUzvX7PH#c2Cb#pAoux)wUG_nm{1*`X0?CP&?1r{tpIEjr<+bov0z4*%j^JhxX?Vz~S$PA@IIb?}l;E+ym`~izU8?OGA(Kp!-QRXKWsQpz_^&Sv=j(JKHf-Vq%vLYs9X#kw~&nWW2UhjhAf4<esmN14Dqs(Jc=+UG&hVV4g4HjLkLqETW_df;DVx|_j3fm%IIPpYRvLSczF7csiC}F;xg0J|9<wh!?oJC89C~cdeY8lCWpf?nWI;fuLj{EbElKz0eA>-viA?<wYOO$cL%SdlQf|k(l^GP$)VZLp#i@NWXmco5q0&)Vg*D7AD`TqKz66C-cb9IwWuwHnAlLGQ3jpl5rX1eNRN7qwaETsW~3yd;tvonAbdK6xq+c3S9V|@=R%1_iwk9|-F0~mdx`<_oDpW=~dyY8V%h5*4BPtwPlK#$;~i{Xs30iQ?g=t~FhUeNygh);}Ey9e*|TU5wFMD9J7&N>;S9qO6%LC9phVQY4uH3g$EOO4hMV7S0B%<ctp&x;tC1$z-mXJs8rn(wl1P$q+1VOD++se%DFefv&mm-I#`i=wE5&uK*50Hh|z4{kxk8{EOjQK!PldLHK-chh?bLqpoIWWfR$ook7*ZF3?lEj(t!oBoyCu%1cck8Te^4r)j*8%dVP<Y6bX(B=m4mX53|iidZV5RAtC$!HkgP#a!63A`MIi~AR6*60wwA;We|)t@3i8&t%~L2s3DIC;Pnk{FO&J<7d2eFqBhIlKyBPlE2v#9`yR!-ES*gd;ve!amz5|ACWL&Z5i*omxpsgnA1%5%!6BMBI_fz>ysii9wfcjP6wdV^g^gTAq(1$*3r?B`kVyu$wue!AleJk7NO;5}r9g3`pk0d<<Ej;iw9Soio?bcK7#cIE72Smcr$aJy&TGk|J{e-~qkBa&`i{MQkNvuyG;AsH`j#VKnu^qw>nJ6O2`dM=B7wkC?zWBGmzVjIRaVGAPay&3dkdoQk;;8Fg~WasdT%Np0sjE<X2xtx=*l<ZLn~${PcG1`<resyPwvcG5O1ZR1M;2OX6Uyqtek4^YlO=U6$0=rR7EdYRL!xse?=^pi8QFV6FcJU1IYy-}as`=MD`kC6V)?U$qYZOioZ+XjZ`?sBql_n36q%>ef;6a_+}>R~}AUNj~6Y;`vigv-oxI!ykCQW<)(SA@@S5!TJ!<V}4D@(f@?qg!)3SM7y4HN$9kD8KlQc4xvI96ej?Q(WlF_=bg;;5-}Ep>!aHTDFil?(M{Gc-(sAXBE|!7rktL+5?nFF_Rzt647G#1v1GM8S@%1Uew&?;hhG}X~U=^A}DKmN58#!(>*@?^|!;5)7JR1m$B@HHU>CEI)MZ#TTuex5HC*Q7~jbM8_l{1&P}6inA8GtGY`eUZm@Uh+xn9-60FS`0Q%lLcn<qQuaCN~4u5>}^7QakNkRci-sBoalPqFW&=^~DLHUlf#}Sf#A>iM`8!$XPY6NQHn&~PD;y`yX6?#|&t)5dLJ8~C=Eal;PSv~Qg53pxz9_;&Q7P0|;cqQvBKzIxrhKGQ|8Et6f5_!YR>X_L`#rr)y>`<d`L4t>BkYewFrjV=F;%@~D1y`yL())4rg?X9BYhXmub2#Mq=tMcM>Ft@)uq-J_M;BrWGRbpl5nfjSBul|gSiw-Ydxj3+D1?EAqjE}KR@#$Slo{dBt(21$Glqp&Ok=dDuf|dRDv2HPQ<Y>GfbCyr{TyD+&9DiSdI2+Bt<5?BrTm%n=VG7w-$Arw|Lohc9)fH{<|;b~x_kk_SUWg50}+feRiQk~V!ldn=~H-{d^pXJP^8?F9{9Mb61n$qQ*aF)mamp{E@kIe;Rb;Z)D06wj=6ctyrM^N3GS$MbTyk#YY`KEq($J-n1tMNKhH7mM{qb4O#j8amhQ`Avu=W`@H;}Q`mq)lh<1JvTQ!ka<k?zcV>k5_Y;cMSNn$T`Q!Q3hoAr}xKid5vIzb=ivako;R*d7Qm};>beiT*oqN+dE13XRan8~Zp;b5elz)Ke_?GPR~*L-2JXgmteh^-&S(f0W8<*Q!~og`Um>!|RQO2rW<s{{*8S0mx0o`>yFHV5~MN@m67Hh0S(GJu@q@N4OG?LK{GLyw^lM?uN|w(9HCTJQre7=AI@^8z6qIGqK<CwNk06ehit_S2EKh9aMk9^%hRi47BklN6_Mxs3_ORrnmKj;ew_Ri*SkDI{}$bWT%ar1Q~L5&eo$UxqmHv!`RJ9oAIy@3t+2xhuJ<;5sd)Icz6z-AWFmG?aqFEqikqrXzSyEGC2&D>+omU3~4bt4p<5^I}Hy<}BwFzk~hpF=kvpz%nLQqG~P)e=={_CkUl2_ezyb9G=uLNdKTNh@gIVpV^B~T_xrw2p2@`?9ZYEql`w#-*Jc51K5ZMso+(Z1E!;axs+t&;XlhV*~mt)8A@PJP@Wsy9Z>|Vf5ku%{khPJo}09%zl(D8(7_MI&mtVd_4h>-eezx4^wBShZN_yhhf}|HLdfgZ>i?73@<I"
MODULE_SOURCES = json.loads(zlib.decompress(
    base64.b85decode(PACKED_MODULE_SOURCES)).decode("utf-8"))
for module_name in ["colorlib", "adjust_colors", "notebook_workflow", "make_preview", "make_samples", "make_stylx", "make_hecras_ramp", "submission_workflow"]:
    module = types.ModuleType(module_name)
    module.__file__ = f"{module_name}.py"
    sys.modules[module_name] = module
    exec(compile(MODULE_SOURCES[module_name], module.__file__, "exec"),
         module.__dict__)

from notebook_workflow import read_json, use_arial
from submission_workflow import *

if IN_COLAB:
    SUBMISSION_BASE = Path("/content/rang-submission")
else:
    SUBMISSION_BASE = Path.cwd() / "cache" / "submission-notebook"
SUBMISSION_BASE.mkdir(parents=True, exist_ok=True)
use_arial()

def receive_workflow_zip(local_path):
    input_dir = SUBMISSION_BASE / "upload"
    input_dir.mkdir(parents=True, exist_ok=True)
    if IN_COLAB:
        print("Choose the final workflow ZIP downloaded from notebook 1")
        uploaded = files.upload()
        if len(uploaded) != 1:
            raise ValueError("Upload exactly one workflow ZIP")
        filename, data = next(iter(uploaded.items()))
        if Path(filename).suffix.lower() != ".zip":
            raise ValueError("The uploaded file must end in .zip")
        output = input_dir / Path(filename).name
        output.write_bytes(data)
        return output
    if not local_path:
        raise ValueError("Enter the local path to the workflow ZIP")
    path = Path(local_path).expanduser().resolve()
    if not path.is_file():
        raise FileNotFoundError(path)
    if path.suffix.lower() != ".zip":
        raise ValueError("The workflow file must end in .zip")
    output = input_dir / path.name
    if path != output.resolve():
        shutil.copy2(path, output)
    return output

def offer_submission_download(path):
    print("Saved:", path)
    if IN_COLAB:
        files.download(str(path))

print("Submission folder:", SUBMISSION_BASE)

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 01. Upload the verified workflow ZIP
#
# Use the single ZIP downloaded at the end of notebook 1.
#
# </div>

# %% [markdown]
# The ZIP must contain one recipe, one palette draft, the uploaded artwork,
# `check-report.json`, and the saved workflow figures. Do not rename files inside
# the ZIP. Renaming the ZIP itself is fine.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#fff3cd;padding:14px"><strong>YOUR INPUT</strong><br>Upload the completed workflow ZIP from notebook 1.</div>

# %%
LOCAL_WORKFLOW_ZIP = "" #@param {type:"string"}

workflow_archive = receive_workflow_zip(LOCAL_WORKFLOW_ZIP)
bundle = load_workflow_archive(
    workflow_archive, SUBMISSION_BASE / "verified-workflow"
)
print("Palette name in recipe:", bundle["recipe"].get("palette", "missing"))
print("Palette name in draft:", bundle["palette"].get("name", "missing"))
print("Recipe:", bundle["recipe_path"].name)
print("Palette draft:", bundle["palette_path"].name)
print("Source image:", bundle["source_path"].name)

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 02. Complete and validate the metadata
#
# Review what was saved and fill any gaps before building the proposal.
#
# </div>

# %% [markdown]
# Notebook 2 recovers the palette name and object-page link from the recipe when
# it can. It also prepares a repository path for the uploaded source image.
#
# The report below separates two kinds of messages. A **STOP** message means the
# saved color workflow cannot be built. A **WARNING** identifies incomplete
# descriptive metadata. Warnings do not stop you from creating the proposal ZIP.
# You can finish those fields now or leave them for later review.

# %%
bundle = apply_metadata_updates(bundle, {})
palette = bundle["palette"]
source = palette.get("source", {})

print("Saved palette metadata")
for field in ("name", "persian", "pronunciation", "about"):
    print(f"{field}: {palette.get(field, 'missing')}")
print()
print("Saved source metadata")
for field in (
    "title", "artist", "date", "geography", "medium", "museum",
    "accession", "credit", "url", "image", "rights", "public_domain",
):
    print(f"{field}: {source.get(field, 'missing')}")

blocking_problems = validate_submission_input(bundle)
metadata_warnings = submission_metadata_warnings(bundle)
if blocking_problems:
    print("\nSTOP")
    for problem in blocking_problems:
        print("-", problem)
else:
    print("\nThe saved color workflow can be built")
if metadata_warnings:
    print("\nWARNINGS")
    for warning in metadata_warnings:
        print("-", warning)
    print("You may continue and complete these fields later")
else:
    print("\nThe metadata has no warnings")

# %% [markdown]
# The next cell is optional. It starts as an empty dictionary, so running it as
# shown keeps every recovered value and continues. Add only the fields you want
# to enter or correct. Do not copy saved values into this cell.
#
# For example, this changes three palette fields and two source fields:
#
# ```python
# METADATA_UPDATES = {
#     "persian": "گیلاس",
#     "pronunciation": "gee-LAAS",
#     "about": "A short description in your own words",
#     "source": {
#         "title": "The artwork title",
#         "date": "The date shown by the source",
#     },
# }
# ```
#
# Use exact wording from the artwork or collection page. Do not type filler such
# as `f`, `test`, or `unknown` into a field. Leave the field out instead. Missing
# metadata will be listed in the proposal for later review.
#
# - `name` is one capitalized English word, such as `Cherry`. It must match the
#   name used in notebook 1. This is the only required metadata field, and the
#   builder normally recovers it for you.
# - `persian` is the Persian name. `pronunciation` explains how to say it in
#   English. `about` is a short description in your own words.
# - `title`, `date`, `geography`, and `medium` describe the artwork.
# - `url` is the HTTPS page where a reviewer can confirm the artwork and rights.
# - `image` is either a direct HTTPS image address or its future repository path.
#   The builder normally proposes a path such as `sources/cherry/source.jpg`.
# - Set `public_domain` to `True` only when the source page explicitly says the
#   image is public domain or open access. A museum source should also include
#   `museum` and `accession`.
# - Set `public_domain` to `False` for your own photo or a licensed image. Then
#   enter the exact `credit` and `rights` wording.
# - Set `preserve_aspect` to `True` when the complete artwork should retain its
#   original proportions. Leave it as `None` to keep the saved value.
#
# If a recovered value is correct, do not mention it in `METADATA_UPDATES`.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>OPTIONAL INPUT</strong><br>Leave this dictionary empty to keep the saved values, or add only the fields you want to change.</div>

# %%
METADATA_UPDATES = {
}

# %%
bundle = apply_metadata_updates(bundle, METADATA_UPDATES)
blocking_problems = validate_submission_input(bundle)
if blocking_problems:
    raise ValueError(
        "The saved color workflow cannot be built:\n- "
        + "\n- ".join(blocking_problems)
    )

metadata_warnings = submission_metadata_warnings(bundle)
if metadata_warnings:
    print("Metadata warnings")
    for warning in metadata_warnings:
        print("-", warning)
    print("These warnings will be included in the proposal for later review")

verification = verify_recipe(bundle["recipe_path"], bundle["work_dir"])
for key, value in verification.items():
    print(f"{key}: {value}")
if not verification["verified"]:
    raise ValueError("The saved recipe did not reproduce. Return to notebook 1")

palette = bundle["palette"]
source = palette["source"]
print()
print("Name:", palette["name"])
print("Persian:", palette.get("persian", "not provided"))
print("Pronunciation:", palette.get("pronunciation", "not provided"))
print("Colors:", *palette["colors"])
print("Artwork:", source.get("title", "not provided"))
print("Object page:", source.get("url", "not provided"))
print("Public domain:", source.get("public_domain", "not confirmed"))
if source.get("public_domain") is False:
    print("Rights:", source.get("rights", "not provided"))

# %% [markdown]
# The three saved figures below show the regions, k-means candidates, and color
# adjustments. A missing adjustment image is normal when no colors were changed.

# %%
review_paths = [
    bundle["work_dir"] / name
    for name in ("regions.png", "candidates.png", "adjustments.png")
    if (bundle["work_dir"] / name).is_file()
]
figure, axes = plt.subplots(
    1, len(review_paths), figsize=(7 * len(review_paths), 7), squeeze=False
)
for axis, image_path in zip(axes[0], review_paths):
    axis.imshow(Image.open(image_path))
    axis.set_title(image_path.stem.replace("-", " ").title())
    axis.axis("off")
figure.tight_layout()

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 03. Describe and confirm the proposal
#
# Write the short context a maintainer needs before reviewing it.
#
# </div>

# %% [markdown]
# `WHY_THIS_WORK` should explain why the artwork and its colors belong in Rang.
# Keep it to one or two direct sentences. Use `MAINTAINER_NOTES` for an unusual
# color adjustment, source limitation, or anything else that deserves attention.
# It can stay empty when there is nothing additional to explain.
#
# Open the object page again before checking the rights box. Confirm the creator,
# credit, reuse status, and exact license against the source record. Also inspect
# the four viewing rows and source distances from notebook 1. The checks support
# your judgment, but the palette should still feel true to the artwork and work
# well as a visualization.
#
# If metadata warnings remain, checking the source box means you reviewed the
# object page and understand that those warnings must be resolved before the
# palette is merged. The warnings do not prevent you from building the proposal.

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#fff3cd;padding:14px"><strong>YOUR INPUT</strong><br>Describe why the work belongs in Rang and add any review notes.</div>

# %%
WHY_THIS_WORK = "" #@param {type:"string"}
MAINTAINER_NOTES = "" #@param {type:"string"}

validate_proposal_details(WHY_THIS_WORK, MAINTAINER_NOTES)

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>YOUR DECISION</strong><br>Confirm the source record and the visual review after checking them yourself.</div>

# %%
CONFIRM_SOURCE_RIGHTS = False #@param {type:"boolean"}
CONFIRM_VISUAL_REVIEW = False #@param {type:"boolean"}

if not CONFIRM_SOURCE_RIGHTS:
    raise ValueError(
        "Open the object page, verify the credit and reuse terms, then check CONFIRM_SOURCE_RIGHTS"
    )
if not CONFIRM_VISUAL_REVIEW:
    raise ValueError(
        "Review the artwork, palette, and four viewing rows, then check CONFIRM_VISUAL_REVIEW"
    )

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 04. Build the submission package
#
# Create repository files, test files, documentation, and review material.
#
# </div>

# %% [markdown]
# The `repository` folder contains the palette, recipe, source card, documentation
# page, and images in their expected Rang paths. The `software` folder contains
# one-palette files for testing in ArcGIS Pro, QGIS, HEC-RAS, and GeoLibre, plus
# Python and R examples. The `review` folder keeps the extraction evidence.
#
# The software files are deliberately palette-specific. They must not replace
# Rang's combined collection files. After copying the repository-ready files, a
# maintainer runs `python tools/build.py <name>` to rebuild the shared outputs.

# %%
proposal = build_submission(
    bundle,
    SUBMISSION_BASE,
    WHY_THIS_WORK,
    MAINTAINER_NOTES,
)
print("Submission folder:", proposal["root"])
print("Submission ZIP:", proposal["archive"])
print("ArcGIS, QGIS, HEC-RAS, and GeoLibre test files are ready")

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 05. Review the generated files and images
#
# Inspect the proposal before downloading it.
#
# </div>

# %% [markdown]
# `README.md` explains where each file belongs. `PULL_REQUEST.md` is a prepared
# pull request description with the workflow results. Its remaining unchecked
# items are repository commands that must run after the proposal files are copied
# into a branch.
#
# The gallery card and sample plots appear below. Check that the artwork is not
# distorted, the palette order reads well, labels fit, and all panels are clear.

# %%
for path in sorted(proposal["root"].rglob("*")):
    if path.is_file():
        print(path.relative_to(proposal["root"]))

slug = palette_slug(proposal["palette"]["name"])
docs_dir = proposal["root"] / "repository" / "docs" / slug
figure, axes = plt.subplots(2, 1, figsize=(14, 12))
for axis, filename in zip(axes, ("card.png", "samples.png")):
    axis.imshow(Image.open(docs_dir / filename))
    axis.set_title(filename.replace(".png", "").title())
    axis.axis("off")
figure.tight_layout()

# %% [markdown]
# <div style="font-family:Arial,sans-serif;background:#d9edf7;padding:14px"><strong>SAVE YOUR WORK</strong><br>Download the submission ZIP after the files and images look right.</div>

# %% [markdown]
# <div style="font-family:Arial,sans-serif">
#
# ## 06. Download the submission ZIP
#
# Save the complete proposal package to your computer.
#
# </div>

# %%
CONFIRM_PROPOSAL_REVIEW = False #@param {type:"boolean"}
DOWNLOAD_SUBMISSION_ZIP = True #@param {type:"boolean"}

if not CONFIRM_PROPOSAL_REVIEW:
    raise ValueError(
        "Inspect the generated file list, gallery card, and samples, then check CONFIRM_PROPOSAL_REVIEW"
    )
if DOWNLOAD_SUBMISSION_ZIP:
    offer_submission_download(proposal["archive"])
else:
    print("Submission ZIP:", proposal["archive"])
